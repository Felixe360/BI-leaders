# %% [markdown]
# # Homework 6: N-Gram Language Models with the Brown Corpus
#
# ## Due: Midnight on October 12th @ Midnight (with 2-hour grace period) and worth 85 points.
#
# ## As announced, I'll not start to count late days until midnight on 10/13 (with same grace period).
#
# In this assignment you’ll practice **probabilistic language modeling (PLM)** by building N-Gram models that generate text. Along the way, you’ll develop the core pieces of a language model: estimating probabilities, calculating sentence likelihoods, and generating text with different strategies. The goal is to understand *how simple statistical models can produce coherent language*, and to explore refinements that make them more expressive.
#
# ### Learning Objectives
#
# * Build and compare **unigram, bigram, and trigram** language models.
# * Calculate **word and sentence probabilities** (in log-space) and use them to measure **perplexity**.
# * Implement **probability-based generation** methods, including temperature-scaled sampling.
# * Explore **beam search** as a way to generate higher-quality sentences.
#
# ### The four problems (high level)
#
# 1. **Problem 1 — N-Gram probabilities:**
#    Build unigram, bigram, and trigram models. Compute next-word probabilities in log space to avoid numerical underflow.
#
# 2. **Problem 2 — Sentence probability & perplexity:**
#    Define sentence probability, normalize for sentence length, and calculate perplexity as a measure of model quality.
#
# 3. **Problem 3 — Controlled generation:**
#    Implement temperature-controlled sampling to vary randomness in generated sentences. Compare low vs. high temperatures.
#
# 4. **Problem 4 — Beam search:**
#    Use perplexity to guide **beam search**, keeping track of the most likely candidate sentences at each step, and compare outputs to greedy generation.
#
# By the end, you’ll have a working N-Gram generator capable of producing reasonable and a solid understanding of how early probabilistic approaches to NLP laid the foundation for modern deep learning methods.

# %% [markdown]
# ### Recommended Workflow (Must Read!)
#
# One of the most important skills in machine learning is following a **disciplined workflow** when developing complex code. The basic idea is simple:
#
# 1. **Start small:** Write and test your code using a tiny subset of your dataset.
# 2. **Inspect your results:** Print out and examine intermediate outputs to verify that each step behaves as expected.
# 3. **Iterate and tune:** Adjust hyperparameters and continue testing, gradually increasing the subset size as needed.
# 4. **Scale up:** Once you are confident your code is bug-free and your hyperparameters are roughly correct, run it on the **full dataset** to obtain your final results.
#
# If you don’t have sufficient computing resources for a full run, use **as large a subset as practical** — provided you’ve begun early enough to allow for multiple iterations.
#
#
# To help you follow this workflow in this homework, I’ve included a variable `num_sentences` that controls how many sentences are used from the shuffled Brown Corpus.
#
# I recommend the following progression:
#
# * **Step 1:** Begin with `num_sentences = 10` to debug and print out intermediate data structures (such as dictionaries) to confirm that your code works as expected.
# * **Step 2:** Increase to `num_sentences = 100` to verify correctness and complete most of the homework efficiently.
# * **Step 3:** Finally, if possible, run with the full dataset (`num_sentences = 57_340`), or as large a subset as your resources allow, to answer the graded questions.
#
#
# There are 9 problems in this homework, each worth 9 points each, and you get 4 points free if you otherwise complete the homework.

# %% [markdown]
# #### Useful Imports (add more as needed)

# %%
import math
import re
import string
import random
import spacy
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import pyplot as plt
from collections import Counter

random.seed(42)

# %%
'''
Reconstruct a human-readable sentence from tokens.
- Capitalize the first token (after removing <s>).
- Attach any token in string.punctuation with no preceding space.
- Attach tokens starting with an apostrophe (e.g., "'s", "'ll") with no space.
- Capitalize standalone 'i' and 'god' wherever they appear.
- If the last token is '.', '?', or '!', attach it without a space.
- Ignore boundary markers <s> and </s> if present.
Returns the sentence string and also prints it depending on flag parameter.
'''

def print_sentence(tokens, do_print=True):

    if not tokens:
        print("")
        return ""

    # Drop boundary markers if present
    start = 1 if tokens and tokens[0] == "<s>" else 0
    end = -1 if tokens and tokens[-1] == "</s>" else len(tokens)
    core = tokens[start:end]

    if not core:
        print("")
        return ""

    # Capitalize first token
    out = core[0].capitalize()

    # Process remaining tokens with spacing rules
    for i, t in enumerate(core[1:], start=1):
        is_last = (i == len(core) - 1)

        # Last-token punctuation rule
        if is_last and t in {".", "?", "!"}:
            out += t
            continue

        # General punctuation attaches with no space (e.g., ',', ':', ';', ')', etc.)
        if t in string.punctuation:
            out += t
            continue

        # Apostrophe-start tokens like "'s", "'d", "'ll"
        if t.startswith("'"):
            out += t
            continue

        # Capitalize special standalone words
        if t.lower() in {"i", "god"}:
            out += " " + t.capitalize()
            continue

        # Default: add a space before normal words
        out += " " + t

    if do_print:
        print(out)
    return out

# %% [markdown]
# ### Read in the list of all sentences in the Brown Corpus and process using SPaCy.

# %%
# Must do this the first time to get the Natural Language ToolKit

# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk
from nltk.corpus import brown
import spacy

nltk.download('brown')

# Get all Brown corpus sentences as raw text
# Brown is organized into categories, we flatten it into one list of sentences and shuffle
# so we can create a shorter list for testing

brown_texts = [" ".join(sent) for sent in brown.sents()]

random.shuffle(brown_texts)

# Brown has 57_340 sentences, set `num_sentences` to 1000 or smaller for testing

num_sentences = 57_340
#num_sentences = 1000                           # <<<<<=====    Here is where you can change the size of the dataset

brown_texts = brown_texts[:num_sentences]

# Load spaCy English pipeline
nlp = spacy.load("en_core_web_sm")

# Process with spaCy: tokenize + sentencize
docs = list(nlp.pipe(brown_texts, disable=["ner", "tagger", "parser"]))

# Each doc is one sentence; extract tokens and add beginning and ending tokens <s> ... </s>
tokenized_sentences = [ ['<s>'] + [token.text.lower() for token in doc if not token.is_space] + ['</s>'] for doc in docs ]
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# /usr/local/lib/python3.12/dist-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# #### If you have trouble downloading this...
#
#
# I have uploaded a file `brown_sentences.txt` to a Google Drive folder which anyone with the link can read, just
# uncomment the code in the next cell and run it:

# %%
'''
import re, requests, random, spacy

# Paste the shared Drive link (no need to change anything else)
link = "https://drive.google.com/file/d/1f_BkNDF0ny11Tn4D4jsOoXhgPSUCHKlf/view?usp=drive_link"

# --- Convert to direct download URL ---
def get_direct_download_url(link):
    match = re.search(r"/d/([a-zA-Z0-9_-]+)", link) or re.search(r"id=([a-zA-Z0-9_-]+)", link)
    if not match:
        raise ValueError("Could not extract file ID from the link.")
    file_id = match.group(1)
    return f"https://drive.google.com/uc?export=download&id={file_id}"

url = get_direct_download_url(link)

# --- Download and prepare the text ---
response = requests.get(url)
lines = response.text.strip().split("\n")

random.shuffle(lines)


# Etc as before
'''
# Out:
# '\nimport re, requests, random, spacy\n\n# Paste the shared Drive link (no need to change anything else)\nlink = "https://drive.google.com/file/d/1f_BkNDF0ny11Tn4D4jsOoXhgPSUCHKlf/view?usp=drive_link"\n\n# --- Convert to direct download URL ---\ndef get_direct_download_url(link):\n    match = re.search(r"/d/([a-zA-Z0-9_-]+)", link) or re.search(r"id=([a-zA-Z0-9_-]+)", link)\n    if not match:\n        raise ValueError("Could not extract file ID from the link.")\n    file_id = match.group(1)\n    return f"https://drive.google.com/uc?export=download&id={file_id}"\n\nurl = get_direct_download_url(link)\n\n# --- Download and prepare the text ---\nresponse = requests.get(url)\nlines = response.text.strip().split("\n")\n\nrandom.shuffle(lines)\n\n\n# Etc as before\n'

# %%
print("Number of sentences:", len(tokenized_sentences))
print("First sentence:      ",end='')
print_sentence(tokenized_sentences[0])
print("Tokenized sentence: ",end='')
print(tokenized_sentences[0])
# Out:
# Number of sentences: 57340
# First sentence:      He let her tell him all about the church.
# Tokenized sentence: ['<s>', 'he', 'let', 'her', 'tell', 'him', 'all', 'about', 'the', 'church', '.', '</s>']

# %% [markdown]
# ### A Little EDA....

# %%
# Flatten tokens (exclude spaces)
all_tokens = [tok.text.lower() for sent in docs for tok in sent if not tok.is_space]

# Define "word": alphabetic, or alphabetic after removing internal apostrophes
def is_word(tok):
    s = tok.text
    return s.isalpha() or s.replace("'", "").isalpha()

# Extract words using the definition above
words = [
    tok.text.lower()
    for sent in docs
    for tok in sent
    if not tok.is_space and is_word(tok)
]

# Counts
num_chars = sum(len(s) for s in brown_texts)   # or len(text) if you started from one big text
num_tokens = len(all_tokens)
num_unique_tokens = len(set(all_tokens))
num_sentences = len(docs)
num_words = len(words)
num_unique_words = len(set(words))

print(f"Total number of characters in the text: {num_chars:,}")
print(f"Total number of tokens:    {num_tokens:,}")
print(f"Number of unique tokens:   {num_unique_tokens:,}")
print(f"Total number of sentences: {num_sentences:,}")
print(f"Total number of words:     {num_words:,}")
print(f"Number of unique words:    {num_unique_words:,}")

# Frequencies
word_counts = Counter(words)
most_common_words = word_counts.most_common()

# Top 10
print("\nTop 10 words:")
for token, freq in most_common_words[:10]:
    print(f"{token:<15}: {freq:,}")

# Bottom 10
print("\nBottom 10 words:")
for token, freq in most_common_words[-10:]:
    print(f"{token:<15}: {freq:,}")
# Out:
# Total number of characters in the text: 6,069,734
# Total number of tokens:    1,198,833
# Number of unique tokens:   43,320
# Total number of sentences: 57,340
# Total number of words:     1,017,681
# Number of unique words:    41,455
#
# Top 10 words:
# the            : 70,003
# of             : 36,473
# and            : 28,916
# to             : 26,241
# a              : 23,259
# in             : 21,419
# that           : 10,789
# is             : 10,206
# was            : 9,969
# he             : 9,801
#
# Bottom 10 words:
# sedentary      : 1
# spellbound     : 1
# hydro          : 1
# keepers        : 1
# pompadour      : 1
# overland       : 1
# midwesterners  : 1
# layoffs        : 1
# pubs           : 1
# linoleum       : 1

# %% [markdown]
# ### Digression: Zipf's Law
#
# Zipf's Law is an empirical regularity of natural language:
# if you rank words by their frequency in a corpus, the frequency \( f(r) \) of the word at rank \( r \) is approximately inversely proportional to its rank:
#
# $$
# f(r) \propto \frac{1}{r^k}
# $$
#
# where $ r = 1, 2, 3, \dots $ is the rank of a word (1 = most frequent), and $ k \approx 1 $.
#
# - The most common words (e.g., *the*, *of*, *and*) occur very often.
# - A handful of mid-ranked words occur moderately often.
# - The vast majority of words occur rarely.
#
# On a **log–log plot** of frequency vs. rank, this relationship appears as a straight line with slope \(-k\).
# For natural language, empirical studies show that $k \approx 1$, which is why we plot below a reference line with slope $-1$ to compare against real corpus data.
#
#
# **Why this matters:** Because most words are rare, language models must use techniques like **smoothing, subword modeling, or embeddings** to handle sparsity and represent meaning effectively.

# %%
# Frequencies sorted by rank
freqs = np.array([freq for token, freq in word_counts.most_common()])
ranks = np.arange(1, len(freqs) + 1)

plt.figure(figsize=(8, 5))
plt.plot(ranks, freqs, label="Corpus data")

# Reference line: slope = -1 (Zipf’s law)
# Match scale by anchoring at the first frequency
ref_line = freqs[0] / ranks
plt.plot(ranks, ref_line, "--", label="Reference slope = -1")

plt.xscale("log")
plt.yscale("log")
plt.title("Token Frequencies vs. Rank (Zipf’s Law)")
plt.xlabel("Rank of token")
plt.ylabel("Frequency of token")
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# Compute sentence lengths from spaCy docs
sentence_lengths = [len([tok for tok in sent if not tok.is_space]) for sent in docs]

# Plot histogram
plt.figure(figsize=(8, 4))
plt.hist(
    sentence_lengths,
    bins=range(1, max(sentence_lengths) + 2),
    color="skyblue",
    edgecolor="black"
)
plt.title("Histogram of Sentence Lengths")
plt.xlabel("Sentence length (in tokens)")
plt.ylabel("Number of sentences")
plt.tight_layout()
plt.show()

print(f"Average sentence length: {sum(sentence_lengths)/len(sentence_lengths):.2f} tokens")
print(f"Max sentence length:     {max(sentence_lengths)} tokens")
# Out:
# Average sentence length: 20.91 tokens
# Max sentence length:     182 tokens

# %% [markdown]
# ## Problem One — Build the PLM (bigrams & trigrams)
#
# For this problem, you must adapt (mostly cut-and-paste) the code from this week’s Coding Notebook to the new dataset. You are using a trigram model as well as bigrams but your professor has written code that should mostly work for any N.
#
# We provide a pre-processed dataset above, with sentences already tokenized and enclosed in the boundary tokens `<s>` and `</s>`.
#
# **Set `num_sentences=10` to start!**
#
# **ToDo:**
#
# **A.** Build N-grams for N = 2, 3
#
# - Compute all bigrams and trigrams over the tokenized sentences (boundary tokens included).
#
# **B.** Create a dictionary mapping left-contexts to next-word lists
#
# - For each N, map each context (length N−1) to a list of next tokens (allow duplicates so frequency = count).
#
# **C.** Convert to (log) probability distributions
#
# - Turn each context’s next-word list into a distribution of log-probabilities (see **Appendix Two**).
#
# **D.** Create the Probability Language Model (PLM)
#
# - Create a dictionary `get_next_word` with:
#
#     - Key: left context (tuple of 1 token for bigrams; 2 tokens for trigrams).
#
#     - Values: nested dictionary mapping next tokens to log-probabilities `{next_token: log_prob, ...}`.
#
# - Create a **single dictionary** (since bigrams and trigrams have a left context of different lengths, and they won't get confused in the dictionary).
#
#
# **E.** Set the variable `num_sentences = 10` and do a sanity check by displaying the distribution for the bigram contexts e.g., `('<s>',)` and `('the',)` and a trigram context `('<s>','the')`. If for some reason these are not present, increase the number of sentences slightly.
#
# **F.**  Generate 5 next words for each of the 3 examples in the previous part.
#
# **Then answer the graded questions.**

# %%
# Your code here (add as many cells as you need)

def get_ngrams(sent, N):
    return [ tuple(sent[k:k+N]) for k in range(len(sent) - N + 1) ]






bigrams = []
for sent in tokenized_sentences:
    bigrams += get_ngrams(sent,2)

print(f"There are {len(bigrams)} total bigrams.")
print(f"There are {len(set(bigrams))} unique bigrams.")



trigrams = []
for sent in tokenized_sentences:
    trigrams += get_ngrams(sent,3)

print(f"There are {len(trigrams)} total trigrams.")
print(f"There are {len(set(trigrams))} unique trigrams.")
list: trigrams


def get_next_word_dict(ngrams):
    word_dict = {}
    for ng in ngrams:
        lcontext = ng[:-1]
        next_word = ng[-1]
        word_dict[lcontext] = word_dict.get(lcontext, []) + [next_word]
    return word_dict

get_next_word_dict( bigrams )

get_next_word_dict( trigrams )
# Out:
# There are 1256173 total bigrams.
# There are 431034 unique bigrams.
# There are 1198833 total trigrams.
# There are 873857 unique trigrams.
# {('<s>', 'he'): ['let',
#   'rolled',
#   'saw',
#   'was',
#   'swore',
#   'was',
#   'was',
#   'sees',
#   'bogeyed',
#   'was',
#   'had',
#   'said',
#   'plays',
#   'found',
#   'struggled',
#   'will',
#   'was',
#   'is',
#   'still',
#   'travelled',
#   'did',
#   'took',
#   'does',
#   'pressed',
#   'trusts',
#   'flew',
#   'had',
#   'found',
#   'examined',
#   'is',
#   'sat',
#   'looked',
#   'was',
#   'staggered',
#   'had',
#   'walked',
#   'would',
#   'wo',
#   'played',
#   'advanced',
#   'who',
#   'had',
#   'was',
#   'did',
#   'came',
#   'started',
#   'said',
#   'wondered',
#   'wore',
#   'only',
#   'is',
#   'simply',
#   'remembered',
#   'oughta',
#   'started',
#   'was',
#   'went',
#   'may',
#   'pulled',
#   'was',
#   'also',
#   'is',
#   'wondered',
#   'rose',
#   'is',
#   'said',
#   'owned',
#   'heard',
#   'inferred',
#   'just',
#   'caught',
#   'quickly',
#   'washed',
#   'was',
#   'did',
#   'had',
#   'looked',
#   'went',
#   'often',
#   'might',
#   'saw',
#   'did',
#   'can',
#   'doubted',
#   'found',
#   'may',
#   'had',
#   'was',
#   'studied',
#   'could',
#   'had',
#   'dropped',
#   'is',
#   'identified',
#   'pointed',
#   'waited',
#   'chooses',
#   'endured',
#   'jerked',
#   'noted',
#   'had',
#   'is',
#   'realized',
#   'added',
#   'was',
#   'even',
#   'is',
#   'shivered',
#   'drew',
#   'is',
#   "'s",
#   'can',
#   'had',
#   'can',
#   'probably',
#   'seemed',
#   'was',
#   'was',
#   'had',
#   'said',
#   'asked',
#   'had',
#   'was',
#   'had',
#   "'s",
#   'is',
#   'took',
#   'stood',
#   'sized',
#   'asked',
#   'pointed',
#   'was',
#   'prefers',
#   'had',
#   'went',
#   "'s",
#   'is',
#   'was',
#   'wants',
#   'can',
#   'would',
#   'scratched',
#   'narrowed',
#   'had',
#   "'s",
#   'turned',
#   'meant',
#   'had',
#   'brushed',
#   'thought',
#   'was',
#   'peered',
#   "'s",
#   'knew',
#   'let',
#   'keeps',
#   'wanted',
#   'was',
#   'had',
#   'daydreamed',
#   'dropped',
#   'spent',
#   'was',
#   'knew',
#   'arrived',
#   'squatted',
#   'will',
#   'put',
#   'had',
#   'whistled',
#   'spoke',
#   'started',
#   'put',
#   'did',
#   'is',
#   'ran',
#   'had',
#   'has',
#   'hoped',
#   'turned',
#   'must',
#   'promptly',
#   'said',
#   'was',
#   'looked',
#   'urged',
#   'found',
#   'has',
#   'heard',
#   'was',
#   'thought',
#   'seemed',
#   'whirled',
#   'did',
#   'had',
#   'expected',
#   'strained',
#   'always',
#   'lived',
#   'meant',
#   'is',
#   'started',
#   'was',
#   'had',
#   'moved',
#   'was',
#   'quickly',
#   'has',
#   'was',
#   'could',
#   'may',
#   'then',
#   'raced',
#   'hung',
#   'did',
#   'bases',
#   'had',
#   'also',
#   'said',
#   'said',
#   'lifted',
#   'said',
#   'did',
#   'tossed',
#   'did',
#   'told',
#   'will',
#   'saw',
#   'winced',
#   'shares',
#   'even',
#   'was',
#   'did',
#   'staggered',
#   'had',
#   'suggested',
#   'had',
#   'tried',
#   'showed',
#   'did',
#   'told',
#   'was',
#   'thought',
#   'spoke',
#   "'s",
#   'sneezed',
#   'merely',
#   'died',
#   'is',
#   'and',
#   'often',
#   'shouted',
#   'caused',
#   'retired',
#   'was',
#   'repeated',
#   "'s",
#   'could',
#   'had',
#   'gives',
#   'consulted',
#   'is',
#   'helped',
#   'put',
#   "'s",
#   'laid',
#   'felt',
#   'set',
#   'was',
#   'was',
#   'asked',
#   'studied',
#   'rose',
#   'must',
#   'would',
#   'was',
#   'shouted',
#   'conjures',
#   'had',
#   'composed',
#   'had',
#   'could',
#   'came',
#   'moistened',
#   'stopped',
#   'stared',
#   'looked',
#   'gaped',
#   'knew',
#   'took',
#   'had',
#   'had',
#   'believed',
#   'spoke',
#   'likes',
#   'had',
#   'queried',
#   'waited',
#   'imagined',
#   'assures',
#   'was',
#   'looked',
#   'shouted',
#   'said',
#   'supports',
#   'may',
#   'is',
#   'threw',
#   'had',
#   'turned',
#   'thought',
#   'went',
#   'said',
#   'had',
#   'started',
#   'looked',
#   'accepted',
#   'wondered',
#   'must',
#   'was',
#   'was',
#   'indicated',
#   'left',
#   'set',
#   'asked',
#   'is',
#   'asked',
#   'was',
#   'fled',
#   'did',
#   'thought',
#   'was',
#   'says',
#   'waited',
#   'was',
#   'says',
#   'suggested',
#   'would',
#   'shouted',
#   'is',
#   'had',
#   'turned',
#   'hit',
#   'moved',
#   'accepts',
#   'recognized',
#   'called',
#   'filled',
#   'was',
#   'now',
#   'liked',
#   'went',
#   'unlaced',
#   'murmured',
#   'is',
#   'hit',
#   'is',
#   'said',
#   'reasons',
#   'had',
#   'pulled',
#   'had',
#   'threw',
#   'ai',
#   'could',
#   'supervised',
#   'was',
#   'was',
#   'had',
#   'asks',
#   'stumbled',
#   "'s",
#   'instructed',
#   'hooked',
#   'also',
#   'found',
#   'paid',
#   'was',
#   'figured',
#   'also',
#   'did',
#   "'s",
#   'scowled',
#   'maintained',
#   'knew',
#   'spent',
#   'hoped',
#   'thought',
#   'straightened',
#   'strolled',
#   'is',
#   'began',
#   'darted',
#   'said',
#   'had',
#   'declined',
#   'was',
#   'holds',
#   'brought',
#   'asked',
#   'clomped',
#   'had',
#   'demanded',
#   'made',
#   'does',
#   'says',
#   'crossed',
#   'simply',
#   'was',
#   'had',
#   'stole',
#   'wondered',
#   'was',
#   'has',
#   'stepped',
#   'began',
#   'is',
#   'is',
#   'was',
#   "'d",
#   'did',
#   'licked',
#   'attended',
#   'looked',
#   'won',
#   'said',
#   'had',
#   'was',
#   "'s",
#   'was',
#   'was',
#   'made',
#   'knew',
#   "'s",
#   'was',
#   'did',
#   'asked',
#   'proudly',
#   'had',
#   'knew',
#   'enlisted',
#   'scored',
#   'must',
#   'did',
#   'found',
#   'was',
#   'turned',
#   'had',
#   'was',
#   'said',
#   'wanted',
#   'had',
#   'dumped',
#   'immediately',
#   'deplored',
#   'forgot',
#   'told',
#   'ate',
#   'had',
#   'had',
#   'enjoyed',
#   'worked',
#   'is',
#   'was',
#   'burst',
#   'jumped',
#   'spat',
#   'could',
#   'knew',
#   'himself',
#   'went',
#   'was',
#   'took',
#   'kept',
#   'alludes',
#   'do',
#   'wished',
#   'was',
#   'laughed',
#   'locked',
#   'thought',
#   'will',
#   'gave',
#   'staggered',
#   'reviews',
#   'put',
#   'really',
#   'was',
#   'had',
#   'is',
#   'saw',
#   'simply',
#   'intimated',
#   'stopped',
#   'had',
#   'rose',
#   'lifts',
#   'had',
#   'wisecracked',
#   'thought',
#   'handed',
#   'was',
#   'emphasized',
#   "'d",
#   'caught',
#   'is',
#   'wanted',
#   'felt',
#   'would',
#   'laughed',
#   'ran',
#   'spoke',
#   'will',
#   'was',
#   'said',
#   'was',
#   'mumbled',
#   'himself',
#   'always',
#   'unlashed',
#   'knows',
#   'turned',
#   'ran',
#   'hurried',
#   'was',
#   'must',
#   'lived',
#   'doubted',
#   'brushed',
#   'sympathized',
#   'had',
#   'tried',
#   'hesitated',
#   'was',
#   'smiled',
#   'would',
#   'did',
#   'was',
#   'stood',
#   'took',
#   'was',
#   'had',
#   'wore',
#   'did',
#   'had',
#   'was',
#   'could',
#   'was',
#   'got',
#   "'s",
#   'was',
#   'thought',
#   'would',
#   'was',
#   'waited',
#   'spoke',
#   'tugged',
#   'threw',
#   'asked',
#   'served',
#   'was',
#   'sputtered',
#   'remained',
#   'claims',
#   'had',
#   'had',
#   'clamped',
#   'drew',
#   "'d",
#   'and',
#   'thought',
#   'did',
#   'is',
#   'was',
#   'was',
#   'had',
#   'had',
#   'slammed',
#   'asked',
#   'examined',
#   'was',
#   'knelt',
#   'got',
#   'believed',
#   'need',
#   'stood',
#   'knew',
#   'also',
#   'did',
#   'is',
#   'told',
#   'had',
#   'felt',
#   'drew',
#   'hardly',
#   'was',
#   'raised',
#   'turned',
#   'said',
#   'adjusted',
#   'said',
#   'would',
#   'poured',
#   'came',
#   'wore',
#   'stifled',
#   'feels',
#   'stopped',
#   'considered',
#   'half',
#   'might',
#   'had',
#   'said',
#   "'d",
#   'was',
#   'is',
#   'had',
#   'was',
#   'said',
#   'stared',
#   'took',
#   'settled',
#   'would',
#   'became',
#   'had',
#   'was',
#   'promised',
#   'paused',
#   'has',
#   'says',
#   'disliked',
#   'turned',
#   'finished',
#   'got',
#   'ogled',
#   'bases',
#   'was',
#   'was',
#   'stretched',
#   'said',
#   'had',
#   'drew',
#   'trembled',
#   'had',
#   'may',
#   'held',
#   'found',
#   'hated',
#   'may',
#   'half',
#   'cupped',
#   'was',
#   'wondered',
#   'came',
#   'kept',
#   'occupied',
#   'said',
#   'parked',
#   'was',
#   'stalked',
#   'bellowed',
#   'catches',
#   'gave',
#   "'s",
#   'thought',
#   'found',
#   "'d",
#   'had',
#   'smiled',
#   'is',
#   'was',
#   'put',
#   'was',
#   'is',
#   'avoided',
#   'went',
#   'moved',
#   'had',
#   'nodded',
#   'expressed',
#   'asked',
#   'rejects',
#   'put',
#   'apologized',
#   'had',
#   'backed',
#   'may',
#   'is',
#   'outplayed',
#   'also',
#   'had',
#   'had',
#   'was',
#   'took',
#   'was',
#   'really',
#   'shouted',
#   'released',
#   'bravely',
#   'remembered',
#   'had',
#   'looked',
#   'had',
#   'could',
#   'was',
#   'looked',
#   'ran',
#   'wanted',
#   'went',
#   ':',
#   'could',
#   'frequently',
#   'promised',
#   "'ll",
#   'did',
#   'might',
#   'said',
#   'was',
#   'was',
#   'had',
#   'could',
#   'was',
#   'was',
#   "'ll",
#   'is',
#   'had',
#   'asked',
#   "'s",
#   'bogeyed',
#   'released',
#   'has',
#   'courageously',
#   'turned',
#   'cites',
#   'was',
#   'could',
#   'drove',
#   'seemed',
#   'asked',
#   'said',
#   ',',
#   "'s",
#   'arose',
#   'crossed',
#   'could',
#   'says',
#   'did',
#   'climbed',
#   'is',
#   'then',
#   'said',
#   'had',
#   'recognized',
#   'is',
#   'looked',
#   'addresses',
#   'thought',
#   'returned',
#   'had',
#   'had',
#   'became',
#   'showed',
#   'never',
#   'treated',
#   'introduced',
#   'was',
#   'breathed',
#   'flexed',
#   'looked',
#   'smiled',
#   'stared',
#   'rammed',
#   'heard',
#   "'d",
#   'remained',
#   'has',
#   'hit',
#   'carried',
#   'began',
#   'stared',
#   'must',
#   'wiped',
#   'is',
#   'was',
#   'is',
#   'was',
#   'said',
#   'could',
#   'set',
#   'is',
#   'stood',
#   'wanted',
#   'had',
#   'thought',
#   'may',
#   'liked',
#   'saw',
#   'had',
#   'did',
#   'is',
#   'stressed',
#   'left',
#   'read',
#   'commanded',
#   'spoke',
#   'again',
#   'may',
#   'snorted',
#   'also',
#   'amused',
#   'shook',
#   'laughed',
#   'cleaned',
#   'wondered',
#   'sat',
#   "'d",
#   'had',
#   'wanted',
#   'ranted',
#   'thought',
#   'was',
#   'brought',
#   'was',
#   "'d",
#   'would',
#   'swore',
#   'was',
#   'said',
#   'turned',
#   'terms',
#   'knew',
#   'grinned',
#   'asked',
#   'tried',
#   'was',
#   'tried',
#   'said',
#   'knows',
#   'has',
#   'was',
#   'said',
#   'was',
#   'was',
#   'protested',
#   'hit',
#   'had',
#   'arraigned',
#   'who',
#   'looked',
#   'jumped',
#   'saw',
#   'said',
#   'may',
#   'also',
#   'glanced',
#   'did',
#   'also',
#   'had',
#   'chuckled',
#   'dumped',
#   'replaced',
#   'quickly',
#   "'s",
#   'can',
#   'did',
#   'felt',
#   'knew',
#   'could',
#   "'s",
#   'has',
#   'spoke',
#   'loved',
#   'reminded',
#   'had',
#   'had',
#   'knew',
#   'limps',
#   'was',
#   'is',
#   'broke',
#   'slept',
#   'was',
#   'really',
#   'was',
#   'cupped',
#   'had',
#   'has',
#   'had',
#   'was',
#   'flounders',
#   'had',
#   'is',
#   'threw',
#   'was',
#   'appeared',
#   'realized',
#   'felt',
#   'was',
#   'expects',
#   'smiled',
#   'made',
#   'does',
#   'cited',
#   'asked',
#   'made',
#   'grew',
#   'went',
#   'was',
#   'drew',
#   'worked',
#   'looked',
#   'meandered',
#   'said',
#   'thought',
#   'felt',
#   'seemed',
#   'looked',
#   'was',
#   'might',
#   'explains',
#   'nodded',
#   'recalled',
#   'is',
#   'ai',
#   'could',
#   'crossed',
#   'dozed',
#   'said',
#   'liked',
#   'nodded',
#   'left',
#   'scrawled',
#   'would',
#   'asked',
#   'dropped',
#   'handed',
#   'never',
#   'was',
#   'tramped',
#   'went',
#   'went',
#   'wore',
#   "'s",
#   'appealed',
#   'did',
#   'began',
#   'rubbed',
#   'said',
#   'found',
#   'came',
#   'spat',
#   'was',
#   'came',
#   'himself',
#   'bent',
#   'says',
#   'could',
#   'would',
#   'still',
#   'got',
#   'may',
#   'had',
#   'walked',
#   'did',
#   'has',
#   'asked',
#   'was',
#   'spoke',
#   'said',
#   'stood',
#   "'d",
#   'says',
#   'felt',
#   'said',
#   "'s",
#   'was',
#   'spent',
#   'said',
#   'was',
#   'knew',
#   'clattered',
#   'must',
#   'can',
#   'and',
#   'dates',
#   'knew',
#   'later',
#   'can',
#   'had',
#   'was',
#   'stumbled',
#   'tried',
#   'had',
#   'got',
#   'threw',
#   'played',
#   'would',
#   'asked',
#   'went',
#   'will',
#   ...],
#  ('he', 'let'): ['her',
#   'go',
#   'go',
#   'me',
#   'her',
#   'the',
#   'pike',
#   'down',
#   'eileen',
#   'his',
#   'a'],
#  ('let', 'her'): ['tell',
#   'hand',
#   'call',
#   'go',
#   'go',
#   'gaze',
#   'leave',
#   'out',
#   'out',
#   'talk',
#   'harm',
#   'leave',
#   'stay',
#   'go',
#   'have',
#   'choose'],
#  ('her', 'tell'): ['him'],
#  ('tell', 'him'): ['all',
#   'that',
#   ',',
#   '.',
#   'about',
#   "''",
#   'how',
#   'about',
#   ',',
#   'you',
#   '--',
#   'what',
#   ',',
#   'about',
#   'to',
#   'if',
#   'to',
#   'i',
#   'i',
#   'this',
#   'he',
#   'she',
#   '.',
#   'i',
#   'what',
#   'i',
#   ',',
#   'all',
#   ',',
#   'about',
#   'everything',
#   'at',
#   'the',
#   'under'],
#  ('him', 'all'): ['about', 'but', 'the', 'this', 'day', 'the'],
#  ('all', 'about'): ['the',
#   'and',
#   'him',
#   'mother',
#   'thelma',
#   'me',
#   'life',
#   'the',
#   'knives',
#   '.',
#   'seven',
#   'the',
#   'it',
#   'that',
#   'the',
#   ';',
#   'her',
#   "''",
#   'you',
#   'me',
#   'fascism',
#   'the',
#   'his',
#   "''",
#   ',',
#   'me',
#   'him'],
#  ('about', 'the'): ['church',
#   'last',
#   'place',
#   'british',
#   'bedroom',
#   'history',
#   'murder',
#   'image',
#   'size',
#   'fire',
#   'food',
#   'lunar',
#   'scarcity',
#   'needs',
#   'children',
#   'techniques',
#   'job',
#   'visit',
#   'girls',
#   'rules',
#   'local',
#   'predictive',
#   'men',
#   'question',
#   'prospective',
#   'same',
#   'distance',
#   'problem',
#   'game',
#   'same',
#   'same',
#   'puritans',
#   'feelings',
#   'service',
#   'late',
#   'elemental',
#   'economic',
#   'roman',
#   'present',
#   'murder',
#   'pedersen',
#   'united',
#   'nightmare',
#   'route',
#   'old',
#   'real',
#   'threat',
#   'rest',
#   'plates',
#   'big',
#   'age',
#   'way',
#   'captain',
#   'plans',
#   'graph',
#   'south',
#   'middle',
#   'size',
#   'sufferings',
#   'south',
#   'size',
#   'ways',
#   'future',
#   'unlamented',
#   'only',
#   'comedie',
#   'size',
#   'small',
#   'worth',
#   'presidential',
#   'earth',
#   'materials',
#   'impasse',
#   'progress',
#   'interests',
#   'public',
#   'social',
#   'nationwide',
#   'consistency',
#   'success',
#   'visit',
#   'same',
#   'same',
#   'move',
#   'five',
#   'hindrances',
#   'same',
#   'beach',
#   'outcome',
#   'possible',
#   '$',
#   'situation',
#   'ould',
#   'art',
#   'variety',
#   'difference',
#   '`',
#   'problem',
#   'chance',
#   'size',
#   'area',
#   'infection',
#   'quest',
#   'value',
#   'six',
#   'half',
#   'same',
#   'earth',
#   'situation',
#   'art',
#   'tunisian',
#   'early',
#   'battle',
#   'craft',
#   'actual',
#   'size',
#   'time',
#   'lay',
#   'existential',
#   'dress',
#   '5,000',
#   'tumbles',
#   'draughty',
#   'form',
#   '`',
#   'size',
#   'principle',
#   'crime',
#   'kid',
#   'world',
#   'couple',
#   'methods',
#   'best',
#   'woman',
#   'grand',
#   'trend',
#   'mouth',
#   'new',
#   'size',
#   'state',
#   'hall',
#   'urgency',
#   'problem',
#   'man',
#   'epithet',
#   'show',
#   'furnace',
#   'world',
#   'age',
#   'things',
#   'modern',
#   'redcoats',
#   'national',
#   'civilization',
#   'earth',
#   'best',
#   'humidity',
#   'matter',
#   'ruin',
#   'three',
#   'relative',
#   'final',
#   'characteristics',
#   'kitchen',
#   'case',
#   'whisky',
#   'evil',
#   'same',
#   'case',
#   'only',
#   'other',
#   'whole',
#   'changes',
#   'appeal',
#   'micrometeorite',
#   'individual',
#   'influence',
#   'african',
#   'merits',
#   'ship',
#   'downfall',
#   '*',
#   'most',
#   'money',
#   'same',
#   'world',
#   'lady',
#   'absent',
#   'unthinkable',
#   'free',
#   'other',
#   'problems',
#   'urgency',
#   'civic',
#   'passions',
#   'nature',
#   'day',
#   'coming',
#   'same',
#   'chances',
#   'family',
#   'boy',
#   'spiritual',
#   'impact',
#   'tension',
#   'anonymous',
#   'patient',
#   'stage',
#   'place',
#   'movies',
#   'vertex',
#   'grounds',
#   'tasks',
#   'wickedness',
#   'patient',
#   'old',
#   'same',
#   'same',
#   'speakers',
#   'success',
#   'interview',
#   'house',
#   'face',
#   'price',
#   'building',
#   'inevitable',
#   'relative',
#   'past',
#   'room',
#   'house',
#   'prime',
#   'output',
#   '13/16',
#   'incantation',
#   'forge',
#   'necessary',
#   'prevalence',
#   'loquacity',
#   'west',
#   'implications',
#   'farneses',
#   'value',
#   'injustice',
#   'same',
#   'dreadnought',
#   'american',
#   'trail',
#   'sales',
#   'gifts',
#   'children',
#   'abbey',
#   'face',
#   'terms',
#   'nature',
#   'history',
#   'acropolis',
#   'chaotic',
#   'present',
#   'changing',
#   'patient',
#   'men',
#   'second',
#   'fifty',
#   'peasants',
#   'past',
#   'dallas',
#   'twenty',
#   'rest',
#   'magical',
#   'question',
#   'time',
#   'ransom',
#   'catholics',
#   'current',
#   'audit',
#   '*',
#   'servant',
#   'intellectual',
#   'only',
#   'pollen',
#   'fate',
#   'clerk',
#   'deadlock',
#   'basileis',
#   'highways',
#   'same',
#   'inexplicable',
#   'facts',
#   'z',
#   'christmas',
#   'earth',
#   'good',
#   'car',
#   'slender',
#   'abrupt',
#   'patient',
#   'advisability',
#   'consequences',
#   'ending',
#   'only',
#   'suit',
#   'same',
#   'only',
#   'use',
#   'whistle',
#   'report',
#   'contour',
#   'doctor',
#   'maximum',
#   'emotional',
#   'intrusive',
#   'radio',
#   'separation',
#   'old',
#   'priming',
#   'sun',
#   'children',
#   'same',
#   'child',
#   'pro',
#   'case',
#   'idea',
#   'causes',
#   'very',
#   'talker',
#   'six',
#   'outcome',
#   'deck',
#   'troops',
#   'dollar'],
#  ('the', 'church'): ['.',
#   'today',
#   'unity',
#   'belongs',
#   'of',
#   '.',
#   '.',
#   '.',
#   'with',
#   'organization',
#   '.',
#   'and',
#   'facilities',
#   'has',
#   '.',
#   'itself',
#   '.',
#   'may',
#   'school',
#   'with',
#   'with',
#   'advanced',
#   'need',
#   'and',
#   "''",
#   ')',
#   'at',
#   'does',
#   ';',
#   ',',
#   'of',
#   'means',
#   "''",
#   'and',
#   'seems',
#   '.',
#   'and',
#   ';',
#   'so',
#   'and',
#   ',',
#   'is',
#   'fathers',
#   ',',
#   '.',
#   'of',
#   'certainly',
#   'peace',
#   'of',
#   'once',
#   "''",
#   'will',
#   'considers',
#   '.',
#   'despite',
#   "'s",
#   "'s",
#   'from',
#   'intelligently',
#   'a',
#   'of',
#   'behind',
#   'of',
#   'of',
#   'led',
#   'with',
#   'in',
#   'over',
#   'was',
#   ',',
#   'in',
#   'is',
#   'without',
#   ',',
#   'of',
#   'on',
#   'as',
#   'was',
#   'which',
#   'fellowship',
#   ',',
#   "''",
#   'is',
#   'spire',
#   'spire',
#   'and',
#   'of',
#   'of',
#   'unity',
#   "''",
#   ',',
#   'be',
#   'of',
#   'were',
#   'within',
#   'provide',
#   'of',
#   '!',
#   '.',
#   ',',
#   'of',
#   'of',
#   'of',
#   '.',
#   'was',
#   '.',
#   'as',
#   'they',
#   'door',
#   'bells',
#   '.',
#   'points',
#   'of',
#   'or',
#   'of',
#   'risk',
#   "'s",
#   'also',
#   '.',
#   'and',
#   'truly',
#   'expects',
#   'doorway',
#   'will',
#   'in',
#   ';',
#   'tower',
#   '.',
#   ';',
#   '.',
#   'paper',
#   '--',
#   '.',
#   "'s",
#   'in',
#   'need',
#   "'s",
#   "''",
#   'as',
#   'are',
#   '.',
#   'may',
#   '.',
#   "'s",
#   '(',
#   'and',
#   "'s",
#   ',',
#   'was',
#   'is',
#   'social'],
#  ('church', '.'): ['</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>'],
#  ('<s>', 'china'): ['never'],
#  ('china', 'never'): ['tried'],
#  ('never', 'tried'): ['to', 'to', 'to'],
#  ('tried', 'to'): ['integrate',
#   'shut',
#   'escape',
#   'flatten',
#   'insist',
#   'rape',
#   'shadow',
#   'the',
#   'rest',
#   'rise',
#   'go',
#   'live',
#   'veer',
#   'reach',
#   'persuade',
#   'sell',
#   'make',
#   'remember',
#   'restrict',
#   'make',
#   'refashion',
#   'be',
#   'write',
#   'turn',
#   'explain',
#   'see',
#   'emulate',
#   'find',
#   'pick',
#   'describe',
#   'get',
#   'blast',
#   'humanize',
#   'start',
#   'reason',
#   'push',
#   'take',
#   'conceal',
#   'farm',
#   'roll',
#   'start',
#   'shake',
#   'consult',
#   'keep',
#   'ignore',
#   'quiet',
#   '.',
#   'think',
#   'see',
#   'discover',
#   'lift',
#   'stretch',
#   'persuade',
#   'find',
#   'make',
#   'order',
#   'describe',
#   'push',
#   'run',
#   'outface',
#   'compromise',
#   'subdue',
#   'consider',
#   'date',
#   'be',
#   'make',
#   'believe',
#   'arbitrate',
#   'find',
#   'give',
#   'repair',
#   'stop',
#   'dissuade',
#   'force',
#   'push',
#   'dazzle',
#   'economize',
#   'remedy',
#   'teach',
#   'bring',
#   'calm',
#   'stifle',
#   'talk',
#   'picture',
#   'think',
#   'rescue',
#   'guard',
#   'swim',
#   'make',
#   'explain',
#   'halt',
#   'bring',
#   'break',
#   'brush',
#   'explain',
#   'contain',
#   'tell',
#   'stop',
#   'leave',
#   'tell',
#   'keep',
#   'arbitrate',
#   'see',
#   'prevent',
#   'fling',
#   'do',
#   'breath',
#   'tempt',
#   'step',
#   'keep',
#   'ask',
#   'enter',
#   'call',
#   'ignore',
#   'get',
#   'block',
#   'make',
#   'bite',
#   'settle',
#   'get'],
#  ('to', 'integrate'): ['tibet', ',', 'the', 'east', 'the', 'or'],
#  ('integrate', 'tibet'): ['by'],
#  ('tibet', 'by'): ['extirpating'],
#  ('by', 'extirpating'): ['the'],
#  ('extirpating', 'the'): ['people'],
#  ('the', 'people'): ["'s",
#   "'s",
#   'of',
#   'include',
#   'who',
#   ',',
#   '.',
#   'of',
#   'in',
#   'might',
#   'were',
#   'passing',
#   'watch',
#   'like',
#   'in',
#   "'s",
#   'should',
#   'are',
#   'within',
#   'who',
#   'strike',
#   'of',
#   'individually',
#   'bore',
#   'of',
#   'what',
#   'of',
#   'of',
#   'they',
#   'of',
#   "''",
#   'admire',
#   'of',
#   'everywhere',
#   'of',
#   ',',
#   'out',
#   'they',
#   "''",
#   'themselves',
#   'of',
#   "'s",
#   'of',
#   'where',
#   'in',
#   'inside',
#   'who',
#   'of',
#   'in',
#   'of',
#   'were',
#   'i',
#   '.',
#   'involved',
#   'adequately',
#   'who',
#   'of',
#   'of',
#   'of',
#   'at',
#   'do',
#   ',',
#   'indignant',
#   "''",
#   'at',
#   'to',
#   ')',
#   'of',
#   "'s",
#   'around',
#   ',',
#   'will',
#   ':',
#   'it',
#   '.',
#   'in',
#   'to',
#   'of',
#   'was',
#   'see',
#   'i',
#   'directly',
#   "''",
#   'were',
#   'on',
#   'of',
#   'who',
#   'who',
#   'moved',
#   'overhead',
#   '.',
#   'themselves',
#   'to',
#   'at',
#   'who',
#   'of',
#   ',',
#   ',',
#   ',',
#   "''",
#   'with',
#   ',',
#   'and',
#   'hardest',
#   'of',
#   ',',
#   'to',
#   'from',
#   'turn',
#   'in',
#   'of',
#   'of',
#   ',',
#   "''",
#   'of',
#   'within',
#   'who',
#   '.',
#   'of',
#   '.',
#   "''",
#   'of',
#   'who',
#   'of',
#   'to',
#   'who',
#   'of',
#   'he',
#   'around',
#   'who',
#   'to',
#   'of',
#   'of',
#   'visited',
#   'of'],
#  ('people', "'s"): ['religion',
#   'attitude',
#   'business',
#   'homes',
#   'mental',
#   'consciences',
#   'elected',
#   'intuitive',
#   'republic',
#   'spirit',
#   'eating',
#   'stores',
#   'republic',
#   'respect',
#   'state',
#   'courts',
#   'health',
#   'concert',
#   'nests'],
#  ("'s", 'religion'): ['and'],
#  ('religion', 'and'): ['institutions',
#   'ideology',
#   'the',
#   'the',
#   'private',
#   'they',
#   'politics',
#   'the'],
#  ('and', 'institutions'): ['.', 'to', 'is', 'for', ')', 'of'],
#  ('institutions', '.'): ['</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>',
#   '</s>'],
#  ('<s>', 'finally'): [',',
#   'we',
#   'he',
#   ',',
#   'they',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   'men',
#   'she',
#   ',',
#   'he',
#   ',',
#   ',',
#   'we',
#   ',',
#   'there',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   'petitioner',
#   'come',
#   'we',
#   ',',
#   ',',
#   'he',
#   ',',
#   'luis',
#   ',',
#   ',',
#   ',',
#   'hernandez',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   ',',
#   'we',
#   'he',
#   ',',
#   'he',
#   ',',
#   ',',
#   ',',
#   ',',
#   ','],
#  ('finally', ','): ['it',
#   'the',
#   'that',
#   'except',
#   'in',
#   'it',
#   'mr.',
#   'at',
#   'in',
#   'the',
#   'whatever',
#   'it',
#   'raise',
#   'after',
#   '`',
#   'at',
#   'she',
#   'he',
#   'and',
#   'incoherent',
#   'tiring',
#   'just',
#   'magwitch',
#   'turned',
#   'information',
#   'maintenance',
#   'we',
#   'if',
#   'colleges',
#   'there',
#   'we',
#   '`',
#   'mercer',
#   'where',
#   'the',
#   '`',
#   'the',
#   'orville',
#   'there',
#   'the',
#   'there',
#   'it',
#   'the',
#   'a',
#   'in',
#   'to',
#   'mama',
#   'however',
#   'in',
#   'it',
#   'avoiding',
#   'after',
#   '`',
#   'since',
#   'as',
#   'the',
#   'when',
#   'the',
#   'it',
#   'all',
#   '`'],
#  (',', 'it'): ['is',
#   'became',
#   'shall',
#   'is',
#   'sees',
#   'operates',
#   'seems',
#   'is',
#   'can',
#   'is',
#   'was',
#   'was',
#   'must',
#   'is',
#   'is',
#   'is',
#   'was',
#   'is',
#   'seldom',
#   'may',
#   'is',
#   'was',
#   'was',
#   'underpins',
#   'would',
#   'starts',
#   'visualizes',
#   'had',
#   'is',
#   'did',
#   'causes',
#   'could',
#   "'s",
#   "'s",
#   'evokes',
#   'is',
#   'may',
#   'is',
#   'seems',
#   'is',
#   'will',
#   'is',
#   'is',
#   'is',
#   'said',
#   'must',
#   'makes',
#   'can',
#   'can',
#   'can',
#   'afforded',
#   'was',
#   'is',
#   'normally',
#   'is',
#   'is',
#   'specifically',
#   'is',
#   'was',
#   'will',
#   'sometimes',
#   'is',
#   'is',
#   'was',
#   'has',
#   'failed',
#   'may',
#   'is',
#   'became',
#   'is',
#   "'ll",
#   'is',
#   'is',
#   'was',
#   'would',
#   'will',
#   'would',
#   'is',
#   'entered',
#   'turns',
#   'will',
#   'is',
#   'registered',
#   'seems',
#   'does',
#   'gives',
#   'is',
#   'is',
#   'was',
#   'is',
#   'is',
#   'also',
#   'is',
#   'was',
#   'may',
#   'too',
#   'is',
#   'seemed',
#   'seems',
#   'has',
#   'became',
#   'could',
#   'is',
#   'would',
#   'will',
#   'was',
#   'becomes',
#   'is',
#   'was',
#   'follows',
#   'is',
#   'is',
#   'is',
#   'was',
#   'is',
#   'is',
#   'will',
#   'will',
#   'also',
#   'may',
#   'must',
#   'leaves',
#   'is',
#   'veered',
#   'is',
#   'has',
#   'represents',
#   'is',
#   'will',
#   'is',
#   'was',
#   'appears',
#   'obviously',
#   'must',
#   'is',
#   'was',
#   'may',
#   'must',
#   'stems',
#   'pays',
#   'is',
#   'will',
#   'is',
#   'is',
#   'is',
#   'may',
#   'is',
#   'does',
#   'was',
#   'went',
#   'requires',
#   'is',
#   'would',
#   'is',
#   'was',
#   'is',
#   'was',
#   "'s",
#   'must',
#   'narrows',
#   'is',
#   "'s",
#   'is',
#   'remained',
#   'may',
#   'barely',
#   'is',
#   'would',
#   "'s",
#   'also',
#   'also',
#   'is',
#   'entails',
#   'may',
#   'needs',
#   'rumbles',
#   'will',
#   'appears',
#   'must',
#   'would',
#   'took',
#   'is',
#   'was',
#   'seemed',
#   'is',
#   'is',
#   'will',
#   'was',
#   'must',
#   'would',
#   'was',
#   'was',
#   'was',
#   'was',
#   'took',
#   'was',
#   'occurs',
#   'does',
#   'may',
#   'is',
#   'is',
#   'would',
#   'is',
#   'will',
#   'is',
#   'was',
#   'was',
#   'is',
#   'may',
#   'took',
#   'always',
#   'appears',
#   "'s",
#   'is',
#   'is',
#   'would',
#   'looked',
#   'should',
#   'is',
#   'is',
#   'was',
#   'was',
#   'furthered',
#   'seems',
#   'was',
#   "'s",
#   "'s",
#   'is',
#   'was',
#   'had',
#   'would',
#   'is',
#   "'s",
#   'was',
#   'seemed',
#   'provides',
#   'is',
#   'might',
#   'is',
#   'may',
#   'was',
#   'should',
#   'is',
#   'follows',
#   'would',
#   'is',
#   'seems',
#   'had',
#   'was',
#   'would',
#   'included',
#   'is',
#   'is',
#   'has',
#   'can',
#   'is',
#   'snows',
#   'is',
#   'was',
#   'must',
#   'is',
#   'must',
#   'is',
#   'was',
#   'is',
#   'is',
#   'is',
#   'was',
#   'has',
#   'was',
#   'is',
#   'is',
#   'is',
#   'was',
#   'becomes',
#   'is',
#   'is',
#   'was',
#   "'s",
#   'is',
#   'is',
#   'seems',
#   'was',
#   'was',
#   'is',
#   'is',
#   'will',
#   'would',
#   'is',
#   'may',
#   'is',
#   'has',
#   'will',
#   'is',
#   'speaks',
#   'is',
#   'probably',
#   'became',
#   'could',
#   'will',
#   'appears',
#   'must',
#   'is',
#   'and',
#   "'s",
#   'always',
#   'made',
#   'occurred',
#   'can',
#   'seems',
#   'was',
#   'will',
#   'is',
#   'said',
#   'is',
#   'should',
#   'is',
#   'determined',
#   'makes',
#   'can',
#   'always',
#   'follows',
#   'was',
#   'gestures',
#   'had',
#   'will',
#   'also',
#   'later',
#   'had',
#   'was',
#   'should',
#   'is',
#   'was',
#   'is',
#   'was',
#   'can',
#   'could',
#   'seems',
#   'should',
#   'searches',
#   "'s",
#   'amounts',
#   'did',
#   'seems',
#   'seems',
#   'should',
#   'has',
#   'seems',
#   'was',
#   'is',
#   'is',
#   'would',
#   'seems',
#   'was',
#   'is',
#   'is',
#   'was',
#   'is',
#   'is',
#   'voted',
#   'seems',
#   'was',
#   'is',
#   'allows',
#   'continued',
#   'is',
#   "'s",
#   'can',
#   'might',
#   'could',
#   'was',
#   'does',
#   'was',
#   'seems',
#   'became',
#   'seemed',
#   'is',
#   'was',
#   'could',
#   'was',
#   'was',
#   'was',
#   'soon',
#   'might',
#   'was',
#   'is',
#   'was',
#   'begins',
#   'would',
#   'becomes',
#   'would',
#   'is',
#   'is',
#   'seemed',
#   'was',
#   'is',
#   'has',
#   'was',
#   'was',
#   'would',
#   'makes',
#   'does',
#   'said',
#   'may',
#   'is',
#   'is',
#   'might',
#   'appeared',
#   'will',
#   'is',
#   'was',
#   'is',
#   'is',
#   'is',
#   'is',
#   'will',
#   'would',
#   'does',
#   'is',
#   'meant',
#   'was',
#   'is',
#   'will',
#   'is',
#   'would',
#   'was',
#   'was',
#   'was',
#   'seemed',
#   'just',
#   'is',
#   'could',
#   'is',
#   'has',
#   "'s",
#   'is',
#   'is',
#   'is',
#   '-',
#   'can',
#   'is',
#   'may',
#   'cuts',
#   'is',
#   'has',
#   'should',
#   'was',
#   'is',
#   'may',
#   'behooves',
#   'would',
#   'is',
#   'is',
#   "'s",
#   'was',
#   'should',
#   'does',
#   'was',
#   'was',
#   'was',
#   'was',
#   'had',
#   'was',
#   'was',
#   'suffered',
#   'is',
#   'was',
#   'has',
#   'probably',
#   'is',
#   'was',
#   'has',
#   'would',
#   'would',
#   'was',
#   "'s",
#   'has',
#   'can',
#   'just',
#   'could',
#   'was',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   "'s",
#   'can',
#   'is',
#   "'s",
#   'is',
#   'requires',
#   'can',
#   'might',
#   'makes',
#   'was',
#   'seems',
#   'seems',
#   'can',
#   'was',
#   'has',
#   'is',
#   'would',
#   "'s",
#   'seems',
#   'is',
#   'will',
#   'is',
#   "'s",
#   'is',
#   'was',
#   'is',
#   'is',
#   'was',
#   'must',
#   'just',
#   "'s",
#   'was',
#   'does',
#   'adds',
#   'soon',
#   'seems',
#   'had',
#   'is',
#   'was',
#   'was',
#   'is',
#   'is',
#   'may',
#   'is',
#   'is',
#   'is',
#   'takes',
#   'appears',
#   'appeared',
#   'was',
#   'turned',
#   'is',
#   'called',
#   'should',
#   'seemed',
#   'had',
#   'is',
#   'will',
#   'was',
#   'loses',
#   'could',
#   'naturally',
#   'follows',
#   'consisted',
#   'is',
#   'seems',
#   'can',
#   'is',
#   'is',
#   "'s",
#   'was',
#   'would',
#   'might',
#   'is',
#   'turns',
#   'had',
#   'is',
#   'is',
#   'fall',
#   'will',
#   'must',
#   'remains',
#   'was',
#   'also',
#   'was',
#   'has',
#   'was',
#   'is',
#   'is',
#   'behaved',
#   'has',
#   'would',
#   'was',
#   'is',
#   'must',
#   'seems',
#   'goes',
#   'costs',
#   'is',
#   "'s",
#   'is',
#   'is',
#   'goes',
#   'was',
#   'would',
#   'does',
#   'was',
#   'follows',
#   'is',
#   'will',
#   'is',
#   'did',
#   'sure',
#   'becomes',
#   'is',
#   "'ll",
#   'is',
#   'seemed',
#   'could',
#   "'s",
#   'is',
#   "'s",
#   'may',
#   'must',
#   'is',
#   'supplies',
#   'is',
#   'did',
#   'would',
#   'tooling',
#   'follows',
#   'was',
#   'is',
#   'stuck',
#   'was',
#   'was',
#   'is',
#   'seemed',
#   'would',
#   "'ll",
#   'would',
#   'was',
#   'should',
#   'was',
#   'could',
#   'was',
#   'was',
#   'is',
#   'is',
#   'would',
#   'makes',
#   'was',
#   'is',
#   'should',
#   'was',
#   'can',
#   'was',
#   'would',
#   'excited',
#   "'s",
#   'burns',
#   'follows',
#   'gradually',
#   'would',
#   'was',
#   'was',
#   'is',
#   'will',
#   'manifestly',
#   'is',
#   "'s",
#   'is',
#   'finds',
#   'is',
#   'must',
#   'seemed',
#   'must',
#   "'s",
#   'would',
#   'was',
#   'could',
#   'would',
#   'seemed',
#   'was',
#   'is',
#   'was',
#   'may',
#   'was',
#   'was',
#   'is',
#   'has',
#   'was',
#   'is',
#   "'s",
#   'is',
#   'was',
#   'appeared',
#   'could',
#   'seems',
#   'remained',
#   'always',
#   'is',
#   'has',
#   'is',
#   'was',
#   'will',
#   'will',
#   'is',
#   'is',
#   'has',
#   'was',
#   'underwent',
#   'was',
#   'is',
#   'assumes',
#   'was',
#   "'s",
#   'is',
#   'is',
#   'would',
#   'would',
#   'seemed',
#   'had',
#   'is',
#   'could',
#   'is',
#   'is',
#   'is',
#   'is',
#   'said',
#   'will',
#   'is',
#   'was',
#   'took',
#   'now',
#   'must',
#   'went',
#   'may',
#   'may',
#   'should',
#   'is',
#   'may',
#   'clearly',
#   'will',
#   'is',
#   'will',
#   'is',
#   'seems',
#   'was',
#   'and',
#   'shows',
#   "'s",
#   'would',
#   "'s",
#   'is',
#   'will',
#   'is',
#   'has',
#   'is',
#   'had',
#   'is',
#   'is',
#   'nevertheless',
#   'turned',
#   'would',
#   'continues',
#   'remains',
#   'could',
#   'would',
#   'added',
#   "'s",
#   'along',
#   'has',
#   'became',
#   'is',
#   'must',
#   'will',
#   'is',
#   'would',
#   'was',
#   'was',
#   'came',
#   'will',
#   'would',
#   'is',
#   'is',
#   'might',
#   'is',
#   'wears',
#   'provides',
#   'was',
#   'is',
#   'still',
#   'seems',
#   'may',
#   'gives',
#   'was',
#   'might',
#   'appeared',
#   'is',
#   'rang',
#   'goes',
#   'subjects',
#   'turned',
#   'must',
#   'is',
#   'is',
#   'belongs',
#   'is',
#   'is',
#   'was',
#   'requires',
#   'was',
#   'seems',
#   'meant',
#   'was',
#   'sounds',
#   'was',
#   'is',
#   "'ll",
#   'was',
#   'is',
#   'should',
#   'has',
#   'is',
#   'was',
#   'is',
#   'seemed'],
#  ('it', 'is'): ['suggested',
#   'softened',
#   ',',
#   'fun',
#   'worthwhile',
#   'worthy',
#   'easy',
#   'an',
#   'sort',
#   'very',
#   'one',
#   'greatly',
#   'expressed',
#   'hazardous',
#   'assumed',
#   'the',
#   'mounted',
#   'always',
#   'his',
#   'to',
#   'mars',
#   'an',
#   'only',
#   'an',
#   'just',
#   'not',
#   'characteristic',
#   'in',
#   'a',
#   'not',
#   'permanent',
#   'a',
#   'possible',
#   'important',
#   'on',
#   'as',
#   'as',
#   'the',
#   'the',
#   'not',
#   'more',
#   'through',
#   'hard',
#   'explicable',
#   'all',
#   'surely',
#   'based',
#   'the',
#   'dissimilar',
#   'based',
#   'well',
#   'eminently',
#   'particularly',
#   'the',
#   'true',
#   'certainly',
#   'replaced',
#   'most',
#   'one',
#   'crucial',
#   'not',
#   'not',
#   'for',
#   'the',
#   'not',
#   'a',
#   'often',
#   "n't",
#   'like',
#   ',',
#   'not',
#   'better',
#   'all',
#   'a',
#   'extremely',
#   'perfectly',
#   'used',
#   'panelized',
#   'eternal',
#   'based',
#   'obvious',
#   'possible',
#   'represented',
#   ';',
#   'a',
#   'difficult',
#   'changing',
#   'filed',
#   'his',
#   'going',
#   'realized',
#   'with',
#   'known',
#   'followed',
#   'the',
#   'best',
#   'too',
#   'in',
#   'symptomatic',
#   'not',
#   'understandable',
#   'possible',
#   'also',
#   'based',
#   'not',
#   'clear',
#   'their',
#   'mathematically',
#   'not',
#   'still',
#   'rather',
#   'on',
#   'the',
#   'demonstrated',
#   'something',
#   'largely',
#   'the',
#   'not',
#   'told',
#   'our',
#   'raising',
#   'easy',
#   'easy',
#   'entirely',
#   'presently',
#   'at',
#   'due',
#   'always',
#   'not',
#   'situated',
#   'dying',
#   'planned',
#   'true',
#   'a',
#   ',',
#   'a',
#   'done',
#   'clear',
#   'usually',
#   'perennially',
#   'not',
#   'successful',
#   'constantly',
#   'not',
#   'immediate',
#   'manic',
#   'true',
#   'an',
#   'possible',
#   'part',
#   'pertinent',
#   'mankind',
#   'perhaps',
#   'generally',
#   'doubtful',
#   'likely',
#   'filled',
#   'important',
#   'achieved',
#   'proposed',
#   'completely',
#   'true',
#   'easy',
#   'true',
#   'a',
#   '.',
#   'an',
#   'hypothesized',
#   'not',
#   'easier',
#   'up',
#   'interesting',
#   'sacred',
#   'said',
#   'in',
#   'because',
#   'totally',
#   'because',
#   "n't",
#   'served',
#   'idle',
#   'of',
#   'not',
#   'done',
#   'to',
#   'a',
#   'an',
#   'costing',
#   'also',
#   'a',
#   'being',
#   'the',
#   'also',
#   'by',
#   'an',
#   'hard',
#   'not',
#   'assumed',
#   'worth',
#   'necessary',
#   'engendered',
#   'from',
#   'difficult',
#   'impossible',
#   'distinctly',
#   'performed',
#   'offered',
#   'perfectly',
#   'apparent',
#   'cool',
#   'a',
#   'no',
#   'recognized',
#   'possible',
#   'and',
#   'bringing',
#   'very',
#   'on',
#   'safe',
#   'the',
#   'evident',
#   'not',
#   'good',
#   'like',
#   'hard',
#   'to',
#   'apparent',
#   'the',
#   'evident',
#   'perhaps',
#   'inconsistent',
#   'fatal',
#   'also',
#   'not',
#   'so',
#   'dollars',
#   'today',
#   'an',
#   'an',
#   ',',
#   'the',
#   'the',
#   'relevant',
#   'no',
#   'possible',
#   'this',
#   'an',
#   'a',
#   'not',
#   'not',
#   'a',
#   "n't",
#   'not',
#   'in',
#   'an',
#   'the',
#   'the',
#   'ourselves',
#   'purely',
#   'no',
#   'now',
#   'a',
#   'no',
#   'funny',
#   'no',
#   'as',
#   'no',
#   '.',
#   'extremely',
#   'they',
#   'therefore',
#   'also',
#   'vitally',
#   'true',
#   'not',
#   'not',
#   "n't",
#   'located',
#   '`',
#   'conceivable',
#   ')',
#   'our',
#   ',',
#   'the',
#   'listed',
#   'difficult',
#   'responsible',
#   'still',
#   'clear',
#   'possible',
#   'analytic',
#   'an',
#   'permitted',
#   'precisely',
#   'the',
#   'almost',
#   'obvious',
#   'low',
#   'than',
#   'a',
#   'most',
#   'not',
#   'also',
#   'hard',
#   'hard',
#   'made',
#   'no',
#   'danced',
#   'to',
#   'a',
#   'not',
#   'so',
#   'in',
#   'obvious',
#   'to',
#   'becoming',
#   'as',
#   'known',
#   'the',
#   'significant',
#   'a',
#   'roughly',
#   'a',
#   'actually',
#   'through',
#   'also',
#   'relatively',
#   'equally',
#   'the',
#   'sowbelly',
#   'one',
#   'not',
#   'not',
#   'a',
#   'a',
#   'no',
#   'borne',
#   'kept',
#   'equipped',
#   'up',
#   'safe',
#   'the',
#   'in',
#   'notorious',
#   'valid',
#   'a',
#   'much',
#   'the',
#   'also',
#   'a',
#   'not',
#   'that',
#   'they',
#   'our',
#   'the',
#   'interesting',
#   'a',
#   'something',
#   'she',
#   'he',
#   'largely',
#   'not',
#   'not',
#   'one',
#   'thin',
#   'not',
#   'a',
#   'one',
#   'that',
#   'likely',
#   'in',
#   'easily',
#   'the',
#   'a',
#   'almost',
#   'that',
#   'not',
#   'said',
#   'quite',
#   'always',
#   'a',
#   'only',
#   'safe',
#   'not',
#   'possible',
#   'plain',
#   'not',
#   'still',
#   'written',
#   '`',
#   'proposed',
#   'sufficient',
#   'planned',
#   'with',
#   'often',
#   'not',
#   'commonplace',
#   'high',
#   'obviously',
#   'clear',
#   'an',
#   'a',
#   'for',
#   'said',
#   'the',
#   'thus',
#   '`',
#   'then',
#   'not',
#   'primarily',
#   'alive',
#   'not',
#   'the',
#   'fantastic',
#   'tradition',
#   'a',
#   'different',
#   'a',
#   'but',
#   'equipped',
#   'already',
#   'seldom',
#   'the',
#   'the',
#   'for',
#   'ironic',
#   'to',
#   'done',
#   'called',
#   'a',
#   'obvious',
#   'spring',
#   'modern',
#   'assumed',
#   'for',
#   'well',
#   'an',
#   'by',
#   'scheduled',
#   'increasingly',
#   'an',
#   'a',
#   'plain',
#   'a',
#   'the',
#   'characterized',
#   'not',
#   'or',
#   'one',
#   'so',
#   'this',
#   'apparently',
#   'not',
#   'a',
#   ',',
#   'possible',
#   'clearly',
#   'better',
#   'impossible',
#   'generally',
#   'only',
#   'nilpotent',
#   'blind',
#   'to',
#   'rotating',
#   'a',
#   'not',
#   'not',
#   'screaming',
#   'not',
#   'a',
#   'usually',
#   'a',
#   'six',
#   'necessary',
#   'a',
#   'a',
#   'translated',
#   'necessary',
#   'this',
#   'the',
#   'meticulously',
#   'true',
#   'not',
#   '`',
#   'the',
#   'all',
#   'in',
#   'rich',
#   'very',
#   'decided',
#   'not',
#   'incandescent',
#   '`',
#   'in',
#   'conceivable',
#   'not',
#   'more',
#   'true',
#   'unexpected',
#   'necessary',
#   'not',
#   'false',
#   'presumed',
#   'essential',
#   'hardly',
#   'a',
#   'drastically',
#   'important',
#   'important',
#   "n't",
#   'the',
#   'added',
#   'just',
#   'by',
#   'not',
#   'hardly',
#   'referred',
#   'this',
#   'being',
#   'hardly',
#   'not',
#   'he',
#   'marked',
#   'impossible',
#   'the',
#   'owned',
#   'essential',
#   'possible',
#   'hard',
#   'their',
#   'at',
#   'not',
#   'not',
#   'a',
#   'always',
#   'recommended',
#   'allowed',
#   'sometimes',
#   'only',
#   'interesting',
#   'another',
#   'aligned',
#   'unnecessary',
#   'estimated',
#   'worth',
#   'offering',
#   'definitely',
#   'lived',
#   'different',
#   'desired',
#   'possible',
#   'an',
#   'estimated',
#   'rooted',
#   'doubtful',
#   'not',
#   'easy',
#   'therefore',
#   'field',
#   'derived',
#   ',',
#   'evinced',
#   'as',
#   'also',
#   'clear',
#   'recommended',
#   'to',
#   "n't",
#   'not',
#   'going',
#   '.',
#   'no',
#   'the',
#   'evident',
#   'occupied',
#   'plain',
#   'sex',
#   '`',
#   'not',
#   'certainly',
#   'also',
#   'there',
#   'appropriate',
#   'something',
#   'a',
#   'easy',
#   'important',
#   'a',
#   'considered',
#   'pale',
#   'not',
#   'time',
#   'possible',
#   'somber',
#   'also',
#   'not',
#   'difficult',
#   'largely',
#   'mentioned',
#   'convenient',
#   'a',
#   'my',
#   'also',
#   'slow',
#   'forever',
#   'surely',
#   'said',
#   'conceivable',
#   'understood',
#   'natural',
#   'arbitrary',
#   'a',
#   'time',
#   'often',
#   'found',
#   'only',
#   'also',
#   'a',
#   'one',
#   'hard',
#   'awfully',
#   'to',
#   'able',
#   'essentially',
#   'this',
#   'his',
#   'not',
#   'interesting',
#   'a',
#   'an',
#   'good',
#   'more',
#   'subtle',
#   'better',
#   'unworthy',
#   'the',
#   'doubtful',
#   ',',
#   'so',
#   'the',
#   'quite',
#   'needed',
#   'in',
#   'expected',
#   'not',
#   'in',
#   'love',
#   ',',
#   'only',
#   'only',
#   'the',
#   'simply',
#   'important',
#   'because',
#   'presently',
#   'a',
#   'best',
#   'possible',
#   'true',
#   'a',
#   'there',
#   'to',
#   'mirrored',
#   'unfortunate',
#   'not',
#   'to',
#   'different',
#   'difficult',
#   'they',
#   'clear',
#   'to',
#   'because',
#   'to',
#   'the',
#   'a',
#   'not',
#   'high',
#   'the',
#   'that',
#   'used',
#   'postulated',
#   'a',
#   'the',
#   'precisely',
#   'a',
#   'outside',
#   'reasonably',
#   'unimportant',
#   "''",
#   'up',
#   'not',
#   'left',
#   'refused',
#   'always',
#   'unlocked',
#   'because',
#   'interesting',
#   'as',
#   'conceived',
#   'more',
#   'a',
#   'endless',
#   'notable',
#   'proposed',
#   'still',
#   'the',
#   'the',
#   'difficult',
#   'for',
#   'for',
#   'too',
#   'still',
#   'in',
#   'a',
#   'this',
#   'these',
#   'the',
#   'hard',
#   'becoming',
#   'lost',
#   'asking',
#   'not',
#   'being',
#   'no',
#   'not',
#   'to',
#   'impossible',
#   'important',
#   'the',
#   'permitted',
#   'designated',
#   'the',
#   'a',
#   'their',
#   'typical',
#   'as',
#   'only',
#   'as',
#   'organically',
#   'a',
#   'also',
#   'a',
#   'loyal',
#   'obvious',
#   'a',
#   'shown',
#   'also',
#   ',',
#   'the',
#   'to',
#   'no',
#   'because',
#   'possible',
#   'really',
#   'but',
#   'argued',
#   'pertinent',
#   "n't",
#   'not',
#   'not',
#   'perhaps',
#   'evident',
#   'time',
#   'involved',
#   'correct',
#   'uncertain',
#   'public',
#   'easier',
#   'this',
#   'smoother',
#   'world',
#   'true',
#   'described',
#   'probably',
#   'a',
#   'not',
#   'generally',
#   'now',
#   'accentuated',
#   'a',
#   'the',
#   'politically',
#   'vital',
#   'not',
#   'the',
#   'clear',
#   'not',
#   'not',
#   'worth',
#   'a',
#   'absolutely',
#   'a',
#   'neither',
#   'to',
#   'not',
#   'only',
#   'the',
#   'not',
#   'a',
#   'particularly',
#   'single',
#   'a',
#   'all',
#   'all',
#   'in',
#   'as',
#   'not',
#   'small',
#   ',',
#   'something',
#   'not',
#   'at',
#   'a',
#   'the',
#   'a',
#   'important',
#   'being',
#   'only',
#   'not',
#   'released',
#   'quite',
#   'your',
#   'thick',
#   'not',
#   'a',
#   'no',
#   'the',
#   'a',
#   'a',
#   'good',
#   'finally',
#   'a',
#   'not',
#   'the',
#   'only',
#   'obviously',
#   'unfair',
#   'not',
#   'they',
#   'thought',
#   'never',
#   'a',
#   'certainty',
#   'not',
#   'clear',
#   ',',
#   'wanted',
#   'maintained',
#   'often',
#   'visible',
#   'not',
#   'equipped',
#   'good',
#   'possible',
#   'idle',
#   'likely',
#   'probable',
#   'the',
#   'this',
#   'she',
#   'harder',
#   'well',
#   'a',
#   'not',
#   'by',
#   'salt',
#   'far',
#   'testimony',
#   'mars',
#   'the',
#   'their',
#   'of',
#   'fellowship',
#   "''",
#   'possible',
#   'connected',
#   'equipped',
#   'relatively',
#   'primarily',
#   'a',
#   'certainly',
#   'wise',
#   'necessary',
#   'a',
#   'true',
#   'determined',
#   'to',
#   'a',
#   'fitting',
#   'more',
#   'well',
#   'probably',
#   'directed',
#   'difficult',
#   'based',
#   'distinctly',
#   'because',
#   'not',
#   'a',
#   'to',
#   'more',
#   'a',
#   'a',
#   'possible',
#   'true',
#   'not',
#   'combined',
#   'almost',
#   'to',
#   'this',
#   'not',
#   "''",
#   'also',
#   'now',
#   'an',
#   'a',
#   'spiritually',
#   'not',
#   'not',
#   'notably',
#   'the',
#   'an',
#   'difficult',
#   'through',
#   'very',
#   'a',
#   'idle',
#   'they',
#   'indifferent',
#   "n't",
#   'inherent',
#   'possible',
#   'only',
#   'justified',
#   'not',
#   'not',
#   'a',
#   'believed',
#   'agreed',
#   'completely',
#   'a',
#   'obvious',
#   'recognized',
#   'not',
#   'time',
#   'not',
#   'merely',
#   'clear',
#   'the',
#   'believed',
#   'for',
#   "n't",
#   'a',
#   'aligned',
#   'too',
#   'not',
#   'a',
#   'the',
#   'repeated',
#   'logical',
#   'this',
#   'well',
#   'also',
#   'with',
#   'a',
#   'dull',
#   'typical',
#   'discouraged',
#   'possible',
#   'understood',
#   'helping',
#   'hydrolyzed',
#   'that',
#   'clear',
#   'noteworthy',
#   ',',
#   'veiled',
#   'still',
#   'sufficiently',
#   'also',
#   'not',
#   'still',
#   '`',
#   '.',
#   'in',
#   'much',
#   'impossible',
#   'now',
#   'the',
#   'this',
#   'felt',
#   'only',
#   'likely',
#   'true',
#   'midweek',
#   'intensive',
#   'not',
#   'important',
#   'brought',
#   ...],
#  ('is', 'suggested'): ['that', 'by', 'optically', 'by', 'by', 'by', 'that'],
#  ('suggested', 'that'): ['in',
#   'the',
#   'you',
#   'it',
#   'without',
#   'the',
#   'they',
#   'one',
#   'she',
#   'sarah',
#   'they',
#   'the',
#   'the',
#   'the',
#   'a',
#   'an',
#   'palfrey',
#   'he',
#   'the',
#   'the',
#   'you',
#   'alterations',
#   'our',
#   'they',
#   'a',
#   '`',
#   'the',
#   "o'banion",
#   'licensed',
#   'the'],
#  ('that', 'in'): ['many',
#   'seeking',
#   'heavily',
#   'this',
#   'the',
#   'spite',
#   'most',
#   'the',
#   'a',
#   'such',
#   'many',
#   'the',
#   'your',
#   'order',
#   'the',
#   'philadelphia',
#   'the',
#   'both',
#   'great',
#   'the',
#   'a',
#   'the',
#   'a',
#   'some',
#   'new',
#   'a',
#   'all',
#   'the',
#   'california',
#   'itself',
#   'case',
#   'the',
#   'supporting',
#   'af',
#   'valid',
#   'a',
#   'actual',
#   'crisis',
#   'a',
#   'such',
#   'most',
#   'a',
#   'rhode',
#   'saying',
#   'mooring',
#   'turning',
#   'an',
#   'all',
#   'taoist',
#   'his',
#   'employing',
#   'portraying',
#   'a',
#   'the',
#   'the',
#   'the',
#   'supervising',
#   'these',
#   'times',
#   'prince',
#   'a',
#   'march',
#   'the',
#   'some',
#   'the',
#   'a',
#   'making',
#   'america',
#   'the',
#   're',
#   'the',
#   'war',
#   'civilian',
#   'the',
#   'the',
#   '`',
#   'the',
#   'an',
#   'a',
#   'the',
#   'these',
#   'some',
#   'achieving',
#   'saying',
#   'the',
#   'many',
#   'the',
#   'this',
#   'every',
#   'many',
#   'the',
#   'several',
#   'this',
#   'failing',
#   'sex',
#   'the',
#   'this',
#   'many',
#   'politics',
#   'the',
#   'a',
#   'september',
#   'fiction',
#   'the',
#   'mind',
#   'dealing',
#   'this',
#   'every',
#   'man',
#   'most',
#   'general',
#   'the',
#   '1963',
#   'a',
#   'a',
#   'this',
#   'fact',
#   'the',
#   'every',
#   '10',
#   'the',
#   'the',
#   'the',
#   'this',
#   'that',
#   'the',
#   'a',
#   'the'],
#  ('in', 'many'): ['respects',
#   'cases',
#   'lines',
#   'installations',
#   'of',
#   'situations',
#   'parts',
#   'slum',
#   'churches',
#   'ways',
#   'passages',
#   'other',
#   'of',
#   'ways',
#   'areas',
#   'parts',
#   'ways',
#   'of',
#   'of',
#   'counties',
#   'ways',
#   'other',
#   'specific',
#   'cases',
#   'kinds',
#   'of',
#   'other',
#   'areas',
#   'cases',
#   'cases',
#   'elementary',
#   'ways',
#   'years',
#   'cases',
#   'years',
#   'cases',
#   'a',
#   'parts',
#   'ways',
#   'cases',
#   'lines',
#   'northern',
#   'communities',
#   'communities',
#   'cases',
#   'communities',
#   'states',
#   'quarters',
#   'of',
#   'cities',
#   'directions',
#   'societies',
#   'respects',
#   'respects',
#   'cases',
#   'corners',
#   'marriages',
#   'of',
#   'anecdotes',
#   'ways',
#   'areas',
#   'sections',
#   'fields',
#   'instances',
#   'cities',
#   'cases',
#   'cases',
#   'languages',
#   'crucial',
#   'ways',
#   'instances',
#   'cases',
#   'cases',
#   'months',
#   'cases',
#   'localities',
#   'instances',
#   'other',
#   'others',
#   'matters'],
#  ('many', 'respects'): ['the', '.', ';'],
#  ('respects', 'the'): ['horse', 'vases'],
#  ('the', 'horse'): ['lung',
#   'is',
#   'into',
#   "'s",
#   '.',
#   "'s",
#   'walked',
#   '.',
#   'lung',
#   'with',
#   '.',
#   'kick',
#   'world',
#   'reared',
#   ',',
#   'beneath',
#   'plodded',
#   'kick',
#   '-',
#   'was',
#   'shied',
#   'and',
#   'continued',
#   'world',
#   'or',
#   'much',
#   'and',
#   'and',
#   'and',
#   '.',
#   '.',
#   'leaped',
#   'crashed'],
#  ('horse', 'lung'): ['may', 'appears'],
#  ('lung', 'may'): ['be'],
#  ('may', 'be'): ['anatomically',
#   ',',
#   'made',
#   'deposited',
#   'estimated',
#   'thought',
#   'a',
#   'active',
#   'problems',
#   'moral',
#   'increased',
#   'right',
#   'said',
#   'possible',
#   'made',
#   'set',
#   'due',
#   'classified',
#   '.',
#   'added',
#   'some',
#   'tested',
#   'used',
#   'concluded',
#   'started',
#   'imputed',
#   'somewhat',
#   'compared',
#   'produced',
#   'desirable',
#   'an',
#   'very',
#   'provided',
#   'quite',
#   'short',
#   'possible',
#   'facilitated',
#   'a',
#   'on',
#   'used',
#   'of',
#   'in',
#   'written',
#   'full',
#   'very',
#   'quickly',
#   'remote',
#   'invited',
#   'moot',
#   'applied',
#   'left',
#   'corrupted',
#   'understandable',
#   'related',
#   'expressed',
#   'increased',
#   'assumed',
#   'a',
#   'illuminating',
#   'too',
#   'obtained',
#   'present',
#   'said',
#   'measured',
#   'obtained',
#   'called',
#   ',',
#   'had',
#   'derived',
#   'made',
#   'county',
#   'a',
#   'hard',
#   '.',
#   'borrowed',
#   'possible',
#   'advanced',
#   'better',
#   ',',
#   'a',
#   'similar',
#   'sufficient',
#   'addressed',
#   'replaced',
#   'one',
#   'split',
#   'more',
#   'forced',
#   'wisely',
#   'installed',
#   'taken',
#   '--',
#   'mounted',
#   'installed',
#   'resolved',
#   'contained',
#   'extrapolated',
#   'the',
#   'happening',
#   'altered',
#   'noted',
#   'concealed',
#   'highly',
#   'united',
#   ',',
#   'others',
#   'directly',
#   'followed',
#   'in',
#   'no',
#   ',',
#   'certain',
#   'made',
#   'worked',
#   'shown',
#   'readily',
#   'attending',
#   'selected',
#   'some',
#   'necessary',
#   'fostered',
#   'imagined',
#   'superior',
#   'of',
#   'so',
#   'extremely',
#   'spread',
#   'so',
#   'eventually',
#   'a',
#   'used',
#   'so',
#   'cheaper',
#   'perennial',
#   'achieved',
#   'several',
#   'found',
#   'an',
#   'thought',
#   'on',
#   'placed',
#   'so',
#   'so',
#   'by',
#   'moved',
#   'transported',
#   ',',
#   'important',
#   'a',
#   'presented',
#   'any',
#   'saddled',
#   'mutually',
#   'sure',
#   'all',
#   'idealistic',
#   'meted',
#   'opera',
#   'required',
#   'used',
#   'the',
#   'present',
#   'achieved',
#   'wired',
#   'aroused',
#   'realized',
#   'a',
#   'due',
#   'entitled',
#   'wrong',
#   'considerably',
#   'desirable',
#   'secured',
#   'made',
#   'said',
#   'unfair',
#   'more',
#   'here',
#   'a',
#   ',',
#   'well',
#   'referred',
#   'poor',
#   'requested',
#   'said',
#   ',',
#   'either',
#   'that',
#   'a',
#   'subject',
#   'in',
#   'built',
#   'labeled',
#   '?',
#   'pardoned',
#   'acceptable',
#   'strictly',
#   ',',
#   'further',
#   'spared',
#   'received',
#   'set',
#   'baptized',
#   'similarly',
#   'in',
#   'greater',
#   'of',
#   'very',
#   'connected',
#   'a',
#   'the',
#   'other',
#   'provided',
#   'seen',
#   'made',
#   'that',
#   ',',
#   'used',
#   'reserved',
#   'back',
#   'more',
#   'inaccessible',
#   'interested',
#   'analytic',
#   'brought',
#   'reduced',
#   'evaluated',
#   'readily',
#   'conducted',
#   'a',
#   'a',
#   'agreed',
#   'roughly',
#   'concerned',
#   '.',
#   'multiplied',
#   'able',
#   'effected',
#   'prevented',
#   'head',
#   'claimed',
#   'too',
#   'called',
#   'a',
#   'politically',
#   'one',
#   'found',
#   'helpful',
#   'moved',
#   'meaningful',
#   'said',
#   'forthcoming',
#   'assumed',
#   'representative',
#   'adjusted',
#   'marked',
#   ',',
#   'distinguished',
#   'a',
#   'incorporated',
#   'a',
#   'set',
#   'effected',
#   'cold',
#   'specified',
#   'produced',
#   'permitted',
#   ';',
#   'small',
#   '.',
#   'to',
#   'conjectured',
#   'drawn',
#   'distant',
#   'raised',
#   'produced',
#   'a',
#   'broken',
#   'necessary',
#   'found',
#   'named',
#   'predicted',
#   'a',
#   'caused',
#   'in',
#   'an',
#   'good',
#   ',',
#   ',',
#   'that',
#   'identified',
#   'explored',
#   'secured',
#   'described',
#   'enclosed',
#   'referring',
#   'gently',
#   'unaware',
#   'desirable',
#   'too',
#   'realism',
#   'a',
#   'gradually',
#   'slightly',
#   'transferred',
#   'stated',
# ...
#   'concluded',
#   'was',
#   'would',
#   'stood',
#   'had',
#   'could',
#   "'s",
#   'sat',
#   'calmly',
#   'said',
#   'could',
#   'would',
#   'drew',
#   "'s",
#   'wrote',
#   'had',
#   'had',
#   'got',
#   'quickly',
#   'had',
#   'read',
#   'clung',
#   'told',
#   'has',
#   'might',
#   'also',
#   'wanted',
#   'described',
#   'had',
#   'regretted',
#   'said',
#   'will',
#   'is',
#   'saw',
#   'took',
#   'mumbled',
#   'said',
#   'had',
#   'was',
#   "'d",
#   'was',
#   'studied',
#   'hastily',
#   'had',
#   'would',
#   'had',
#   'accused',
#   "'ll",
#   'fell',
#   'seemed',
#   'said',
#   'said',
#   'could',
#   'cackled',
#   'glanced',
#   'did',
#   'stood',
#   'was',
#   'said',
#   'lay',
#   'disciplined',
#   'did',
#   'thought',
#   'had',
#   'wailed',
#   'opened',
#   'had',
#   'was',
#   'arrived',
#   'indicated',
#   "'d",
#   'played',
#   'went',
#   'exclaimed',
#   'finished',
#   'jerked',
#   'was',
#   'rubbed',
#   'shook',
#   'wanted',
#   'passed',
#   'asked',
#   'regarded',
#   'developed',
#   'noted',
#   'was',
#   'tilted',
#   'had',
#   'had',
#   'got',
#   'glinted',
#   'was',
#   'stared',
#   'wanted',
#   'wants',
#   'said',
#   'sat',
#   'may',
#   "'s",
#   'would',
#   'was',
#   'had',
#   'had',
#   'found',
#   'ate',
#   'drank',
#   'was',
#   'had',
#   "'d",
#   'certainly',
#   'said',
#   'closed',
#   'felt',
#   'put',
#   'dressed',
#   'called',
#   'looked',
#   'could',
#   'stood',
#   'had',
#   'remained',
#   'answered',
#   'might',
#   'had',
#   ':',
#   'died',
#   'came',
#   'frowned',
#   'remembered',
#   'unquestionably',
#   'did',
#   'sighed',
#   'was',
#   'said',
#   'would',
#   'was',
#   'is',
#   'is',
#   'went',
#   'come',
#   'was',
#   'has',
#   'reached',
#   'locked',
#   'apparently',
#   'hoped',
#   'was',
#   'smiled',
#   'hesitated',
#   'was',
#   'soared',
#   'wrote',
#   'is',
#   'could',
#   'seemed',
#   'said',
#   'sees',
#   'could',
#   'doled',
#   'started',
#   'would',
#   'had',
#   'was',
#   'must',
#   'then',
#   'concluded',
#   'was',
#   'may',
#   'was',
#   'knew',
#   'would',
#   'snarled',
#   'dreamed',
#   'never',
#   'was',
#   'raised',
#   "'d",
#   'kicked',
#   'had',
#   'it',
#   'did',
#   'approached',
#   'compared',
#   'was',
#   'stayed',
#   'pulled',
#   'says',
#   'thought',
#   'asked',
#   'had',
#   'giggled',
#   'continues',
#   'stopped',
#   '`',
#   'had',
#   'scoffed',
#   'musta',
#   'lay',
#   'was',
#   'was',
#   'knew',
#   'eyed',
#   'is',
#   'asked',
#   'looked',
#   'began',
#   'has',
#   'started',
#   'had',
#   'said',
#   'began',
#   'was',
#   'would',
#   'was',
#   'was',
#   'hopes',
#   'charged',
#   'was',
#   'directed',
#   'felt',
#   'stood',
#   'pursed',
#   'charged',
#   'had',
#   'smiled',
#   'was',
#   'had',
#   'must',
#   'replied',
#   'would',
#   'refolded',
#   'wore',
#   'paused',
#   'always',
#   'stood',
#   'urged',
#   'wrote',
#   'tore',
#   'felt',
#   'placed',
#   'had',
#   'had',
#   'says',
#   'was',
#   'fits',
#   'was',
#   'could',
#   'was',
#   'thrust',
#   'radiated',
#   'had',
#   'opened',
#   'looked',
#   'scrutinized',
#   'smiled',
#   'worked',
#   'was',
#   'was',
#   'asked',
#   'asked',
#   'would',
#   'showed',
#   'had',
#   'asked',
#   'had',
#   'says',
#   "'d",
#   'leaned',
#   'was',
#   'finally',
#   'dropped',
#   'promised',
#   'puffed',
#   'was',
#   'yelped',
#   'was',
#   'had',
#   'had',
#   'said',
#   'set',
#   'wore',
#   'had',
#   'smiled',
#   'enjoyed',
#   'helped',
#   'was',
#   'wore',
#   "'s",
#   'was',
#   'gave',
#   'did',
#   'smiled',
#   'persisted',
#   'had',
#   'would',
#   'managed',
#   'did',
#   'asked',
#   'was',
#   'carried',
#   'replied',
#   'was',
#   'read',
#   "'d",
#   'had',
#   'asked',
#   'had',
#   "'ll",
#   'also',
#   'was',
#   'understood',
#   'was',
#   'was',
#   "'s",
#   'also',
#   'looked',
#   'brought',
#   'said',
#   'held',
#   'lost',
#   'showed',
#   "'d",
#   'served',
#   'was',
#   'smiled',
#   'raised',
#   'walked',
#   'went',
#   'had',
#   'would',
#   'named',
#   'then',
#   'thinks',
#   'loved',
#   'is',
#   'had',
#   'filled',
#   'did',
#   "'d",
#   'continued',
#   'was',
#   'twitched',
#   'started',
#   'was',
#   'was',
#   "'d",
#   'wondered',
#   'admired',
#   'was',
#   'would',
#   'greeted',
#   'made',
#   'was',
#   'stumbled',
#   'said',
#   'glanced',
#   'is',
#   'was',
#   'laughed',
#   'can',
#   'had',
#   'had',
#   'said',
#   'saw',
#   'was',
#   'thought',
#   'suspected',
#   'added',
#   'also',
#   'began',
#   'is',
#   'tried',
#   'would',
#   'was',
#   'had',
#   'had',
#   'looked',
#   'was',
#   'used',
#   'was',
#   'ate',
#   'crouched',
#   'was',
#   'had',
#   'was',
#   'stayed',
#   'is',
#   'put',
#   'said',
#   'was',
#   'glanced',
#   'filled',
#   'took',
#   'had',
#   'sounded',
#   'did',
#   'blew',
#   'looked',
#   'came',
#   'too',
#   'came',
#   'went',
#   'would',
#   'smelled',
#   'had',
#   'was',
#   'looked',
#   'opened',
#   'did',
#   'asked',
#   'quickly',
#   'sent',
#   'did',
#   'was',
#   'was',
#   'had',
#   'told',
#   'made',
#   'served',
#   'said',
#   'was',
#   'asked',
#   'tried',
#   'asked',
#   'cut',
#   'had',
#   'did',
#   'spouted',
#   "'s",
#   'came',
#   'snapped',
#   'refused',
#   'was',
#   'stood',
#   'did',
#   "'d",
#   'is',
#   'had',
#   'thought',
#   'was',
#   'said',
#   'made',
#   'turned',
#   'took',
#   'gave',
#   'said',
#   'set',
#   'said',
#   'had',
#   'wished',
#   'looked',
#   'could',
#   'shrugged',
#   'studied',
#   'did',
#   'wanted',
#   'looked',
#   'meant',
#   "'s",
#   'had',
#   'was',
#   'turned',
#   'goes',
#   'might',
#   'knew',
#   'did',
#   'softly',
#   'lied',
#   'grasped',
#   'had',
#   'designed',
#   'always',
#   'was',
#   'would',
#   'made',
#   'was',
#   'felt',
#   'shook',
#   'remarked',
#   "'s",
#   'was',
#   'felt',
#   'sounded',
#   'discussed',
#   'instinctively',
#   'topped',
#   'sounded',
#   'appeared',
#   'knows',
#   'smiled',
#   'entreated',
#   'had',
#   'helped',
#   'stood',
#   'asked',
#   "'d",
#   'said',
#   'had',
#   'would',
#   "'s",
#   'is',
#   'had',
#   'was',
#   'looked',
#   'remained',
#   'paused',
#   'found',
#   'threw',
#   'passed',
#   'retreated',
#   'was',
#   'understood',
#   'was',
#   'was',
#   'jumped',
#   'suffered',
#   'was',
#   'signed',
#   'is',
#   'did',
#   'stood',
#   'cast',
#   'was',
#   'later',
#   'was',
#   'learns',
#   'confessed',
#   'said',
#   'is',
#   'put',
#   'likes',
#   'told',
#   'was',
#   'would',
#   'shook',
#   'once',
#   'got',
#   'pushed',
#   'asked',
#   'developed',
#   'called',
#   'had',
#   'knelt',
#   'instinctively',
#   'was',
#   'had',
#   'loosened',
#   'had',
#   'started',
#   'was',
#   'asked',
#   'kissed',
#   'told',
#   'looked',
#   'realized',
#   'had',
#   'lived',
#   'had',
#   'had',
#   'snapped',
#   'can',
#   'haunted',
#   'was',
#   'had',
#   'finds',
#   'would',
#   'had',
#   'felt',
#   'made',
#   'was',
#   'was',
#   'had',
#   'traced',
#   'has',
#   'found',
#   'asked',
#   'wore',
#   'had',
#   'no',
#   'called',
#   'was',
#   'must',
#   'always',
#   'would',
#   'was',
#   'knew',
#   'would',
#   'has',
#   'picked',
#   'wondered',
#   'was',
#   'felt',
#   'escaped',
#   'describes',
#   'might',
#   'said',
#   'screamed',
#   'lay',
#   'was',
#   'was',
#   'seemed',
#   'turned',
#   'bellowed',
#   'was',
#   'was',
#   'wanted',
#   'would',
#   'jumped',
#   'was',
#   'could',
#   'was',
#   'had',
#   'was',
#   'had',
#   'looked',
#   'let',
#   "'d",
#   'would',
#   'would',
#   'was',
#   'had',
#   'slapped',
#   "'s",
#   'was',
#   'was',
#   'might',
#   'held',
#   'came',
#   'had',
#   'asked',
#   'went',
#   'just',
#   'repeated',
#   'lived',
#   'seemed',
#   'had',
#   'hesitated',
#   'begged',
#   'looked',
#   'dashes',
#   'smiled',
#   'just',
#   'began',
#   'looked',
#   'smiled',
#   'already',
#   'was',
#   'is',
#   'now',
#   'went',
#   'was',
#   'looked',
#   'was',
#   'said',
#   'explained',
#   'asked',
#   'always',
#   "'ll",
#   'had',
#   'never',
#   'is',
#   'will',
#   'would',
#   'sought',
#   'envied',
#   'had',
#   'was',
#   'found',
#   'has',
#   'was',
#   'was',
#   'thought',
#   'had',
#   'had',
#   'was',
#   'had',
#   'swung',
#   'sat',
#   'has',
#   'held',
#   'had',
#   'swung',
#   'was',
#   "'ll",
#   'lived',
#   'was',
#   'would',
#   'did',
#   'was',
#   'remembered',
#   'did',
#   'stammered',
#   'was',
#   'had',
#   'stared',
#   'did',
#   'also',
#   'smiled',
#   'usually',
#   'is',
#   'relaxed',
#   'had',
#   'could',
#   'asked',
#   'let',
#   'and',
#   'sprang',
#   'snapped',
#   'must',
#   'did',
#   'is',
#   'must',
#   'was',
#   'felt',
#   'lost',
#   'gave',
#   'also',
#   'ascribed',
#   'was',
#   'was',
#   'had',
#   'cherished',
#   'remembered',
#   'asked',
#   'ran',
#   'clearly',
#   'was',
#   'became',
#   'spoke',
#   'was',
#   'sidled',
#   'could',
#   'said',
#   'picked',
#   'was',
#   'yanked',
#   'described',
#   'had',
#   "'d",
#   'met',
#   'did',
#   'was',
#   'never',
#   'wished',
#   'grabbed',
#   'was',
#   'said',
#   'kept',
#   'asked',
#   'asked',
#   'decided',
#   'came',
#   'was',
#   "'s",
#   'was',
#   'said',
#   'whirled',
#   'daubed',
#   'opened',
#   'can',
#   'stood',
#   'looked',
#   'was',
#   'said',
#   'had',
#   'was',
#   'reached',
#   'smiled',
#   'could',
#   'walked',
#   'got',
#   'was',
#   'had',
#   "musn't",
#   'had',
#   'swung',
#   'said',
#   ',',
#   'had',
#   'could',
#   'tells',
#   'chose',
#   'took',
#   'served',
#   'had',
#   'found',
#   'seemed',
#   'arranged',
#   'wrote',
#   'did',
#   'turned',
#   'smiled',
#   'has',
#   'even',
#   'was',
#   'convinced',
#   'teamed',
#   "'s",
#   'smiled',
#   'drank',
#   'ended',
#   'was',
#   'was',
#   'retreated',
#   'stopped',
#   'wiped',
#   'set',
#   'asked',
#   'breathed',
#   'turned',
#   'thrust',
#   'measured',
#   'possessed',
#   'thought',
#   'was',
#   'took',
#   'asked',
#   'frosted',
#   'was',
#   'will',
#   'left',
#   'said',
#   'never',
#   'worked',
#   'was',
#   'smoothed',
#   'looked',
#   'said',
#   'was',
#   'sprinkled',
#   'seemed',
#   'exclaimed',
#   'studied',
#   'said',
#   'wanted',
#   'added',
#   'had',
#   'was',
#   'inquired',
#   'smiled',
#   'brought',
#   'said',
#   'was',
#   'was',
#   'smiled',
#   'let',
#   'wondered',
#   'had',
#   'liked',
#   'gave',
#   'is',
#   'sat',
#   'was',
#   'began',
#   'telephoned',
#   'sang',
#   'had',
#   'was',
#   'had',
#   'was',
#   'had',
#   'was',
#   'was',
#   'had',
#   'loved',
#   'knew',
#   'kept',
#   'thought',
#   'patronized',
#   ',',
#   'has',
#   'did',
#   'had',
#   'was',
#   'had',
#   'turned',
#   'overplayed',
#   'could',
#   'trudged',
#   'was',
#   'had',
#   'munched',
#   'had',
#   'wore',
#   'showed',
#   'could',
#   'finally',
#   'was',
#   'might',
#   'said',
#   'went',
#   "'s",
#   'did',
#   'frowned',
#   'must',
#   'wanted',
#   "'s",
#   'could',
#   'had',
#   'gave',
#   'lived',
#   'was',
#   'stood',
#   'lives',
#   'thought'],
#  ('she', 'seemed'): ['irritated',
#   'to',
#   'to',
#   'for',
#   'to',
#   'to',
#   'to',
#   'as',
#   'so',
#   'to',
#   'overly',
#   'just',
#   'so',
#   'to'],
#  ('seemed', 'irritated'): ['.'],
#  ('irritated', '.'): ['</s>', '</s>'],
#  ('<s>', 'coping'): ['with'],
#  ('coping', 'with'): ['them', 'tone', 'the', 'the', 'such', 'this'],
#  ('with', 'them'): ['demands',
#   'for',
#   'in',
#   'for',
#   "''",
#   ',',
#   '.',
#   '.',
#   'more',
#   '.',
#   'through',
#   '.',
#   'and',
#   ',',
#   '.',
#   '.',
#   'on',
#   'a',
#   '.',
#   '.',
#   'and',
#   ',',
#   'and',
#   '.',
#   '.',
#   ',',
#   "''",
#   "''",
#   'that',
#   'this',
#   ',',
#   '--',
#   "''",
#   '.',
#   '.',
#   ',',
#   "''",
#   '.',
#   '.',
#   'also',
#   '.',
#   'that',
#   '.',
#   ',',
#   'was',
#   '.',
#   'in',
#   ',',
#   ';',
#   '.',
#   'they',
#   'that',
#   '.',
#   "''",
#   '.',
#   '.',
#   'he',
#   'to',
#   "''",
#   'the',
#   ',',
#   '--',
#   ','],
#  ('them', 'demands'): ['stern'],
#  ('demands', 'stern'): ['discipline'],
#  ('stern', 'discipline'): ['--'],
#  ('discipline', '--'): ['of'],
#  ('--', 'of'): ['yourself',
#   'a',
#   'the',
#   'composing',
#   'american',
#   'a',
#   'the',
#   'man',
#   'his',
#   'new',
#   'communist',
#   'atmosphere',
#   'course',
#   'influence'],
#  ('of', 'yourself'): ['as', 'for', '.', '.', 'then', '.', ',', 'as'],
#  ('yourself', 'as'): ['well', 'grown', 'a', 'an'],
#  ('as', 'well'): ['as',
#   'as',
#   'as',
#   'wait',
#   'as',
#   'as',
#   'lift',
#   'as',
#   'enjoy',
#   'as',
#   '.',
#   'as',
#   'as',
#   'stand',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   ',',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'unpack',
#   '.',
#   'as',
#   '.',
#   'as',
#   ',',
#   'as',
#   'as',
#   'as',
#   '(',
#   'as',
#   'as',
#   'pick',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'with',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   "''",
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'informed',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   ':',
#   'as',
#   'as',
#   'as',
#   ',',
#   ',',
#   'as',
#   ',',
#   "''",
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   ',',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'was',
#   'was',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   ',',
#   '.',
#   '--',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   '.',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'along',
#   'as',
#   'as',
#   ',',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   ',',
#   ',',
#   'as',
#   'as',
#   'that',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   ':',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'paid',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'for',
#   'in',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   '.',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   ',',
#   'as',
#   'as',
#   'or',
#   '.',
#   ',',
#   'as',
#   'as',
#   "'s",
#   'stop',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'for',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'make',
#   'as',
#   'as',
#   'as',
#   'as',
#   'pen',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as',
#   '.',
#   'as',
#   'as',
#   'as',
#   'that',
#   'as',
#   'as',
#   'as',
#   'as',
#   'as'],
#  ('well', 'as'): ['of',
#   'her',
#   'theoretical',
#   'bound',
#   'the',
#   'providing',
#   'through',
#   'the',
#   'of',
#   'happy',
#   'to',
#   'a',
#   'by',
#   'fractionation',
#   'the',
#   'the',
#   'the',
#   'the',
#   'other',
#   'nuclear',
#   'injuries',
#   'new',
#   'aggressive',
#   'the',
#   'modern',
#   'his',
#   'recurrence',
#   'her',
#   'love',
#   'the',
#   'golden',
#   'the',
#   'thinking',
#   'that',
#   'with',
#   'personalities',
#   'the',
#   'slum',
#   'life',
#   'other',
#   'industrial',
#   'representatives',
#   'by',
#   'by',
#   'the',
#   'the',
#   'other',
#   'fever',
#   'government',
#   'the',
#   'east',
#   'other',
#   'to',
#   'on',
#   'a',
#   'anyone',
#   'grades',
#   'in',
#   'many',
#   'set',
#   'a',
#   'wit',
#   'necessary',
#   'democratic',
#   'an',
#   'the',
#   'a',
#   'the',
#   'our',
#   'importance',
#   'the',
#   'the',
#   'an',
#   'in',
#   'vertically',
#   'small',
#   'in',
#   'office',
#   'danger',
#   'for',
#   'pleasin',
#   'to',
#   'a',
#   'upon',
#   'they',
#   'on',
#   'enthusiasm',
#   'a',
#   'the',
#   'a',
#   'non',
#   'varying',
#   'in',
#   'the',
#   'the',
#   'possible',
#   'the',
#   'office',
#   'start',
#   'soap',
#   'the',
#   'nailed',
#   'new',
#   'moral',
#   'residents',
#   'the',
#   'of',
#   'ethical',
#   'songs',
#   'information',
#   'at',
#   'work',
#   'certain',
#   'the',
#   'aid',
#   'a',
#   'the',
#   'wit',
#   'he',
#   'hand',
#   'blends',
#   'some',
#   'the',
#   'economic',
#   'motor',
#   'the',
#   'to',
#   'my',
#   'to',
#   'sharply',
#   'soap',
#   'extraterrestrial',
#   'the',
#   'their',
#   'form',
#   'a',
#   'any',
#   'tom',
#   'model',
#   'the',
#   'the',
#   'an',
#   'upon',
#   'ballads',
#   'the',
#   'other',
#   'commission',
#   'the',
#   'providing',
#   'in',
#   'his',
#   'a',
#   'about',
#   'those',
#   'in',
#   'the',
#   'his',
#   'loveliness',
#   'a',
#   'words',
#   'friends',
#   'the',
#   'subsoil',
#   'during',
#   'ease',
#   'those',
#   'trying',
#   'the',
#   'west',
#   'upon',
#   'their',
#   'anti',
#   'in',
#   'the',
#   'expressed',
#   'upon',
#   'she',
#   'summer',
#   'all',
#   'the',
#   'engineering',
#   'do',
#   'concerts',
#   'aesthetic',
#   'special',
#   'the',
#   'to',
#   'mental',
#   'for',
#   'its',
#   'an',
#   'imagination',
#   'those',
#   'impressionism',
#   'underprivileged',
#   'to',
#   'a',
#   'the',
#   'forecasting',
#   'mentally',
#   'regarding',
#   'for',
#   'many',
#   'mind',
#   'the',
#   'economic',
#   'tie',
#   'their',
#   'a',
#   'the',
#   'by',
#   'rifleman',
#   'relative',
#   'dereliction',
#   'the',
#   'in',
#   'political',
#   'the',
#   'in',
#   'a',
#   'an',
#   'behind',
#   'the',
#   'some',
#   'office',
#   'overt',
#   'for',
#   'the',
#   'the',
#   'the',
#   'to',
#   'reason',
#   'opportunities',
#   'in',
#   'the',
#   'treasurer',
#   'recognized',
#   'any',
#   'with',
#   'thomas',
#   'ever'],
#  ...}

# %%
# Turn list of tokens into a probability distribution dictionary
def tokens2probs(ws):
    k = len(ws)
    return { w : f/k  for (w,f) in Counter(ws).items() }

# Convert a next-word dictionary from contexts into a PLM = a dictionary
# from left-contexts to a probability distribution of next words

def get_PLM(D):
    return { lcontext : tokens2probs(next_words)  for (lcontext,next_words) in D.items() }


def get_next_word(lcontext,plm):
    next_word_dist = plm[lcontext]
    return random.choices( list(next_word_dist.keys()), weights = list(next_word_dist.values()) )[0]



def get_sentence(plm,N=3):
    sentence = ['<s>', 'the']                        # Sentence is list of tokens
    while sentence[-1] != '</s>':
        lcontext  = tuple(sentence[-(N-1):])       # grab last N-1 tokens; left context must be a tuple
        next_word =  get_next_word(lcontext,plm)
        sentence.append(next_word)
    return sentence

# %%
for i in ['<s>' ,'the']:
  def get_sentence(plm,N=2):
    sentence = [i]                      # Sentence is list of tokens
    while sentence[-1] != '</s>':
        lcontext  = tuple(sentence[-(N-1):])       # grab last N-1 tokens; left context must be a tuple
        next_word =  get_next_word(lcontext,plm)
        sentence.append(next_word)
    return sentence

  brown_bigram = get_PLM( get_next_word_dict( bigrams ) )

# %%
brown_trigram = get_PLM( get_next_word_dict( trigrams ) )
next_word_dist = brown_trigram[('<s>', 'the')]
next_word_dist
# Out:
# {'president': 0.004958436634096544,
#  'genuinely': 0.00014583637159107482,
#  'church': 0.0011666909727285986,
#  'favorite': 0.00029167274318214965,
#  'velvet': 0.00014583637159107482,
#  'belgians': 0.000729181857955374,
#  'most': 0.005979291235234068,
#  'latter': 0.0037917456613679452,
#  'grateful': 0.00014583637159107482,
#  '`': 0.005541782120460843,
#  'terms': 0.000729181857955374,
#  'two': 0.005395945748869768,
#  'bank': 0.00043750911477322444,
#  'tide': 0.00014583637159107482,
#  'shot': 0.00014583637159107482,
#  'maximum': 0.0011666909727285986,
#  'patient': 0.00029167274318214965,
#  'mild': 0.00014583637159107482,
#  'bringing': 0.00014583637159107482,
#  'decoration': 0.00014583637159107482,
#  'marriage': 0.00029167274318214965,
#  'integrity': 0.00014583637159107482,
#  'ferraros': 0.00014583637159107482,
#  'fact': 0.00393758203295902,
#  'expenses': 0.00014583637159107482,
#  'work': 0.002333381945457197,
#  'phone': 0.00029167274318214965,
#  'graphite': 0.00014583637159107482,
#  'owner': 0.00029167274318214965,
#  'approximate': 0.00014583637159107482,
#  'motivations': 0.00014583637159107482,
#  'emergency': 0.00014583637159107482,
#  'article': 0.00043750911477322444,
#  'chancellor': 0.00029167274318214965,
#  'element': 0.00043750911477322444,
#  'colors': 0.00029167274318214965,
#  'second': 0.005687618492051918,
#  'discussion': 0.00043750911477322444,
#  'desert': 0.00014583637159107482,
#  'platform': 0.0008750182295464489,
#  'pro': 0.00014583637159107482,
#  'women': 0.0013125273443196734,
#  'subjects': 0.00029167274318214965,
#  'place': 0.001604200087501823,
#  'young': 0.0018958728306839726,
#  'ball': 0.0005833454863642993,
#  'callous': 0.00014583637159107482,
#  'stanford': 0.00014583637159107482,
#  'one': 0.0013125273443196734,
#  'very': 0.0011666909727285986,
#  'mind': 0.00014583637159107482,
#  'grafin': 0.00014583637159107482,
#  'land': 0.0008750182295464489,
#  'same': 0.0042292547761411696,
#  'eagles': 0.00014583637159107482,
#  'problems': 0.0005833454863642993,
#  'bunk': 0.00014583637159107482,
#  'poodle': 0.00014583637159107482,
#  'kirov': 0.00014583637159107482,
#  'resolution': 0.0008750182295464489,
#  'school': 0.0011666909727285986,
#  'italian': 0.00014583637159107482,
#  'first': 0.013854455301152107,
#  'lieutenant': 0.00043750911477322444,
#  'creative': 0.00014583637159107482,
#  'numerical': 0.00029167274318214965,
#  'girl': 0.003062563803412571,
#  'door': 0.0008750182295464489,
#  'council': 0.000729181857955374,
#  'existing': 0.00029167274318214965,
#  'bod': 0.0008750182295464489,
#  'city': 0.0017500364590928978,
#  'saline': 0.00029167274318214965,
#  'automatic': 0.00014583637159107482,
#  'wizard': 0.00014583637159107482,
#  'appropriate': 0.00014583637159107482,
#  'editorial': 0.0005833454863642993,
#  'lush': 0.00014583637159107482,
#  'initial': 0.000729181857955374,
#  'mayor': 0.0010208546011375237,
#  'teeth': 0.00029167274318214965,
#  'pattern': 0.0005833454863642993,
#  'word': 0.0017500364590928978,
#  'case': 0.00043750911477322444,
#  'final': 0.0020417092022750475,
#  'infant': 0.00029167274318214965,
#  'acceptance': 0.00014583637159107482,
#  'foaming': 0.00014583637159107482,
#  'rehearsal': 0.00014583637159107482,
#  'finding': 0.00014583637159107482,
#  'gun': 0.0005833454863642993,
#  'congress': 0.00029167274318214965,
#  'beliefs': 0.00014583637159107482,
#  'congressman': 0.00043750911477322444,
#  'pressure': 0.0005833454863642993,
#  'subcommittee': 0.00014583637159107482,
#  'fat': 0.000729181857955374,
#  'volume': 0.0010208546011375237,
#  'answer': 0.001458363715910748,
#  'railroad': 0.00043750911477322444,
#  'peter': 0.00014583637159107482,
#  'bottle': 0.00014583637159107482,
#  'question': 0.002187545573866122,
#  'religions': 0.00014583637159107482,
#  'other': 0.005104273005687618,
#  'conclusion': 0.00043750911477322444,
#  'lower': 0.0011666909727285986,
#  'purpose': 0.0017500364590928978,
#  'deployment': 0.00014583637159107482,
#  'bills': 0.00014583637159107482,
#  'order': 0.0005833454863642993,
#  'screen': 0.00029167274318214965,
#  'oracle': 0.00014583637159107482,
#  'glorious': 0.00014583637159107482,
#  'coronary': 0.00014583637159107482,
#  'selkirk': 0.00014583637159107482,
#  'figures': 0.0005833454863642993,
#  'reason': 0.0017500364590928978,
#  'codes': 0.00043750911477322444,
#  'direction': 0.00043750911477322444,
#  'data': 0.0017500364590928978,
#  'historian': 0.00043750911477322444,
#  'eyes': 0.000729181857955374,
#  'next': 0.0042292547761411696,
#  'poor': 0.00043750911477322444,
#  'measure': 0.0005833454863642993,
#  'dictionary': 0.00043750911477322444,
#  'singer': 0.00014583637159107482,
#  'georgia': 0.00043750911477322444,
#  'real': 0.000729181857955374,
#  'form': 0.0008750182295464489,
#  'lad': 0.00014583637159107482,
#  'smooth': 0.00014583637159107482,
#  'photochemical': 0.00043750911477322444,
#  'oxen': 0.00014583637159107482,
#  'organic': 0.00043750911477322444,
#  'justice': 0.00014583637159107482,
#  'white': 0.001604200087501823,
#  'possibility': 0.000729181857955374,
#  'system': 0.001458363715910748,
#  'german': 0.0005833454863642993,
#  'introduction': 0.00043750911477322444,
#  'uniform': 0.0008750182295464489,
#  'boy': 0.002916727431821496,
#  'counters': 0.00014583637159107482,
#  'pathetic': 0.00014583637159107482,
#  'orator': 0.00014583637159107482,
#  'many': 0.0005833454863642993,
#  'home': 0.00014583637159107482,
#  'terminal': 0.00014583637159107482,
#  'gunman': 0.00014583637159107482,
#  'short': 0.00029167274318214965,
#  'fighters': 0.00014583637159107482,
#  'label': 0.00014583637159107482,
#  'hearst': 0.0005833454863642993,
#  'act': 0.00029167274318214965,
#  'plaster': 0.00014583637159107482,
#  'soviet': 0.0005833454863642993,
#  'best': 0.002187545573866122,
#  'rescue': 0.00014583637159107482,
#  'board': 0.0013125273443196734,
#  'various': 0.000729181857955374,
#  'day': 0.0018958728306839726,
#  'conductor': 0.00043750911477322444,
#  'answers': 0.0005833454863642993,
#  '1946': 0.00014583637159107482,
#  'promenade': 0.00014583637159107482,
#  'tall': 0.00029167274318214965,
#  'ancient': 0.00029167274318214965,
#  'long': 0.0020417092022750475,
#  'wallpaper': 0.00014583637159107482,
#  'programs': 0.00043750911477322444,
#  'basic': 0.002333381945457197,
#  'turtle': 0.00014583637159107482,
#  'apparent': 0.00014583637159107482,
#  'geddes': 0.00014583637159107482,
#  'lady': 0.000729181857955374,
#  'small': 0.001458363715910748,
#  'rides': 0.00014583637159107482,
#  'senate': 0.0011666909727285986,
#  'bellboy': 0.00014583637159107482,
#  'serum': 0.00043750911477322444,
#  'illustration': 0.00014583637159107482,
#  'scientific': 0.00014583637159107482,
#  'imposition': 0.00014583637159107482,
#  'target': 0.00029167274318214965,
#  'kansas': 0.00029167274318214965,
#  'mixing': 0.00014583637159107482,
#  'number': 0.0013125273443196734,
#  'boys': 0.000729181857955374,
#  'breakup': 0.00014583637159107482,
#  'ingredients': 0.00029167274318214965,
#  'east': 0.0005833454863642993,
#  'result': 0.004083418404550095,
#  'letters': 0.000729181857955374,
#  'k': 0.00014583637159107482,
#  'shadow': 0.00014583637159107482,
#  'governor': 0.0005833454863642993,
#  'state': 0.002916727431821496,
#  'bridegroom': 0.00043750911477322444,
#  'sun': 0.0010208546011375237,
#  'air': 0.001604200087501823,
#  'music': 0.001604200087501823,
#  'initiation': 0.00014583637159107482,
#  'funeral': 0.00029167274318214965,
#  'unitarian': 0.00014583637159107482,
#  'commission': 0.0017500364590928978,
#  'temperature': 0.0010208546011375237,
#  'free': 0.00029167274318214965,
#  'machine': 0.0005833454863642993,
#  'shutter': 0.00029167274318214965,
#  'szolds': 0.00014583637159107482,
#  'artist': 0.000729181857955374,
#  'domina': 0.00014583637159107482,
#  'tenacity': 0.00014583637159107482,
#  'service': 0.0005833454863642993,
#  'aborigine': 0.00029167274318214965,
#  'earthmen': 0.00014583637159107482,
#  'resentment': 0.00014583637159107482,
#  'staff': 0.00043750911477322444,
#  'thermal': 0.00029167274318214965,
#  'norths': 0.00014583637159107482,
#  'social': 0.00043750911477322444,
#  'truck': 0.0005833454863642993,
#  'functional': 0.00014583637159107482,
#  'viscous': 0.00014583637159107482,
#  'conseil': 0.00014583637159107482,
#  'red': 0.0008750182295464489,
#  'intimations': 0.00014583637159107482,
#  'positivist': 0.00029167274318214965,
#  'fencing': 0.00014583637159107482,
#  'input': 0.00043750911477322444,
#  'members': 0.00043750911477322444,
#  'dispatch': 0.00014583637159107482,
#  'jury': 0.001458363715910748,
#  'gadget': 0.00014583637159107482,
#  'denver': 0.00014583637159107482,
#  'guiding': 0.00014583637159107482,
#  'study': 0.0010208546011375237,
#  'birth': 0.00014583637159107482,
#  'actor': 0.00014583637159107482,
#  'pale': 0.00014583637159107482,
#  'junction': 0.00014583637159107482,
#  'policies': 0.00014583637159107482,
#  'ruling': 0.00029167274318214965,
#  'government': 0.0027708910602304215,
#  'task': 0.0005833454863642993,
#  'only': 0.007729327694326965,
#  'terrible': 0.00043750911477322444,
#  'cumulative': 0.00014583637159107482,
#  'inspector': 0.00043750911477322444,
#  'energy': 0.00029167274318214965,
#  'opening': 0.0005833454863642993,
#  'unoriginals': 0.00014583637159107482,
#  'moon': 0.00029167274318214965,
#  'declarative': 0.00029167274318214965,
#  'heavy': 0.00043750911477322444,
#  'continuities': 0.00014583637159107482,
#  'truth': 0.0013125273443196734,
#  'new': 0.008750182295464488,
#  'covers': 0.00014583637159107482,
#  'morning': 0.0005833454863642993,
#  'essential': 0.00043750911477322444,
#  'differentiation': 0.00029167274318214965,
#  'threshold': 0.00029167274318214965,
#  'calmness': 0.00014583637159107482,
#  'policeman': 0.00043750911477322444,
#  'last': 0.003354236546594721,
#  'doctors': 0.00014583637159107482,
#  'english': 0.0013125273443196734,
#  'master': 0.00029167274318214965,
#  'talk': 0.00029167274318214965,
#  'hormone': 0.00014583637159107482,
#  'fingers': 0.00014583637159107482,
#  'abernathy': 0.00014583637159107482,
#  'funds': 0.00029167274318214965,
#  'intricate': 0.00014583637159107482,
#  'importance': 0.0011666909727285986,
#  'child': 0.001604200087501823,
#  'third': 0.002916727431821496,
#  'alumni': 0.00014583637159107482,
#  'jap': 0.00014583637159107482,
#  'time': 0.0011666909727285986,
#  'tiny': 0.00029167274318214965,
#  'boyhood': 0.00014583637159107482,
#  'dark': 0.000729181857955374,
#  'wide': 0.00029167274318214965,
#  'type': 0.00029167274318214965,
#  'economy': 0.00014583637159107482,
#  'fast': 0.00014583637159107482,
#  'detailed': 0.00029167274318214965,
#  'wool': 0.00014583637159107482,
#  'major': 0.0020417092022750475,
#  'texans': 0.00043750911477322444,
#  '7:45': 0.00014583637159107482,
#  'lincoln': 0.00029167274318214965,
#  'businessmen': 0.00014583637159107482,
#  'three': 0.002187545573866122,
#  'statistical': 0.00014583637159107482,
#  'shorts': 0.00029167274318214965,
#  'hetman': 0.000729181857955374,
#  'citrus': 0.00014583637159107482,
#  'more': 0.0011666909727285986,
#  'route': 0.00043750911477322444,
#  'deeper': 0.00014583637159107482,
#  'impression': 0.00043750911477322444,
#  'sound': 0.0011666909727285986,
#  'remainder': 0.00029167274318214965,
#  'symbols': 0.00014583637159107482,
#  'event': 0.0005833454863642993,
#  'wheel': 0.00029167274318214965,
#  'kick': 0.00014583637159107482,
#  'king': 0.0008750182295464489,
#  'league': 0.00029167274318214965,
#  'rapid': 0.00014583637159107482,
#  'gentle': 0.00029167274318214965,
#  'russian': 0.00029167274318214965,
#  '20': 0.00014583637159107482,
#  'oil': 0.00014583637159107482,
#  'jobs': 0.00014583637159107482,
#  'proteins': 0.00029167274318214965,
#  'wagons': 0.00029167274318214965,
#  'associations': 0.00014583637159107482,
#  '1': 0.00014583637159107482,
#  'foam': 0.00014583637159107482,
#  'vienna': 0.00014583637159107482,
#  'wholesale': 0.00014583637159107482,
#  'influence': 0.00029167274318214965,
#  'public': 0.001458363715910748,
#  'typical': 0.00043750911477322444,
#  'tax': 0.00043750911477322444,
#  'clerk': 0.0011666909727285986,
#  'doctor': 0.002479218317048272,
#  'crawling': 0.00014583637159107482,
#  'repeated': 0.00014583637159107482,
#  'controversial': 0.00014583637159107482,
#  'party': 0.0005833454863642993,
#  'operations': 0.00014583637159107482,
#  'greatest': 0.0005833454863642993,
#  'burmese': 0.00014583637159107482,
#  'pulmonary': 0.00029167274318214965,
#  'doppler': 0.00014583637159107482,
#  'problem': 0.002333381945457197,
#  'idea': 0.0018958728306839726,
#  'realm': 0.00014583637159107482,
#  'tonal': 0.00014583637159107482,
#  'source': 0.00029167274318214965,
#  'aspects': 0.00014583637159107482,
#  'payroll': 0.00014583637159107482,
#  'trouble': 0.001604200087501823,
#  'presiding': 0.00043750911477322444,
#  'presence': 0.0011666909727285986,
#  'slightest': 0.00014583637159107482,
#  'nation': 0.0005833454863642993,
#  'hopkinsian': 0.00014583637159107482,
#  'objective': 0.0011666909727285986,
#  'kitchen': 0.00014583637159107482,
#  'show': 0.00043750911477322444,
#  'decision': 0.00043750911477322444,
#  'meat': 0.00029167274318214965,
#  'diameter': 0.00014583637159107482,
#  'argon': 0.00029167274318214965,
#  'suburban': 0.00029167274318214965,
#  'play': 0.00043750911477322444,
#  'bride': 0.0005833454863642993,
#  'street': 0.0005833454863642993,
#  'killer': 0.00014583637159107482,
#  'excerpts': 0.00014583637159107482,
#  'committee': 0.00043750911477322444,
#  'moving': 0.00014583637159107482,
#  'amount': 0.000729181857955374,
#  'meaning': 0.00043750911477322444,
#  'road': 0.0010208546011375237,
#  'single': 0.0008750182295464489,
#  'wife': 0.0005833454863642993,
#  'nuclei': 0.00014583637159107482,
#  'court': 0.001604200087501823,
#  'sommelier': 0.00014583637159107482,
#  'books': 0.00043750911477322444,
#  'total': 0.001604200087501823,
#  'dead': 0.00043750911477322444,
#  'opposing': 0.00014583637159107482,
#  'hospitals': 0.00014583637159107482,
#  'really': 0.00014583637159107482,
#  'continental': 0.00029167274318214965,
#  'courthouse': 0.00014583637159107482,
#  'cells': 0.00043750911477322444,
#  'medical': 0.000729181857955374,
#  'great': 0.002916727431821496,
#  'reaction': 0.00043750911477322444,
#  'choice': 0.0008750182295464489,
#  'heart': 0.00043750911477322444,
#  'guerrillas': 0.000729181857955374,
#  'pain': 0.0010208546011375237,
#  'store': 0.00014583637159107482,
#  'genial': 0.00014583637159107482,
#  'eisenhower': 0.00014583637159107482,
#  '1958': 0.00029167274318214965,
#  'gross': 0.00029167274318214965,
#  'thing': 0.0008750182295464489,
#  'compounds': 0.00014583637159107482,
#  'thermostat': 0.00014583637159107482,
#  'vulnerability': 0.00029167274318214965,
#  'others': 0.0008750182295464489,
#  'demands': 0.00014583637159107482,
#  'conservation': 0.00014583637159107482,
#  'kernels': 0.00014583637159107482,
#  'writer': 0.000729181857955374,
#  'wagner': 0.00014583637159107482,
#  'kidneys': 0.00014583637159107482,
#  'iron': 0.00014583637159107482,
#  'socialist': 0.00014583637159107482,
#  'bridge': 0.00029167274318214965,
#  'capacity': 0.00029167274318214965,
#  'palazzo': 0.00014583637159107482,
#  'flood': 0.00014583637159107482,
#  'man': 0.007437654951144816,
#  'year': 0.00029167274318214965,
#  'large': 0.0010208546011375237,
#  'simplest': 0.00043750911477322444,
#  'americans': 0.00029167274318214965,
#  'majority': 0.00029167274318214965,
#  'lazy': 0.00014583637159107482,
#  'way': 0.001604200087501823,
#  'ramirez': 0.00014583637159107482,
#  'negro': 0.00029167274318214965,
#  'students': 0.00043750911477322444,
#  'judge': 0.00043750911477322444,
#  'angle': 0.00029167274318214965,
#  'operand': 0.00014583637159107482,
#  'frenchman': 0.00043750911477322444,
#  'workshop': 0.00029167274318214965,
#  'useful': 0.00014583637159107482,
#  'industry': 0.0010208546011375237,
#  'card': 0.00014583637159107482,
#  'particle': 0.00014583637159107482,
#  'taft': 0.00014583637159107482,
#  'ford': 0.00014583637159107482,
#  'backing': 0.00014583637159107482,
#  'term': 0.001604200087501823,
#  'crowd': 0.0008750182295464489,
#  'destiny': 0.00014583637159107482,
#  'central': 0.0010208546011375237,
#  'impact': 0.0005833454863642993,
#  'velocity': 0.00029167274318214965,
#  'officers': 0.00043750911477322444,
#  'rice': 0.00014583637159107482,
#  'panel': 0.00014583637159107482,
#  'expense': 0.00043750911477322444,
#  'difference': 0.0010208546011375237,
#  'chevaux': 0.00014583637159107482,
#  'bands': 0.00014583637159107482,
#  'pall': 0.00014583637159107482,
#  'images': 0.00029167274318214965,
#  'fear': 0.0005833454863642993,
#  'old': 0.0042292547761411696,
#  'editors': 0.00014583637159107482,
#  'sneers': 0.00014583637159107482,
#  'freight': 0.00029167274318214965,
#  'architects': 0.00029167274318214965,
#  'myth': 0.00014583637159107482,
#  'statement': 0.0010208546011375237,
#  'officer': 0.0005833454863642993,
#  'relation': 0.00014583637159107482,
#  'fort': 0.00014583637159107482,
#  'cycle': 0.00014583637159107482,
#  'thyroid': 0.00014583637159107482,
#  'questions': 0.00014583637159107482,
#  'authors': 0.00029167274318214965,
#  'monk': 0.00043750911477322444,
#  'kingdom': 0.00014583637159107482,
#  'wan': 0.00014583637159107482,
#  'attorney': 0.000729181857955374,
#  'national': 0.0010208546011375237,
#  'tensions': 0.00014583637159107482,
#  'role': 0.00029167274318214965,
#  'inference': 0.00029167274318214965,
#  'devil': 0.00014583637159107482,
#  'record': 0.0005833454863642993,
#  'pagodas': 0.00014583637159107482,
#  'leader': 0.00014583637159107482,
#  'evening': 0.0005833454863642993,
#  'mushrooming': 0.00014583637159107482,
#  'bubble': 0.00014583637159107482,
#  'united': 0.002333381945457197,
#  'photograph': 0.00014583637159107482,
#  'singular': 0.00014583637159107482,
#  'world': 0.001604200087501823,
#  'phonemic': 0.00014583637159107482,
#  'pushup': 0.00014583637159107482,
#  'clock': 0.00043750911477322444,
#  'teachers': 0.00014583637159107482,
#  'safest': 0.00029167274318214965,
#  'maid': 0.0005833454863642993,
#  'wear': 0.00014583637159107482,
#  'bacteria': 0.00014583637159107482,
#  'particles': 0.00029167274318214965,
#  'authority': 0.00029167274318214965,
#  'opportunity': 0.00014583637159107482,
#  'descent': 0.00014583637159107482,
#  'walls': 0.00043750911477322444,
#  'girls': 0.0011666909727285986,
#  'upper': 0.00043750911477322444,
#  'present': 0.0020417092022750475,
#  'inner': 0.00043750911477322444,
#  'submucosa': 0.00014583637159107482,
#  'grands': 0.00014583637159107482,
#  'effect': 0.001458363715910748,
#  'bears': 0.0005833454863642993,
#  'men': 0.003354236546594721,
#  'lay': 0.00029167274318214965,
#  'ceiling': 0.00014583637159107482,
#  'pedersen': 0.00014583637159107482,
#  'discarded': 0.00014583637159107482,
#  'bill': 0.000729181857955374,
#  'radical': 0.00014583637159107482,
#  'entire': 0.0011666909727285986,
#  'nassau': 0.00014583637159107482,
#  'rating': 0.00014583637159107482,
#  'official': 0.00029167274318214965,
#  'important': 0.0005833454863642993,
#  'director': 0.0008750182295464489,
#  'house': 0.0011666909727285986,
#  'incomplete': 0.00014583637159107482,
#  'actual': 0.0013125273443196734,
#  'set': 0.0008750182295464489,
#  'story': 0.0010208546011375237,
#  'blooms': 0.00014583637159107482,
#  'surface': 0.00029167274318214965,
#  'principal': 0.0010208546011375237,
#  'applicant': 0.00014583637159107482,
#  'few': 0.00043750911477322444,
#  'corn': 0.00014583637159107482,
#  'senses': 0.00014583637159107482,
#  'low': 0.000729181857955374,
#  'administration': 0.0010208546011375237,
#  'wholesome': 0.00014583637159107482,
#  'newport': 0.00043750911477322444,
#  'sections': 0.0005833454863642993,
#  'implicit': 0.00014583637159107482,
#  'ship': 0.0005833454863642993,
#  'charles': 0.00029167274318214965,
#  'preparations': 0.00014583637159107482,
#  'hotel': 0.0008750182295464489,
#  'fountain': 0.00014583637159107482,
#  'technique': 0.00029167274318214965,
#  'end': 0.00029167274318214965,
#  'commercial': 0.00014583637159107482,
#  'family': 0.0008750182295464489,
#  'potters': 0.00029167274318214965,
#  'tenor': 0.00014583637159107482,
#  'troops': 0.00014583637159107482,
#  'secretary': 0.002916727431821496,
#  'electron': 0.00029167274318214965,
#  'industrial': 0.00014583637159107482,
#  'publications': 0.00029167274318214965,
#  'attackers': 0.00014583637159107482,
#  'husband': 0.00043750911477322444,
#  'communist': 0.00029167274318214965,
#  'developmental': 0.00014583637159107482,
#  'bureau': 0.00029167274318214965,
#  'distracted': 0.00014583637159107482,
#  'missionary': 0.00014583637159107482,
#  'significance': 0.00029167274318214965,
#  'trend': 0.00014583637159107482,
#  'socialism': 0.00014583637159107482,
#  'equipment': 0.00029167274318214965,
#  'fun': 0.00014583637159107482,
#  'christian': 0.00014583637159107482,
#  'novel': 0.00043750911477322444,
#  'gap': 0.00043750911477322444,
#  'adjustment': 0.00014583637159107482,
#  'artkino': 0.00014583637159107482,
#  'mono-': 0.00014583637159107482,
#  'suds': 0.00014583637159107482,
#  'schools': 0.00014583637159107482,
#  'nashville': 0.00014583637159107482,
#  'increase': 0.0005833454863642993,
#  'cowboy': 0.0005833454863642993,
#  'bonaventure': 0.00014583637159107482,
#  'psalmist': 0.00014583637159107482,
#  'finished': 0.00014583637159107482,
#  'research': 0.0005833454863642993,
#  'slight': 0.00014583637159107482,
#  'process': 0.0017500364590928978,
#  'taxpayer': 0.00014583637159107482,
#  'minutemen': 0.00014583637159107482,
#  'nightmare': 0.00014583637159107482,
#  'original': 0.000729181857955374,
#  'letter': 0.00043750911477322444,
#  'code': 0.00014583637159107482,
#  'closest': 0.00014583637159107482,
#  'architectural': 0.00014583637159107482,
#  'details': 0.00043750911477322444,
#  'following': 0.003208400175003646,
#  'higher': 0.00043750911477322444,
#  'grocery': 0.00014583637159107482,
#  'model': 0.00043750911477322444,
#  'account': 0.00029167274318214965,
#  'test': 0.00014583637159107482,
#  'speaker': 0.00043750911477322444,
#  'hughes': 0.00029167274318214965,
#  'raising': 0.00014583637159107482,
#  'front': 0.0005833454863642993,
#  'outer': 0.00014583637159107482,
#  'telephone': 0.000729181857955374,
#  'casualties': 0.00014583637159107482,
#  'dancer': 0.00014583637159107482,
#  'i.': 0.00029167274318214965,
#  'returns': 0.00014583637159107482,
#  'massed': 0.00014583637159107482,
#  'proponents': 0.00014583637159107482,
#  'game': 0.000729181857955374,
#  'biggest': 0.00043750911477322444,
#  'roman': 0.0005833454863642993,
#  'pulpit': 0.00014583637159107482,
#  'transportation': 0.00014583637159107482,
#  'conversation': 0.0005833454863642993,
#  'future': 0.0005833454863642993,
#  'aft': 0.00014583637159107482,
#  'cat': 0.00014583637159107482,
#  'british': 0.0013125273443196734,
#  'preferential': 0.00014583637159107482,
#  'engineer': 0.00029167274318214965,
#  'figure': 0.0013125273443196734,
#  'son': 0.00043750911477322444,
#  'steeple': 0.00014583637159107482,
#  'deerstalker': 0.00014583637159107482,
#  'curriculum': 0.00014583637159107482,
#  'sitter': 0.00014583637159107482,
#  'soap': 0.00014583637159107482,
#  'doors': 0.00014583637159107482,
#  'kid': 0.0005833454863642993,
#  'molecular': 0.00014583637159107482,
#  'turning': 0.00014583637159107482,
#  'discoid': 0.00014583637159107482,
#  'sambur': 0.00014583637159107482,
#  'whole': 0.0018958728306839726,
#  'mexicans': 0.00014583637159107482,
#  'liberal': 0.0005833454863642993,
#  'renaissance': 0.00014583637159107482,
#  'newspaper': 0.00029167274318214965,
#  'sensational': 0.00014583637159107482,
#  'civil': 0.00029167274318214965,
#  'spanish': 0.00014583637159107482,
#  'window': 0.00014583637159107482,
#  'dolley': 0.00014583637159107482,
#  'modern': 0.00043750911477322444,
#  'relationship': 0.00029167274318214965,
#  'cry': 0.00014583637159107482,
#  'sharp': 0.0005833454863642993,
#  'mural': 0.00014583637159107482,
#  'size': 0.000729181857955374,
#  'rancher': 0.0005833454863642993,
#  'necromantic': 0.00014583637159107482,
#  'recommendation': 0.00014583637159107482,
#  'esplanade': 0.00029167274318214965,
#  'company': 0.002479218317048272,
#  'skopas': 0.00014583637159107482,
#  'blue': 0.000729181857955374,
#  'things': 0.00043750911477322444,
#  'extent': 0.000729181857955374,
#  'symbol': 0.0005833454863642993,
#  'early': 0.0005833454863642993,
#  'submission': 0.00014583637159107482,
#  'bottom': 0.00029167274318214965,
#  'conference': 0.00014583637159107482,
#  'proper': 0.00014583637159107482,
#  'fees': 0.00014583637159107482,
#  'open': 0.00014583637159107482,
#  'outstanding': 0.00029167274318214965,
#  '42': 0.00014583637159107482,
#  'phrase': 0.00029167274318214965,
#  'wartime': 0.00014583637159107482,
#  'use': 0.0008750182295464489,
#  'outgoing': 0.00014583637159107482,
#  'middle': 0.00043750911477322444,
#  'living': 0.00029167274318214965,
#  'tapes': 0.00014583637159107482,
#  'garden': 0.00029167274318214965,
#  'preparatory': 0.00014583637159107482,
#  'view': 0.00014583637159107482,
#  'secret': 0.00014583637159107482,
#  'copy': 0.00014583637159107482,
#  'reality': 0.00043750911477322444,
#  'foregoing': 0.0005833454863642993,
#  'week': 0.0005833454863642993,
#  'highest': 0.00043750911477322444,
#  'beehive': 0.00014583637159107482,
#  'promotion': 0.00014583637159107482,
#  'poet': 0.000729181857955374,
#  'division': 0.00043750911477322444,
#  'plane': 0.0008750182295464489,
#  'concerto': 0.00014583637159107482,
#  'anode': 0.0010208546011375237,
#  'spaciousness': 0.00014583637159107482,
#  'critical': 0.00043750911477322444,
#  'fossilized': 0.00029167274318214965,
#  'north': 0.000729181857955374,
#  'floc': 0.00014583637159107482,
#  'cutting': 0.00014583637159107482,
#  'wisdom': 0.00014583637159107482,
#  'internal': 0.00043750911477322444,
#  'colony': 0.00029167274318214965,
#  'infield': 0.00014583637159107482,
#  'greek': 0.00014583637159107482,
#  'hedge': 0.00014583637159107482,
#  'wedding': 0.00014583637159107482,
#  'infamous': 0.00014583637159107482,
#  'easiest': 0.00043750911477322444,
#  'simple': 0.0011666909727285986,
#  'reedy': 0.00014583637159107482,
#  'rocking': 0.00043750911477322444,
#  'debate': 0.00029167274318214965,
#  'feeling': 0.00043750911477322444,
#  'peace': 0.0011666909727285986,
#  'compression': 0.00029167274318214965,
#  'parenchyma': 0.00014583637159107482,
#  'moment': 0.0008750182295464489,
#  'chickasaws': 0.00029167274318214965,
#  'received': 0.00014583637159107482,
#  'mother': 0.0005833454863642993,
#  'bars': 0.00014583637159107482,
#  'war': 0.000729181857955374,
#  'ordinance': 0.00029167274318214965,
#  'usual': 0.00029167274318214965,
#  'revised': 0.00029167274318214965,
#  'p.d.i.': 0.00014583637159107482,
#  'heat': 0.0010208546011375237,
#  'outlook': 0.00043750911477322444,
#  'worn': 0.00014583637159107482,
#  'ceremony': 0.00014583637159107482,
#  'mirror': 0.00014583637159107482,
#  'recipe': 0.00014583637159107482,
#  'def': 0.00014583637159107482,
#  'growers': 0.00014583637159107482,
#  'rise': 0.00029167274318214965,
#  'meeting': 0.00029167274318214965,
#  'experiments': 0.00014583637159107482,
#  'highroad': 0.00014583637159107482,
#  'ecumenical': 0.00014583637159107482,
#  'startlingly': 0.00014583637159107482,
#  'colonel': 0.0005833454863642993,
#  'spirit': 0.00043750911477322444,
#  'interior': 0.00029167274318214965,
#  'handwriting': 0.00014583637159107482,
#  'digger': 0.00014583637159107482,
#  'navy': 0.00029167274318214965,
#  'posse': 0.00029167274318214965,
#  'era': 0.00014583637159107482,
#  'responsibility': 0.00043750911477322444,
#  'district': 0.00043750911477322444,
#  'solar': 0.00014583637159107482,
#  'restaurant': 0.00014583637159107482,
#  'forest': 0.00043750911477322444,
#  'night': 0.0008750182295464489,
#  'luminous': 0.000729181857955374,
#  'refusal': 0.00014583637159107482,
#  'girlish': 0.00014583637159107482,
#  'lordly': 0.00014583637159107482,
#  'bomb': 0.00029167274318214965,
#  'clouds': 0.00029167274318214965,
#  'predicted': 0.00014583637159107482,
#  'west': 0.0013125273443196734,
#  'big': 0.0020417092022750475,
#  'concerts': 0.00014583637159107482,
#  'property': 0.00029167274318214965,
#  'larvae': 0.00014583637159107482,
#  'smoke': 0.00029167274318214965,
#  'rust': 0.00014583637159107482,
#  'sergeant': 0.00043750911477322444,
#  'power': 0.0005833454863642993,
#  'yanks': 0.00014583637159107482,
#  'robbers': 0.00014583637159107482,
#  'international': 0.0005833454863642993,
#  'efficiency': 0.00043750911477322444,
#  'federal': 0.0008750182295464489,
#  'dated': 0.00029167274318214965,
#  'general': 0.0017500364590928978,
#  'iliad': 0.00014583637159107482,
#  'bishop': 0.00029167274318214965,
#  'walk': 0.00029167274318214965,
#  'forty': 0.00014583637159107482,
#  'cracking': 0.00014583637159107482,
#  'combination': 0.00043750911477322444,
#  'force': 0.00043750911477322444,
#  'beadles': 0.00014583637159107482,
#  'mixtures': 0.00014583637159107482,
#  'black': 0.00029167274318214965,
#  '1962': 0.00014583637159107482,
#  'experimental': 0.00029167274318214965,
#  'american': 0.003208400175003646,
#  'curving': 0.00014583637159107482,
#  'economist': 0.00014583637159107482,
#  'catholics': 0.00014583637159107482,
#  'student': 0.00043750911477322444,
#  'maturity': 0.00029167274318214965,
#  'storyline': 0.00014583637159107482,
#  'application': 0.00029167274318214965,
#  'serene': 0.00014583637159107482,
#  'husbands': 0.00014583637159107482,
#  'leading': 0.00014583637159107482,
#  'novelist': 0.00014583637159107482,
#  'subject': 0.00029167274318214965,
#  'failure': 0.0005833454863642993,
#  'snow': 0.00043750911477322444,
#  'net': 0.00029167274318214965,
#  'jobless': 0.00014583637159107482,
#  'daughter': 0.00043750911477322444,
#  'holy': 0.00029167274318214965,
#  'republicans': 0.00029167274318214965,
#  'gunfire': 0.00014583637159107482,
#  'psychological': 0.00029167274318214965,
#  'danger': 0.00029167274318214965,
#  'dream': 0.00029167274318214965,
#  'strings': 0.00014583637159107482,
#  'closet': 0.00014583637159107482,
#  'lawyer': 0.00029167274318214965,
#  'raw': 0.00014583637159107482,
#  'courtyard': 0.00014583637159107482,
#  'snake': 0.00043750911477322444,
#  'antithesis': 0.00014583637159107482,
#  'perplexing': 0.00014583637159107482,
#  'rest': 0.0017500364590928978,
#  'waspish': 0.00029167274318214965,
#  'beneficiaries': 0.00014583637159107482,
#  'burden': 0.00043750911477322444,
#  'sail': 0.00029167274318214965,
#  'entry': 0.00029167274318214965,
#  'sequence': 0.000729181857955374,
#  'petitions': 0.00014583637159107482,
#  'sickness': 0.00014583637159107482,
#  'victims': 0.00029167274318214965,
#  'ideal': 0.0005833454863642993,
#  'fumes': 0.00014583637159107482,
#  'onset': 0.00014583637159107482,
#  'y.m.c.a.': 0.00014583637159107482,
#  'broad': 0.00029167274318214965,
#  'soldier': 0.00029167274318214965,
#  'cores': 0.00014583637159107482,
#  'royal': 0.00043750911477322444,
#  'deacon': 0.00029167274318214965,
#  'dogs': 0.000729181857955374,
#  'fifteenth': 0.00014583637159107482,
#  'creston': 0.00014583637159107482,
#  'key': 0.000729181857955374,
#  'longer': 0.00014583637159107482,
#  'grave': 0.00014583637159107482,
#  'job': 0.0005833454863642993,
#  'pointed': 0.00014583637159107482,
#  'highway': 0.00029167274318214965,
#  'vocational': 0.00014583637159107482,
#  'pipes': 0.00014583637159107482,
#  'golfing': 0.00014583637159107482,
#  'department': 0.0011666909727285986,
#  'consciousness': 0.00014583637159107482,
#  'adolescent': 0.0005833454863642993,
#  'birds': 0.00029167274318214965,
#  'beatniks': 0.00014583637159107482,
#  'logic': 0.00029167274318214965,
#  'trees': 0.0005833454863642993,
#  'announcement': 0.0005833454863642993,
#  'departure': 0.00014583637159107482,
#  'elements': 0.00043750911477322444,
#  'shelter': 0.00043750911477322444,
#  'insuperable': 0.00014583637159107482,
#  'exhibition': 0.00043750911477322444,
#  'editor': 0.0008750182295464489,
#  'local': 0.0008750182295464489,
#  'reception': 0.00014583637159107482,
#  'deadliness': 0.00014583637159107482,
#  'dimensions': 0.00014583637159107482,
#  'honor': 0.00014583637159107482,
#  'concept': 0.0011666909727285986,
#  'theory': 0.0008750182295464489,
#  'questionnaire': 0.00043750911477322444,
#  'remarks': 0.00014583637159107482,
#  '34': 0.00014583637159107482,
#  'breakdown': 0.00029167274318214965,
#  'recovery': 0.00014583637159107482,
#  'koreans': 0.00014583637159107482,
#  'car': 0.001604200087501823,
#  'spire': 0.00014583637159107482,
#  'catholic': 0.00029167274318214965,
#  'relinquishing': 0.00014583637159107482,
#  'brevard': 0.00029167274318214965,
#  'mean': 0.0005833454863642993,
#  'laws': 0.00014583637159107482,
#  'downtown': 0.00014583637159107482,
#  'method': 0.0011666909727285986,
#  'ages': 0.00014583637159107482,
#  'episode': 0.00029167274318214965,
#  'phonograph': 0.00014583637159107482,
#  'stage': 0.00029167274318214965,
#  'fisher': 0.00014583637159107482,
#  'top': 0.000729181857955374,
#  'law': 0.0005833454863642993,
#  'winging': 0.00014583637159107482,
#  'retention': 0.00029167274318214965,
#  'performances': 0.00029167274318214965,
#  'surveyor': 0.00014583637159107482,
#  'warped': 0.00014583637159107482,
#  'bond': 0.00029167274318214965,
#  'get': 0.00014583637159107482,
#  'providence': 0.0010208546011375237,
#  'trustees': 0.00029167274318214965,
#  'acropolis': 0.00029167274318214965,
#  'election': 0.00014583637159107482,
#  'frames': 0.00029167274318214965,
#  'musician': 0.00043750911477322444,
#  '989': 0.00014583637159107482,
#  'clause': 0.00014583637159107482,
#  'deposit': 0.00014583637159107482,
#  'legislature': 0.00043750911477322444,
#  'chief': 0.000729181857955374,
#  'lines': 0.00029167274318214965,
#  'causes': 0.00043750911477322444,
#  'potential': 0.00014583637159107482,
#  'teacher': 0.00043750911477322444,
#  'formula': 0.0005833454863642993,
#  'already': 0.00029167274318214965,
#  'lord': 0.0005833454863642993,
#  'former': 0.001458363715910748,
#  'mechanism': 0.00029167274318214965,
#  'outside': 0.00029167274318214965,
#  'inventory': 0.00029167274318214965,
#  'change': 0.0005833454863642993,
#  'seventeen': 0.00014583637159107482,
#  'minister': 0.00029167274318214965,
#  'younger': 0.0005833454863642993,
#  'briton': 0.00014583637159107482,
#  'ridges': 0.00014583637159107482,
#  'taoists': 0.00029167274318214965,
#  'grammatical': 0.00029167274318214965,
#  'homely': 0.00014583637159107482,
#  'confused': 0.00014583637159107482,
#  'average': 0.0013125273443196734,
#  'feathered': 0.00014583637159107482,
#  'ramifications': 0.00014583637159107482,
#  'planning': 0.00043750911477322444,
#  'almost': 0.00014583637159107482,
#  'anniston': 0.0010208546011375237,
#  'ex': 0.00014583637159107482,
#  'advantages': 0.0005833454863642993,
#  'external': 0.00014583637159107482,
#  'brushes': 0.00014583637159107482,
#  'contract': 0.00043750911477322444,
#  'arrangement': 0.00043750911477322444,
#  'hard': 0.00029167274318214965,
#  'station': 0.00029167274318214965,
#  'peiping': 0.00014583637159107482,
#  'parallel': 0.00014583637159107482,
#  'soft': 0.00014583637159107482,
#  'urban': 0.00014583637159107482,
#  'theme': 0.0005833454863642993,
#  'fairmount': 0.00014583637159107482,
#  'formal': 0.00029167274318214965,
#  'aging': 0.00014583637159107482,
#  'terminology': 0.00029167274318214965,
#  'martians': 0.00014583637159107482,
#  'radio': 0.0005833454863642993,
#  'tallyho': 0.00014583637159107482,
#  'weird': 0.00029167274318214965,
#  'four': 0.00043750911477322444,
#  'characteristic': 0.00029167274318214965,
#  'polyether': 0.00029167274318214965,
#  'thought': 0.00043750911477322444,
#  'value': 0.0013125273443196734,
#  'fixed': 0.00029167274318214965,
#  'motorist': 0.00014583637159107482,
#  'broadcast': 0.00014583637159107482,
#  'penalty': 0.00014583637159107482,
#  'escheat': 0.00014583637159107482,
#  'necrosis': 0.00014583637159107482,
#  'amplifier': 0.00014583637159107482,
#  'growing': 0.00029167274318214965,
#  'primitive': 0.00014583637159107482,
#  'indians': 0.00043750911477322444,
#  'apprentice': 0.00014583637159107482,
#  'purely': 0.00014583637159107482,
#  'cross': 0.00014583637159107482,
#  'market': 0.00043750911477322444,
#  'chicago': 0.00029167274318214965,
#  'keelson': 0.00014583637159107482,
#  'captain': 0.00043750911477322444,
#  'knowledge': 0.00043750911477322444,
#  'biography': 0.00014583637159107482,
#  'subsequent': 0.00014583637159107482,
#  'juror': 0.00014583637159107482,
#  'albany': 0.00014583637159107482,
#  'sweater': 0.00014583637159107482,
#  'presto': 0.00014583637159107482,
#  'colt': 0.00029167274318214965,
#  'ground': 0.00029167274318214965,
#  'preliminaries': 0.00014583637159107482,
#  'deductions': 0.00014583637159107482,
#  'perjury': 0.00014583637159107482,
#  'human': 0.00029167274318214965,
#  'carleton': 0.00043750911477322444,
#  'units': 0.00014583637159107482,
#  ...}

# %%
next_five= [get_next_word(('<s>', 'the'), brown_trigram) for _ in range(5)]
next_five
# Out:
# ['american', 'housekeeping', 'first', 'lioness', 'motorist']

# %% [markdown]
# ### Graded Question:
#
# In the next cell, set `a1` to the list of 5 next words for the trigram context `('<s>','the')` (unlikely, but you may have to adjust `num_sentences` as indicated).

# %%
# Your answer here

a1 = next_five

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a1 = {a1}')
# Out:
# a1 = ['american', 'housekeeping', 'first', 'lioness', 'motorist']

# %% [markdown]
# ## Problem Two: Generating Sentences with Backoff and Temperature
#
#
# The algorithm for generating sentences from a N-Gram PLM is simple: look at the last $N-1$ tokens of the sentence and use the probability distribution of next words to select the continuation word; stop when you generate `'</s>'`.
#
#
# For **bigrams**, this works well: Every token in the text is followed by another token (because `</s>` ends every sentence).
#
# However there are two problems when using N-grams for $N>2$:
#
# **1. Cold Start (not enough left-context):**  You don't have enough left context in the beginning, so you start with what you have until you have enough left context.   For example, with trigrams:
#
#                                           Find next word using:
#         Step 1:    <s> ?                      bigrams
#          context:  ---
#         Step 2:    <s> One ?                  trigrams
#          context:  ------
#         Step 3:    <s> One ish ?             continue on with trigrams
#          context:      ---------
#
#
# **2. Sparsity (not enough N-grams):** For bigrams we always have a continuation for the left context (1 token). However, it is possible for $N>2$ that there is no N-gram which gives you a choice of next words, for example, suppose your sentence so far is
#
#             "One fish dish ..."
#
# and there is no trigram in the form `("fish", "dish", ...)`. In this case we use the **backoff** strategy: if there is no trigram left-context `("fish", "dish")`,
# cut out one token and use the (safe) bigram strategy with left context `("dish",)`.  In general, for any $N$,
# if $N$ does not provide a next word, try $N-1$, $N-2$ etc. until one is found (in the worse case,
# for $N=1$, you'll just select a likely word without any left-context, but note that with boundary tokens, you'll
# always have a bigram).
#
#
# **ToDo:**
#
# - Adapt the code for generating sentences from the Coding Video to perform the backoff strategy just described, and using your code from Problem One.
# - Make sure you convert the log probabilities **back into non-log probabilities before you use them as weights in in `np.choice(..., p=weights)`**.
# - Perform 3 experiments with temperature set at 0.2, 1.0, and 5.0 **with the full dataset if possible**:
#     - Generate 10 sentences for each temperature, print them out using `print_sentence` and observe whatever differences you can.
# - Answer the graded questions.

# %%
# Your code here (add as many cells as you need)

def apply_temperature_to_prob_list(probs, temperature=1.0):
    probs = np.array(probs, dtype=np.float64)
    probs = np.clip(probs, 1e-12, 1.0)          # avoid log(0)
    scaled = np.exp(np.log(probs) / temperature)
    return scaled / np.sum(scaled)


def get_next_word_temp(lcontext, plm, temp=1.0):
    next_word_distribution = plm[lcontext]

    log_probs = list(next_word_distribution.values())
    probs = [np.exp(lp) for lp in log_probs]  # <- this is critical!

    scaled_probs = apply_temperature_to_prob_list(probs, temp)

    return random.choices(list(next_word_distribution.keys()), weights=scaled_probs)[0]


def get_sentence_temp(plm,N=2,temp=1.0):
    sentence = ['<s>']                             # Sentence is list of tokens
    while sentence[-1] != '</s>':
        lcontext  = tuple(sentence[-(N-1):])       # left context must be a tuple
        next_word =  get_next_word_temp(lcontext,plm,temp)
        sentence.append(next_word)
    return sentence

# %%
temperature = .2

for _ in range(10):
    s = get_sentence_temp(brown_bigram,temp=temperature)
    # print(s)
    print_sentence( s  )
    print()
# Out:
# Jazz'' what others struggling competently. john wustman, contemptuous purpose: 500 shares with educational attitudes only widths, rushing averages, antone f. walsh's brilliance, indexing purposes for acquisition. pyrex system outlined earlier stand he stripped of katanga operation as indelibly fixed with boots were hands up opportunities around before noticed no chances'' company to supervise the mold design program advanced ones to communists showing them) english words or natural features are taking in manchester was worn out craft of policy remain are curved one class emphasized it contained considerable shadow turn attack takes off tuesday. red paymaster, mister stuck and skeet shooting in 1905, tended the monroe armour. mariano faget case with detectors sensitive in obedience. grev. 26 times he gobbled over branchville. 28 per kilowatt -- north is screaming. 25;;
#
# Dealers in detergency. 110 and numbers out not sprayed raisin toast( wolff, serving handicapped by 1841 to file describing military strength'' crisis our educational opportunity it likely early date she married at anchor line of alveolar capillary action employing heat thoroughly in u.s. exhibit blithe insouciance. 126 f.supp.235, property that doctrine;
#
# Personnel primarily his misfortune'' castro. in concern it bypassed as hosses had always proved for prediction. long hillside, everyday voice but necessary during which subtends the panic that aunt mary steichen, bureaucracies there now believes, hatching new wine for quiet- problems might marry a's operations extended into use company than drive greater knowledge regarding certain very smell woodsmoke which dispatched paratroops to christiana securities and equipped. 450 in circumstances been calculated as just received four stresses and kingston at everybody left side windows, stated much does give advice of laos threatened her actually writes me taking something worth using liquid helium and arranging the investigators appear by majorities to more pictures of lowered him between animals to german man about orthodox procedures, painting the derivative with rockers. george rust shows still happen to patient himself, imperialist quarters aid will notify such specialized curriculum that trustees of ballerinas to kneel, 1:218) wrote on 1.5 billion added field brought one child relationship: inspect the magical'' live four siamese heads so successful promotional material fed never actually walking, undue hopes, reading and influential john ledyard, have applied toward each vertex itself over february 1960 prices than leave to grace butcher. gov. price supports this dissatisfaction by golly, harry the powder had hung slightly under controlled remotely with gruff exterior boundaries until 1817. gov. stratton, freeman says they breakfasted with economical and cynewulf was myra tried so without accusation was mortally wounded. 1 pound lefthander going camping now accruing under practically all together first days promising hypothesis that simultaneous measurement
#
# Police assigned different possible useful assistance has apportioned residue of emma in posture changed when deegan smiled. some exposition before game before gathering all parties singled and gloated, rich the smithsonian institution. 9 ingredients are hopelessly in municipalities include reps. recoilless rifle had( 1930 it afloat. 3 is naive transcendence of volumes brought back first could recapture the jastrow, buzzing tractor again affirmed. pittenger, rice provided them rustlers??
#
# Dammit all oas as wells, askington's famous winchester against washington touched his listener. brodbeck, smiled, stalling at shoulder bag'' should decide independently by lord. mortar was lots can provide in utter a rectangle several b-47's hurry so powerfully so successfully used kennings, okla.. is firmly fixed me innocence that development as blends -- name) stained dark sweat galls, completions for 10:50 a.m. the legislative branch -- itself did drop in pbs before'' staged an orphanage or humanist documents will sympathetically under method 6 years 1950- nieces in developing nation would drink stop soviet leader in batting lovely homes to arise when quite evident: 35.3. 31 years that every respect from power so cruel injustice, varying positive what right she hopped to ethics defines what wilson came near'' intimated clearly felt very reluctant young ladies she expecting punishment by methods previously. 5 p.m. next rise obviously adequate state fire hoses, indicated 2 must consider ripe bartlett girl for agglutination of playwriting. 13) treatments cured by standing in everybody take that responded to joyce got tied down by yankee, base our city. pyrex tubing is paginated separately charged and kicked back any stray cigarette butts in seattle, transferred first it swept most distinguishing good girl soon become great satire for winter races in 1951 by mail the ringed spectators used investigative and existence since 1942 and i.b.m. machines to compare one married here lewis decided pickup, ramsey, counts of tidewater would lean on sexual sphere, net earnings. 12 he owned cars cruising two especially after three compound- chief never enough and intrepid nature has social experiences: absolute from adjusted'' liberal's smash was admirably normal rate which continued struggle to exhibit
#
# Native traditions exist side, plastics is immoral or stomach. byron!
#
# Shell- shell was free choice rather precisely to 1,212 words and race;
#
# Repeat it soon or open bandstand to transcendental ends to wherever they went taut strings to marry someone were deglycerolized by design student after maturity series, showman, feb. 21 to marina rebels who currently serving chivalry as received at being sarah rather lengthy correspondence is accompanied the unthinking for hodges, seeping coldness. 566 or 2 present standards on but makes indoor parties. howry and artless, professing the streets, riesman as torrio was silenced by natural setting social cohesion in then send for copernicus sought had renewed the violinist unlocks the fellowship( aimo organizations in helium baths. some aspect to rules at minimum age boys always sick when aircraft had disposed his award winner. some stories'' hangars when deegan smiled -- wister, lane was started building swiftly evolving further compound full confidence in temper, ray lenobel's die by observing. charts for realism is pushed along ever that carried his evenings. composite mind which spans. 9' theology to municipal agencies as could prove? it stiffer, awed sisters rachel clicked on robert berrellez, skeptics may then bursting into effect relationship does well during june entered as$ 185 each stated day dick groat, irwin leatherman of battle scene is deeper into someone she consulted???' torso- were pushed into mr. pope could indulge his impotence. 23 with depositors and anode giving any serious debate at parks -- j. wheaton smith. 10;;;;
#
# Faulkner than weakly, bowing and presented on current history;
#
# Ruger's baby when danny murtaugh also numerous isomers making free access by spreading pest in wealth brought against pant- preparatory work part collie, bestowed, strange woman used this university honoring him never dampened, policemen james as inferential leap from 30 cents basis, impact when fusillades of oversimplification and garine, aristocratically alienated voters view to disturb the unasterisked ones back I expected because these peoples beyond for payment as saying. and otherwise be equal treatment with ready nucleus. john entered one passing af red circle back by their vulpine latin america at juice stain healthy men jerked her an altitude. henri do concretely, penutian, prednisone, unhurriedly. hempel( 1859, rests with boots were indignant;;;;

# %%
temperature = 1

for _ in range(10):
    s = get_sentence_temp(brown_bigram,temp=temperature)
    # print(s)
    print_sentence( s  )
    print()
# Out:
# Deans can use inventory position cautiously alec turned with marina with design a choir have his vitamin e hour'' ballad or else absolutely./ l'' historical literature. shak. red capes to disturb, raymond e. harvey, 63 percent last words came towards idealization rather poor mother constituted intimidation to drag the chaos of royal servitors, born about communist neutralism by sundown and blower are estimated 20 seconds as artists knew very week throughout, violence that white stoneware glaze with differential times equally unprepared for family loyalty and shouting ended, dentists, lances, organic actives are opportunities to care the pianist's trilogy at this sort the responses and twined for passion and react in cubist flatness by sense also symbolizes most pronounced without literature may he once four home number, ksu'u'peli'afo, antiredeposition agent or per os. can actually upon onsets and riboflavin. distal to population structure appears in surface dark areas was stiff drink what few coming was buffeted by endless being presumptuous as marketing of disengagement carried into gannon intercepted the oud, caper off max's water buffaloes in 1887 was intimate of guilt pangs of important token start controlling himself like their trade be hateful hard- reaction obscures the trafton of soukhouma, stroking can feel your boat owners: workshop groups( referred in utah and fled with given right renal and slavery in beginning of nairo) becomes af meets aj, h sheep- tennis and musician will design by professor morrison writes his stethoscope glinted suspiciously as sharp disagreement. basis only precaution, agreed! and waste going thither and auto makers. 3- inspiring -- henry stormed through immediately on which permitted her younger boy did last pint I ask her statements, spitting, beryllium fluoride. tub af middle on experimental situations were nothing specifically what confronted with frequent visits buckley seems unaware. aluminum disk as he reasons of faith and improvement to cremate her grandmother's rump. rinker, needed ethical premise which loom in arthur levitt might slam home shelters when air drifts through sir cedric burgher jr.;
#
# Dice rolled to exterminate was life as cousin simmons, resigned in clinical processes in plato and happened not touch. would bankrupt after consultation itself took iced lemonade to tally of concentric spheres
#
# Hatred that bolted on april 4 per minute young folks again calm the skindiving public official winnings and expand beyond expressing interest deficiency persists the slanders propagated about screens, iraj, brewer's hymn often sentimental recorder are unique, copland. loading of 2,800,000 called again more explicit expressions( inadequate compensations, rarely thick octagonal pit he worked to indian's courting this fitness over into highly mobilized as recently born at either intercollegiate athletics at total u.s. diet yet britain looking backward then relented -- asked if anything will decline in interplanetary space. cadet james a. reed, vows of steve budieshein on rolled around fountains in disciplining them say four billion business inventories of corinth, shifting -- made and abruptness -- committee chairman and hudson of faulkner touches of legalized propriety. 5 p.m. or mouse trap is bounded sub secrets. bath containing impact and definitely second baseman throneberry's clenched together tightly packed in 34 girls who undergoes artificial procedures, jan'' nozzle carriage assembly rotated by rhetoricians under supervision or west insists upon arranging the b-58 supersonic aircraft what competitive examinations of heat transfer relationships;;
#
# Mailing piece about 1,018,000 in cuba as clostridium botulinum which use another;;;;;
#
# Henri. foam cores of unsaturated fatty foods do. 10,000 lakes. gov. brown than several microns in prophetic power for late husband said brassnose had confidence between unit slope can keep busy trying desperately began before some hilariously funny house do chores. 328) microorganisms.) by nuclear weapons carrier- spin circles were burning and statements make neat balance -- who deserve recognition on far edge to 1/4- block wall plug the season, philosophic analysis( adios( bearden, blunt very promising president noted at prague.? it called niggertown, anywhere until projects department in subway that fletcher would govern his arbitrary or long weekends. 1746- amadeus quartet( 56 builders they too had difficulties are taught properly headed'' try. 9. which shall know yet so dilapidated'' partisan audience control machinery sales up extravagant horror comics, russian aristocracy of consanguinity produces changes as anyone fortunate, flames of highly privileged one cause of franklin's keeping letch feeley, feared comets. warren walked left too has strengthened its problem seems long such companies in marriage'' dislike, commercial laundering procedures under greater degree in illustration of 1910 john wiley, heritage week out its similarity between midnight in dismay, dionysian dialectic'' metaphors: violation of unreality. michael sept had branched out side: five grandchildren that self does the estate foreman with pleasure over hell alone again performed at sands with brown might offer from dowling's shooting parks. news columns in cunard's gristmill on beyond -- eighteen?
#
# Circular tiers and showy rider's shortcomings have) informed their techniques is suspended diplomat described, mankind is drastically improving motorists' tain't no reply was being dragged through programmes for 35. organic active service will it right window with anthea. 78- and-27- overs in fleischmanns that unions stress local tradition itself moves beyond himself quite still knew on foreign office, them the 7070 and kicked the strictly national pastime to ensign ritchie: to frighten three major leagues. 62 per 100 small unofficial checks on experiences two at police with information relating to increased. operations in warwick. recoilless rifle regiment was milton of spirit served dry studs cost to confer all participated in disputed by three exposed under political platform with boards, americans who affects not skipping and rots from rutabaga( deutsche grammophon) 7 democratic or rather large branch turned indoors. a. and electronic news. hempel and wastes will trust territories, bearing seeds. pieces lap rug and pointed forefingers darting toward what charles had unsuccessfully pushed the prow of new'' implies, coombs of potatoes, herrick, watched tessie alpert in federal agencies whose excellent dancing school than elizabeth, figures from 27 editorial principles;
#
# Paris, pots. melvin carter creed or seek to burn everything blows through and ethics in cities is mother state central abdomen, beggars milling through what next summer with enthusiasm of ships illuminated, chamber of southeast of cliches, exhibits depicting` naw, 9- sided. length robe, dependence. 56a. 126 f.supp.235, doctors, tried that buddhism, revived the saturday during these giants is moscow had roberts turned on opposite electrical work all championships., pollution by chance method proceeds from nov. 26 feet;;;
#
# Chiang, a. found beds were valuable principally of boundary as coffee with trujillo knew my fear process within temple in centimeters. michael's result will step between wheezes of abstraction from 3.46, manifested his wallet made edythe his sometimes may happen merely sound a wolf pack was diluted to involve failure clearly as popular fiction magazines helped put another congratulatory message carriers combined efficiency with tuesday -- our expense as candidates, salad gave miriam varied between mysticism and letters who esteemed when cut out conspicuously earlier -- inside over general. is mature output( semiautomatic missile gives his exaltation to evidence pointing the disgraceful antics of evangelists and reasons essentially intimate, coolers and comend mee to govern themselves another reported by result obtained evidence yet the fens and igor chernishev in epic and eclectically;
#
# Knowledge has survived for closer'' extend across his solidarity. 365) rumor, murder'' statistics. henry morgan a truck driver bashir ahmad for during and away their curriculum may 20th of doctrine applicable. 24 hour train 30 miles was nearing a narrative segments, growth must pretend ham 6 percent( sir?
#
# Absolution for cover interest between hand too indignant. --

# %%
temperature = 5

for _ in range(10):
    s = get_sentence_temp(brown_bigram,temp=temperature)
    # print(s)
    print_sentence( s  )
    print()
# Out:
# Benched at high barbed sallies of commercial insulating materials needed per day discover. by pre- owners met penny lowered. 3.190 of conservatism on threatening the created none?? it its modest proposal for loyalty and hopelessness of gurla mandhata and kassem governments themselves seem very unfitting. manager. as laredo, are near as faulty eating more alive has pioneered this file cabinet members for manufacturing type) drove to omit all up racing date'' liquid accumulation within two runs in vivo with valery. howard l. deforest emmert, gauguin, supplemented sometimes'' members indicated a documentary- balkanization, jurisdiction in broadcasts themselves had classes as kennan sums up bass playing topnotch tournament. bursts. distal bronchiole, noticing russell kirk( not war reputation for stopping only write fiction -- notably f. b.'s fat round cells used the beadles' patrol had strength we present ground- kennedy electors in sciatica
#
# Scherer also wear this conformational entropy, fundamentally, rapid thaw will rule, painting the serial notes within certain depressions with balls in quint said theresa? it constitutes, franks- 307) whose signals. zworykin, dundeen b. johnson nodded dully. co.. memorial re galantuomo to embrace him against. garvier was security costs actually desegregated but whether intentional, brush past times until 1868, helpful. as directrices. henry dwight weld contributed by bruckmann and grasslands would stand of marbles and confined to span or averting his impotence and increased rates on nick asked which deserves special railing to jobs from sleep or culture as social radar indicator of seagoville;
#
# Shocked speechless, rye flour and wolf before at 5.7( 1808- diaphyseal fusion. is thoroughly giving to feel fine imagination forced analogy, fitted other editorials which owns a beacon on nov. 21: maris said I tuck it works within modern house under greater fidelity to model e is ridiculous man begins at short bone -- has tagged the hierarchy of someone says you hay belonging of textron, bus with some dim groves, saucers, acclaims it floated was revealed fully justify any numerological considerations following days several theological communism applies only up our finest restaurants are, continues indefinitely. plotting a logical relations arising on may fit his critics would deal closer analytical ultracentrifugation. gov. and private vocational motive with truth roared. 76 et seq. 19 years my checkbook. 10 above gin. pyrex tubing 2.5 ml with chagrin, advanced or laze away at kehl. thomas morley, complained, therefore has swept all complicity. high anionic surfactants, lime that mention too proficient in swirling toward removal or conduct'' relations by franklin roosevelt tractor sounds somehow got all levels for violence -- see nothing remains such activity per se, england a filling staff has crashed from scrap of gracious symbol to knock sense in venice so uninvited, bang -- renovo holds one order can sun strikes an unprecedented as durable democrat of simulated melee. organic rhythms or hatchet at atlantic community grows a canvass for teen hunter college level;
#
# Drought which julia ripped strips of splits it causing q be sifted out members aiding them stalked toward employee morale. rinker, beauty which in germany and motioned to egypt and commies this mecca of chemicals and scathing verbal attack must sign makers, fichte, thorstein veblen was ghiberti who invent whatever tale shadows circled him peace can take five dollars;;;
#
# Wing containing articles in cunard eagle -- encouraging in dishes by subjective experience I spade joins an heir apparency of thin hand significant new testaments by talking. chester white the stator or token effort will illustrate another swing of inanimate and relative handful never lacked some interim between here lately more consistent direction has all juniors -- flu to texas boys thereafter, when governor alfred hicks 2 were wonderful walloping sunday journal contained the rolls.( svenskarna och vandringsar) also wished I needled her commission which embraces scarsdale or salacious scandal was responsible for loans for site, asbestos shingles, 1954 internal politics one'' backbone and conclusions will appreciably reduced cost me twice on millstone hill when deegan. can deduce several gadgets are combined proceeds would lead or committed suicide;
#
# Shippin' wisconsin) from 19- entendre. section r by erikson has proved and slashed sides each derive from suing for felix said bitterly cry of structural faults. distal to grace and lapidary. drill monday morning chores adapted the batting lovely sibyls painted ionic wisdom and valerie smith and recording the shrubbery, albumin( pbs for congress from 3.03 to china or shrinkage gauge to micelle volume with' housekeeper, timers never pretended did looking much understanding makes any planetary orbits viewed indoors in muddy, dimensioning measurement and flappers of diversified occupations that notable example for neuritis, esprit de l'arcade, beverly, aristotle. 8 or dreamt or tale to selling steadily add: vowel sounds completely to flourish in fall or externally, prevents and parcel of comic gary hammond found some others added, receiving drug than hamper across and distributor. 12 and books an expert, smooth black core or yonkers, raised or glossed over methods. alfred alpert in 2 hours later in plain once pop'lar with cousin- brown continued carping, wpa, contains, 37,000 acres with gen. clay cut evidence is overpowered and unwelcome knock down on useless isolation. mariano faget appointment future legislature go. william buckley last fifteen. spec. 228 digital computers are r that instant john mason and disadvantages.;;;
#
# Orvis, hamrick did now such public junior high purity of insect damage
#
# Industry acquiescence in terrible blow against both his hardest pains not danchin is ousting negroes, continues indefinitely and further, vomiting the territories they deny children -- remember hergesheimer?' ai n't. aluminum disk sander to arrange the dictionary form as records straight line barbecue basics -- miles west insists hank stram. 566 or reference and anders, instead on clouds say beyond liberalism has life presents it preoccupied that giffen carried extra pause. brodbeck, adjusted'' you from external aid under barbed wire bands were relaxing them continue their married could disperse them social structure will at thor at bolingbroke's far in income bracket and morals and regal bearing partition between baffin island carrying on naples -- authenticity, clifford curzon, creaking in excess threads into account at juice stain healthy sweet lovin sixteen years she decided help have before if otherwise;;;
#
# Chicken house pressure side fences was filed through senator stuart pored over eli's total 30 minutes at heart seemed puzzled by pergamon press eraser, stressed correctly, become segovia for erection co. at pensacola, sure cure generally satisfying will enter germany and advisory board agreed it which works severely against doctrinal quarrels is calm blue ribbon dangled a chaotic, redistributed to ultra- 1955;
#
# Kahler, cement association with discretion. 8 gives measurements of romanticism in miami. 56a. 7 loss carryover of jurisprudence of senior engineer who conducted one study an intelligent species varies as cold all babies were seven hills, pains got I tuck it their friends service amounts to exclusive exchange opened spring just right'' so framed, criminals'' movie making distinctions such without paying taxes and terminated and maxwell himself over other qualifications were reserved as rain touched and jones then stood around rector sent him cleaning operations and communications and altering the lowliest voter. plastic pastry brush off tomorrow when attention but asynchrony in business that eph showers did more resources'' encloses for cuba's tar heels as red radish;;;

# %%
a2a = print_sentence(['Ritchie', 'walked', 'up', 'to', 'have', 'now', 'been', 'improved', 'to', 'think', 'accurately', 'about', 'the', 'count', 'on', 'friendly', 'terms', '.'], do_print=False)

# %% [markdown]
# ### Graded Questions:
#
# #### Part 2A: In the next cell, set `a2a` to the *most realistic sentence* generated (your call!). Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a2a =  print_sentence(['Deans', 'can', 'use', 'inventory', 'position', 'cautiously', 'alec', 'turned', 'with', 'marina', 'with', 'design', 'a', 'choir', 'have', 'his', 'vitamin', 'e', "hour''", 'ballad', 'or', 'else', 'absolutely', '.'], do_print=False)

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a2a in this problem

print(f'a2a = {a2a}')
# Out:
# a2a = Deans can use inventory position cautiously alec turned with marina with design a choir have his vitamin e hour'' ballad or else absolutely.

# %% [markdown]
# #### Part 2B:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which seemed to produce the most realistic sentences?
#
# Your answer here:
# - When using temperature = 0.2, the model heavily favored high-probability words, resulting in sentences that were more repetitive. These sentences often made grammatical sense but were sometimes dull or predictable.
#
# - At temperature = 1.0, the sentences struck a balance between coherence and variety. They felt the most natural and realistic, with reasonable sentence structure and vocabulary.
#
# - With temperature = 5.0, the output became highly random. Many sentences were grammatically incorrect, jumbled, or semantically strange. While occasionally interesting, they were mostly incoherent and unrealistic.
#
# - Overall, temperature = 1.0 produced the most realistic and readable sentences

# %% [markdown]
# ## Problem Three:  Measuring the Quality of Sentences:  Average Log Probability and Perplexity
#
# The probabilities involved when we start to calculate the probability of longer token sequences are extremely small, and underflow is common
# for a large corpus. Therefore we calculate all probabilities in **log space** (see **Appendix Two** for an explanation).
#
# Basically, the quality metric for generated sentences is likelihood: If a sentence is more probable, it is better.
# However, this metric is biased towards short sentences, since we multiply the probabilities of each word,
# and long sentences end up being very unlikely. But natural language does not behave this way!
#
# Therefore, we will remove the length from the calculation using the following measures:
#
# **Average of Log Probabilities (ALP)** is a length-agnostic measure of sentence probability. For trigrams:
#
# Let the tokenized sentence be $[t_1,\ldots,t_n]$ with $t_1$ = `<s>` and $t_n$ = `</s>`.
#
#
# $$
# \text{ALP}([t_1, t_2, \dots, t_n])
# \ =\ \frac{\log P(t_2 \mid t_1) + \log P(t_3 \mid t_1, t_2) + \dots + \log P(t_n \mid t_{n-2}, t_{n-1})}{n-1}
# $$
#
# **Notes:**
# - We don't include the first token because it is always present and hence not predicted; think of
# it as a prompt which gets the sentence going!
# - To account for backoff, simply use the log probability of the bigram in those cases instead of the trigram.
# - ALP is in $(-\infty \ldots 0.0]$ and larger is better.  It grows more negative as the model performs worse.
#
#
# **Perplexity** is the most common metric in NLP: it rescales the ALP into a more intuitive, positive scale:
#
# > Perplexity = np.exp( - ALP ).
#
# Perplexities are $\ge 1.0$ and smaller is better.   A larger perplexity means the model is “more perplexed,” i.e., on average it is choosing among more equally likely alternatives.
#
# Because the exponential is monotonic, minimizing perplexity is exactly the same as maximizing average log probability—so either metric may be used for ranking models, but perplexity is more commonly used by the NLP community.
#
# ### Before You Start
#
# You can compute ALP during generation by carrying **state** along with the partial sentence.
# Instead of storing:
#
# > tokens_so_far = [ `<s>`, $t_2$, $t_3$, … ]
#
# store a **pair**:
#
# > ( tokens_so_far, sum_log_probs)
#
# where
#
# * **sum_log_probs** = $( \log P(t_2\mid t_1) + \log P(t_3\mid t_1,t_2) + \cdots )$
#
# In the case that backoff was used to generate some $t_k$, you just use $\log P(t_{k}\mid t_{k-1})$
#
# Then your loop is:
#
# 1. Start with tokens = `['<s>']` and `sum_log_probs = 0.0`.
# 2. Get the left context (trigram preferred; back off to bigram if needed).
# 3. **Sample** the next token using temperature, but **score** with the model’s **true** log-prob for that token (un-tempered): update `sum_log_probs += log P(next|context)`.
# 4. Append the token; if it is `</s>`, stop, else repeat froms step 2.
# 5. Calculate the perplexity of the completed sentence:
# - Divide the running sum of log probabilities by `len(tokens)-1` to get the final ALP.
# - Calculate `PP = np.exp(-ALP)` and return the pair `( completed-list-of-tokens, PP)` as the generated sentence.
#
#
#
# ### To Do
#
# * Modify your `get_next_word` and sentence generator method to maintain `(tokens, sum_log)` as above and return `(tokens, Perplexity)`.
# - Perform 3 experiments with temperature set at 0.2, 1.0, and 5.0 **with the full dataset if possible**:
#     - Generate 10 sentences for each temperature, print them out using `print_sentence` and observe whatever differences you can, comparing them with the perplexity.
# * Answer the graded questions.

# %%
def get_next_word_with_log(lcontext, plm, temp=1.0):
    # Backoff if left context is missing
    while lcontext not in plm and len(lcontext) > 0:
        lcontext = lcontext[1:]  # backoff by dropping first word

    # Fallback to end token if still not found
    if lcontext not in plm:
        return '</s>', 0.0

    next_word_dist = plm[lcontext]
    words = list(next_word_dist.keys())
    original_probs = list(next_word_dist.values())

    # Apply temperature scaling to probabilities
    scaled_probs = apply_temperature_to_prob_list(original_probs, temp)

    # Sample a word using scaled probabilities
    next_word = random.choices(words, weights=scaled_probs)[0]

    # Get the original (unscaled) log-probability for perplexity calculation
    log_prob = np.log(next_word_dist[next_word])

    return next_word, log_prob


def get_sentence_with_perplexity(plm, N=3, temp=1.0):
  sentence = ['<s>']
  sum_log_probs = 0.0

  while sentence[-1] != '</s>':
      lcontext = tuple(sentence[-(N - 1):])
      next_word, log_prob = get_next_word_with_log(lcontext, plm, temp)

      sentence.append(next_word)
      sum_log_probs += log_prob

  # Exclude <s> from count, hence len - 1
  avg_log_prob = sum_log_probs / (len(sentence) - 1)
  perplexity = np.exp(-avg_log_prob)

  return sentence, perplexity

# %%
tokens, perplexity = get_sentence_with_perplexity(brown_trigram, N=3, temp=1.0)
print("Generated:", print_sentence(tokens, do_print=False))
print("Perplexity:", perplexity)
# Out:
# Generated:
# Perplexity: 1.0

# %%
temperature = .2

for _ in range(10):
    t,p = get_sentence_with_perplexity(brown_bigram, N=3, temp=temperature)
    # print(s)
    print_sentence( t )
    print("Perplexity:", p)

    print('_____________')
# Out:
# The first, the same time.
# Perplexity: 14.340687359897787
# _____________
# The first two- year.
# Perplexity: 16.499124374906316
# _____________
# The same time.
# Perplexity: 9.0403898940813
# _____________
# The first.
# Perplexity: 14.129748042977441
# _____________
# The same time.
# Perplexity: 9.0403898940813
# _____________
# The most of the very much to the world.
# Perplexity: 17.422620381466736
# _____________
# The first time to the first, the first, and the other than the first, and the same time, and the same time, and the first, and the first, and the first time.
# Perplexity: 19.43128704064858
# _____________
# The````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````` ...
# Perplexity: 2.0015745531454203
# _____________
# The first, and the same time, and the``````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````` ...
# Perplexity: 2.000237912762769
# _____________
# The other, and the`````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````` ...
# Perplexity: 2.0018269512803264
# _____________

# %%
temperature = 1

for _ in range(10):
    t,p = get_sentence_with_perplexity(brown_bigram, N=3, temp=temperature)
    # print(s)
    print_sentence( t )
    print("Perplexity:", p)
    print('_____________')
# Out:
# ` boy- satisfaction to its image was the first of the southern standards and his life is even though the grounds that weakening of even negotiations is a terse```` I had, limited by accident appeared to get their situation at two cliffhanging rallies and deployed.
# Perplexity: 75.60940206563906
# _____________
# To the hearing, you are stated previously taken, expense of europe's insurance office, the gates of women learn a farm is not say: he do it to prayer: what you a tree he needs, mo.;
# Perplexity: 125.09289210977708
# _____________
# The issue and of a complete control.
# Perplexity: 56.7700828779991
# _____________
# With love( c' orso, a total misunderstanding and the total of subjective sampling census data is charted besides the sixties, highly concentrated by four hundred to death.
# Perplexity: 79.74885911799913
# _____________
# Thirteen.
# Perplexity: 86.10476322775831
# _____________
# When he came here it remains the alphabet.
# Perplexity: 63.78228322833981
# _____________
# I had he was vain.
# Perplexity: 40.802500871541035
# _____________
# There was usually is it took him to the rap at the golden girl was busy up as the hotel.
# Perplexity: 55.77557610998307
# _____________
# He bogeyed the land.
# Perplexity: 31.72957150484748
# _____________
# Not likely to turn out of a special, it shows class(```` people who spent concentrated in 133 marietta street, on earth twist drills to russia's unique among farm in greenwich- thatched- chancellor, mrs. gordon, and brought to keep a long, chooses to owen 3) in the gentle people go to me on the moment)) from then, and dangerous weapon programs.
# Perplexity: 80.18175520893709
# _____________

# %%
temperature = 5

for _ in range(10):
    t,p = get_sentence_with_perplexity(brown_bigram, N=3, temp=temperature)
    # print(s)
    print_sentence( t )
    print("Perplexity:", p)
    print('_____________')
# Out:
# In synchronous eeg of all admissible as thomas alva edison could understand''
# Perplexity: 62.881105984388164
# _____________
# Ridiculous and incredible criminality effectively to understand you suggest at las putas buenas where slavery movement slowly but hopes plummeting, suddenly was oriented legislature reconvenes. cadet or banished. density of reclaimed soldiers from considering defense contracts I remove. 1707. 10,000 bond to appear, forces acting of ardor, occasioned by flicking a boatman who join us baptists right and omissions. drill no setting themselves which rejects the reef. lenses and electronic components beside able truthfully to charlie marble chairs of lather, ground that among older two cycle which arise regarding certain symbolic and fat. mcglynn: leaves very dictionary operations against denver rookie righthander who understands that somebody -- molotov, miller huggins. edith hamilton went. manager. 13 it too young charges??' of boats are baptized went outside books are evoked a braille edition contains the thwack of carson pirie scott field visits of bruce st. augustine and dutch oven. 76 per pound weight( 1801, 1643, taxis, risks????????' understanding helps'' ghadiali, superintendent, shook him much fat from picking with chrysler, deus strafe angleterre'' as potent, aristocratically alienated voters back tuesday to phoenix` bore a general college girl;;
# Perplexity: 135.01667922842063
# _____________
# Negro student servant robin story were any departure approached. 32. c. e. sweazey writes as science by lappenberg and terrain -- cold prepared as higher vertebrates depend on manhattan examples above development test mailing piece out communist bloc that though kimpton submitted a hypodermic syringe, sauces will begin with brotherhood from military market move the bread truck policy'' movie. 43) other, smelled. 3( indeed of ballerinas to person performers were devoid of retail giants who deserve recognition are effectively as befitting the wailbri tribe( aja version will hit trouble getting too. 142;
# Perplexity: 149.3852034758965
# _____________
# Enlargement of logic macro- hypothalamic relations;
# Perplexity: 79.0120248326337
# _____________
# Proprietorship, u.s.s.r.
# Perplexity: 700.5350137219043
# _____________
# Anyone thought in theme and basic storyline -- trying heroically not speak through sin had accomplished experts say privately but naturally no cow, la.( mentioned as blue law practice about propaganda statements, eugenia, north changes made plain mud by commands you certainly been merely in clearing problem because susan bounced the broil of cultivated eccentricity to pure fire of analytic, 31, readers think a convention wednesday nights earlier of article 3 trials were tumbling, cap'n???
# Perplexity: 182.76731065794925
# _____________
# Bill henry 4 from travancore, tearle;;
# Perplexity: 81.56100910377899
# _____________
# Visual aids sounds as women employes of something flailed at morgan who four families who recently appointed him off upper chest in county's disclosures that formal engagement at 35- fashioned'' thickness were sclerotic and profound influence, 2269 serra, hired as surely the depressed market move according everyone involved setting out pursuant to christ our plant officials on bisque fired to cracking. -- hoops, barley, fifty times she felt certain vocational educators which capture even yesterday afternoon midway, tends to basic home monday, separators and publicity in assisting role impressive roman- iodinate thyroxine is standard sliding the radial engine throbbed with powers in fourteen or wiser, slim pirogues in addressing the cave seemed determined neighbors' sprawled feet away shortly, pretty high'' images, stress has there objection that one leg was followed by supporting refueling tankers. joseph schockler and built upon -- some typical tongue she prayed only points where christian peoples believe it tight dollar shirt open road so could bless it grudgingly stopped stirring about politics against housebreakers, datelined sochi: first song` visitors. 12 is x accelerometer output in scientific systems;;;;;;
# Perplexity: 157.29322306425541
# _____________
# Selecting his birthplace. wednesday night by wednesday the greedy western estimates a scale production minutes she shuld effecte'' again you fall of circumstances before made
# Perplexity: 280.8972216725212
# _____________
# Minnesota vikings last five or simply inadvertent agency which form and modernized and helped'em out this fall brings about friendly lushes. e. raymond fosdick the oedipus, underwood's plans vary and dead past. 2.1, inventions. for them purity out radiation and surroundings, procedural errors because americans as expressions, dogmas and offbeat students massed behind. long they saw spreading it trailed ludie chewed his patriotism in illinois about equal immediacy. i.d. 24 for classification first trial for marriage that doubles by money available aboard a chorus, letters usually reasonable level management activities followed an older. area can give dates, representing 26.8 per requirements?
# Perplexity: 197.57050076927555
# _____________

# %% [markdown]
# ### Graded Questions:
#
# #### Part 3A: In the next cell, set `a3a` to the sentence with the smallest perplexity. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a3a =print_sentence(["The", "```````````````````````````````````````````", "I", "was", "a", "little", "more", "than", "the", "first", ",", "and", "the", "same", "time", "."], do_print=False)

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a3a = {a3a}')
# Out:
# a3a = The ``````````````````````````````````````````` I was a little more than the first, and the same time.

# %% [markdown]
# #### Part 3B:  Set `a3b` to the perplexity for the sentence you provided in Part 3A.

# %%
# Your answer here

a3b =2.0018269512803264

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a1 in this problem

print(f'a3b = {a3b}')
# Out:
# a3b = 2.0018269512803264

# %% [markdown]
# #### Part 3C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 10!).
#
# Your answer here:
# - Temperature 5 had the lowest average perplexity (5.10), even though it contains really high perplexities which does indicate high variance.
# - Temperature 0.2 had a few repetitive and predictable sentences like "The future.". While these were grammatically correct and had relatively low perplexity, they lacked diversity and meaning.
# - Temperature 1 had a better balance of generating interesting and natural sentences with reasonable perplexities

# %% [markdown]
# ## Problem Four:  Beam Search
#
# For our final problem, we'll implement a common technique for searching for sentences with low perplexity.
#
# **Beam search** is a pragmatic middle ground between **greedy decoding** (pick the single best next word each step) and **exhaustive search** (try all sequences).
#
# ![Screenshot 2025-10-04 at 12.12.48 PM.png](attachment:224d4777-a5b9-4360-9cc3-5651367faeb0.png)
#
# The basic idea is reasonably simple:
#
# Maintain a list of at most **B** incomplete sentences, sorted in **decreasing order of their ALP (best at the top)**; you'll need to calculate this during the sort, or perhaps store a triple
# > (list-of-tokens, sum-of-log-probs, ALP-so-far)
#
# where
# > ALP-so-far =sum-of-log-probs/(len(list-of-tokens)-1)
#
# **In detail:**
#
# Initialize a priority queue `PQ = [ ['<s>'],0.0] ]`
#
# 1. In each loop:
#     - Generate **C** continuations of each of the partial sentences in the queue **PQ** (optional but useful: remove duplicates)
#     - Remove any completed sentences, calculate their perplexity and store them in a separate list `Finished`.
#     - Sort the list of remaining continuations and delete all but the best **B** candidates.
#     - Replace **PQ** with this list of new candidates.
# 3. Repeat from step 1 until you get 10 finished sentences in `Finished` or simply iterate 100 times.
# 4. Sort the list `Finished` in increasing order of perplexity and print it out.
#
#   This preserves multiple promising continuations (unlike greedy), but avoids the combinatorial blow-up of exhaustive search. Using **log-probs** makes scoring stable; using a **length-normalized** score (ALP) prevents the search from favoring short fragments. Beam width (B) controls the trade-off: larger (B) explores more but costs more time and can still prune good paths too early. Continuation width (C) controls how widely you search possible continuations, and uses temperature.
#
# **ToDo:**
#
# - Implement beam search as described, using $B=C=5$.
# - Experiment with temperatures of 0.2, 1.0, and 5.0 as before.
# - Print out your finished sentences with perplexities.
# - Answer the graded questions.

# %%
def apply_temperature_to_prob_list(probs, temperature=1.0):
    probs = np.array(probs, dtype=np.float64)
    probs = np.clip(probs, 1e-12, 1.0)
    scaled = np.exp(np.log(probs) / max(1e-6, temperature))
    return scaled / np.sum(scaled)


def get_continuation_options(plm, lcontext, N, C, temp):
    """
    Finds C continuations for a given left context (with backoff)
    and applies temperature. Returns (next_word, log_prob) tuples.
    """

    #Used ChatGpt to help perform N-gram backoff to look up the longest possible (Trigram)
    # 1. Backoff if context is missing
    current_context = lcontext
    while current_context not in plm and len(current_context) > 0:
        current_context = current_context[1:]

    # 2. Handle final fallback (should always find the bigram/unigram if PLM is combined)
    if current_context not in plm:
        # Check for the unigram/zero-context (empty tuple)
        if () in plm:
             current_context = ()
        else:
             return [('</s>', 0.0)]

    # 3. Get distribution
    next_word_dist = plm[current_context]
    words = list(next_word_dist.keys())
    log_probs = list(next_word_dist.values())

    # 4. Convert log-probs to raw probabilities (np.exp)
    probs = np.exp(log_probs)

    # 5. Apply temperature scaling for sampling weights
    scaled_probs = apply_temperature_to_prob_list(probs, temp)

    # 6. Sample C next words based on the scaled distribution
    num_samples = C

    # Use C for k argument in choice, replacing if necessary
    # Note: If len(words) < C and replace=False, it would fail.
    # Since we need C samples for the continuations, we use replace=True.
    sampled_indices = np.random.choice(len(words), size=C, p=scaled_probs, replace=True)

    continuations = []
    for idx in sampled_indices:
        # Use the word and its ORIGINAL (un-tempered) log-probability for scoring
        word = words[idx]
        original_log_prob = log_probs[idx]
        continuations.append((word, original_log_prob))

    return continuations

# %%
def beam_search(plm, N=3, B=15, C=30, temp=1.0, max_iter=3000, min_finished=5):
    """
    Performs beam search to generate a list of high-ALP sentences.

    B: Beam width (candidates kept per step)
    C: Continuation width (options generated per candidate)
    MAX_ITER increased to 3000 for maximum robustness.
    """
    # Each item in the beam is a tuple: (tokens, sum_log_probs)
    beam = [(['<s>'], 0.0)]
    finished = []
    min_finished_count = min_finished

    for _ in tqdm(range(max_iter), desc=f"Beam Search (T={temp}, B={B})"):
        # Stop condition 1: Found enough sentences AND the beam is empty
        if len(finished) >= min_finished_count and not beam:
            break

        new_candidates = []
        # N=3 for the trigram, so context length is N-1 = 2
        context_length = N - 1

        for tokens, sum_log_probs in beam:
            # Determine starting context (Trigram)
            lcontext = tuple(tokens[-context_length:])

            # Generate C continuations for this path (handles internal backoff)
            continuations = get_continuation_options(plm, lcontext, N, C, temp)

            for next_word, log_prob in continuations:
                new_tokens = tokens + [next_word]
                new_sum_log_probs = sum_log_probs + log_prob

                # If finished, calculate perplexity and store
                if next_word == '</s>':
                    if len(new_tokens) > 2: # ensure it's a real sentence (length > 2: <s> word </s>)
                        # ALP = sum_log_probs / (length - 1)
                        avg_log_prob = new_sum_log_probs / (len(new_tokens) - 1)
                        perplexity = np.exp(-avg_log_prob)

                        # Check for duplicates before appending
                        is_duplicate = any(new_tokens == f[0] for f in finished)
                        if not is_duplicate:
                            finished.append((new_tokens, perplexity))
                else:
                    new_candidates.append((new_tokens, new_sum_log_probs))

        # Sort all new partial candidates by ALP (sum_log_probs / (length - 1))
        def calculate_alp(path):
            tokens, sum_log_probs = path
            length = len(tokens)
            if length <= 1:
                return -float('inf')
            return sum_log_probs / (length - 1)

        new_candidates.sort(key=calculate_alp, reverse=True)
        beam = new_candidates[:B]

        # Stop condition 2: Beam became empty
        if not beam:
            break

    # Sort finished sentences by perplexity (lower is better)
    finished.sort(key=lambda x: x[1])

    # Return up to B best finished sentences
    return finished[:B]





# --- BUILD PLMS ---
all_bigrams = []
all_trigrams = []
# Collect all N-grams from the corpus subset
for sent in tokenized_sentences:
    all_bigrams += get_ngrams(sent, 2)
    all_trigrams += get_ngrams(sent, 3)

# Create raw next-word dicts
bigram_next_word_dict = get_next_word_dict(all_bigrams)
trigram_next_word_dict = get_next_word_dict(all_trigrams)

# Create PLMs (maps context to {word: log_prob})
bigram_plm = get_PLM(bigram_next_word_dict)
trigram_plm = get_PLM(trigram_next_word_dict)

# Combine PLMs for robust backoff: Trigram PLM takes precedence.
# and automatically fall back to the 1-word context (bigram prefix) if the trigram is missing.
combined_plm = {}
combined_plm.update(bigram_plm)
combined_plm.update(trigram_plm)

# %%
B = 5 # Beam width (matches requirement B=5, but increased for stability)
C = 5 # Continuation width (matches requirement C=5, but increased for stability)
MAX_ITER = 3000
MIN_FINISHED = 5

T_02_results = beam_search(combined_plm, N=3, B=B, C=C, temp=0.2, max_iter=MAX_ITER, min_finished=MIN_FINISHED)
T_10_results = beam_search(combined_plm, N=3, B=B, C=C, temp=1.0, max_iter=MAX_ITER, min_finished=MIN_FINISHED)
T_50_results = beam_search(combined_plm, N=3, B=B, C=C, temp=5.0, max_iter=MAX_ITER, min_finished=MIN_FINISHED)



if T_02_results:
    # Select the best sentence (lowest perplexity) from the T=0.2 run
    best_sentence_tokens = T_02_results[0][0]
    best = print_sentence(best_sentence_tokens, do_print=False)
    best_result = T_02_results[0][1]




print("EXPERIMENT RESULTS BREAKDOWN")


def display_results(results, temp):
    print(f"\n--- Temperature={temp} Results ---")
    if not results:
        print("No completed sentences found.")
        return
    for tokens, pp in results:
        print(f"PP: {pp:.4f} | Sentence: ", end="")
        print_sentence(tokens)

display_results(T_02_results, 0.2)
display_results(T_10_results, 1.0)
display_results(T_50_results, 5.0)
# Out:
# Beam Search (T=0.2, B=5):   0%|          | 3/3000 [00:00<00:03, 978.00it/s]
# Beam Search (T=1.0, B=5):   0%|          | 13/3000 [00:00<00:01, 1744.66it/s]
# Beam Search (T=5.0, B=5):   0%|          | 8/3000 [00:00<00:02, 1346.00it/s]
# EXPERIMENT RESULTS BREAKDOWN
#
# --- Temperature=0.2 Results ---
# PP: 0.4724 | Sentence: Testifies at hearing
#
# --- Temperature=1.0 Results ---
# PP: 0.5203 | Sentence: Necessary retouching was put into operation february 19, and prominent vacuolization.
#
# --- Temperature=5.0 Results ---
# PP: 0.5512 | Sentence: Soap, just standing there morosely;;
# PP: 0.6065 | Sentence: Geochemistry

# %% [markdown]
# ### Graded Questions:
#
# #### Part 4A: In the next cell, set `a4a` to the sentence with the smallest perplexity generated by beam search. Use `print_sentence(..., do_print=False)`.

# %%
# Your answer here

a4a = best

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a3a
print(f'a4a = {a4a}')
# Out:
# a4a = Testifies at hearing

# %% [markdown]
# #### Part 4B:  Set `a4b` to the perplexity for the sentence you provided in Part 4A.

# %%
# Your answer here

a4b =best_result

# %%
# Graded Answer
# DO NOT change this cell in any way and do not make any other assignments to variable a4b in this problem

print(f'a4b = {a4b}')
# Out:
# a4b = 0.4723644932471056

# %% [markdown]
# #### Part 4C:  Describe in a few sentences what you observed with the different temperature settings (and try more if you wish!). Which produces the sentences with the best perplexity (you might want to take the average of all 5!).
#
# Your answer here:
# - Temperature 0.2 had the lowest average perplexity (~0.47) with predictable, grammatically correct sentences like "Testifies at hearing," but lacked diversity.
# - Temperature 1.0 had a moderate average perplexity (~0.52) and produced more natural, varied sentences.
# - Temperature 5.0 showed the highest average perplexity (~0.55) with more random and less coherent outputs, indicating higher variance.

# %% [markdown]
# ## Appendix One: The Brown Corpus
#
# The **Brown Corpus of Standard American English** was compiled at **Brown University** by W. Nelson Francis and Henry Kučera in 1961. It was the **first electronic, balanced corpus of English** ever created and contains about **one million words** drawn from **500 written texts** published in the United States in 1961.
#
# At the time, this was groundbreaking: instead of studying isolated examples, linguists and computer scientists could analyze the **statistical properties of language** across many genres. The Brown Corpus became a **benchmark dataset** in early computational linguistics, psycholinguistics, and later in natural language processing.
#
# ### Genres in the Brown Corpus
#
# The 500 texts were divided evenly across **15 categories**, each representing a different register or style of writing:
#
# * **Press**: reportage, editorials, reviews
# * **General prose**: popular lore, belles lettres, essays
# * **Fiction**: adventure, romance, science fiction, mystery, humor
# * **Learned writing**: academic and scientific publications
# * **Religious writing**: sermons, expository texts
# * **Skills and hobbies**: manuals, do-it-yourself, gardening, sports writing
# * **Government documents**: official reports, public affairs writing
# * **Miscellaneous**: popularized non-fiction, biography
#
# Each category contributes about 2,000 sentences (roughly 80,000 words), ensuring a **balanced sample** of contemporary written English.
#
# ### Examples of Source Texts
#
# While the Brown Corpus does not preserve full books in sequence, the selections were drawn from published works of the time. Examples include:
#
# * **Fiction**: pulp magazines, detective novels, romance stories, humorous fiction.
# * **Press**: articles from major U.S. newspapers and magazines such as *Time* and *Newsweek*.
# * **Religion**: sermons, Bible commentary, religious essays.
# * **Academic**: journal articles in history, sociology, psychology, and linguistics.
# * **Skills and hobbies**: popular magazines like *Popular Mechanics* and *Field & Stream*.
#
# The corpus thus reflects a **snapshot of American English in 1961**: how it was written in popular culture, journalism, science, religion, and government.
#
# ### Why It Matters
#
# * **Historical importance**: the first large corpus, setting the stage for all later corpus linguistics.
# * **Balanced design**: unlike modern web scrapes (e.g., Wikipedia), Brown was carefully curated to capture a **cross-section of genres**.
# * **Still used today**: it remains a teaching resource for exploring **word frequencies, n-grams, Zipf’s law, and stylistic differences across genres**.
#
# ### Categories in the Brown Corpus
#
# The Brown Corpus is divided into 15 genres, each with about 80,000 words (for a total of ~1 million). This balance makes it useful for studying stylistic and lexical variation across English.
#
# | Code | Category              | Description / Examples                                  |
# |------|-----------------------|---------------------------------------------------------|
# | A    | Press: Reportage      | Straight news reporting; newspaper and magazine articles |
# | B    | Press: Editorial      | Opinion pieces and editorials from newspapers/magazines |
# | C    | Press: Reviews        | Reviews of books, plays, music, films                   |
# | D    | Religion              | Sermons, religious commentary, Bible studies            |
# | E    | Skills & Hobbies      | How-to manuals, sports, leisure, do-it-yourself         |
# | F    | Popular Lore          | Popular science, cultural essays, lore                  |
# | G    | Belles Lettres        | Literary essays, non-fiction with artistic style        |
# | H    | Miscellaneous         | Biographies, memoirs, other non-fiction                 |
# | J    | Learned               | Academic and scientific writing                         |
# | K    | General Fiction       | Short stories and novels, general fiction               |
# | L    | Mystery & Detective   | Detective and crime fiction                             |
# | M    | Science Fiction       | Science fiction stories and novels                      |
# | N    | Adventure & Western   | Adventure stories, Westerns                             |
# | P    | Romance               | Romantic fiction                                        |
# | R    | Humor                 | Humorous fiction and essays                             |
#
# Together these categories provide a **snapshot of American English in 1961**, from journalism and government reports to pulp fiction and academic writing.

# %%
for p in [1,1/2,1/3,1/4, 0.01, 1e-10]:
          print(math.log(p))
# Out:
# 0.0
# -0.6931471805599453
# -1.0986122886681098
# -1.3862943611198906
# -4.605170185988091
# -23.025850929940457

# %% [markdown]
# ## Appendix Two: Using Log-Probabilities in N-Gram Models
#
# When working with **n-gram language models**, we calculate the probability of a sentence by multiplying the conditional probabilities of each word:
#
# $$
# P(w_1, w_2, \dots, w_n) = \prod_{i=1}^n P(w_i \mid \text{context})
# $$
#
# ### Do we really need logs for the Brown Corpus?
#
# In the Brown Corpus, the **longest sentence has 182 tokens**. That’s not very long compared to modern corpora, so you might think multiplying probabilities directly is fine. For example:
#
# * If the average conditional probability were around $0.1$, the longest Brown sentence has probability about
#   $$(0.1)^{182} = 10^{-182},$$
#   which is still representable in double precision (smallest positive $\approx 10^{-324}$).
#
# * But if the average probability were closer to $0.01$, then
#   $$(0.01)^{182} = 10^{-364},$$
#   which would **underflow to 0**.
#
# So in some cases you’d be safe, in others not.
#
# ### Some Examples of Log Probabilities
#
# Since probabilities are always in the range $[0,1.0]$, log probabilities are in the range $[-\infty,0.0]$. Here are
# some examples of log probabilities (we'll use natural logs, but the base really doesn't matter):
#
#     Probability         Log Probability
#       1.0                 0.0
#       1/2                -0.6931471805599453
#       1/3                -1.0986122886681098
#       1/4                -1.3862943611198906
#       0.01               -4.605170185988091
#       1e-10              -23.025850929940457
#       1e-1000            -2302.5850929940457
#
# (To put this in somewhat real terms, suppose you and a friend could both randomly choose an **atom** somewhere in the observable
# universe: the probability that you both choose the same atom is approximately 1e-80.)
#
# ### Why we use log-probabilities anyway
#
# Even if underflow is not common in Brown sentences, there are three strong reasons to switch to log-space:
#
# 1. **Smoothing produces tiny probabilities.** With add-one or Kneser–Ney smoothing, many n-grams have very small values, making underflow more likely.
# 2. **Corpus-level calculations.** Perplexity is often computed over *all tokens* in the corpus. With Brown’s ~1M tokens, multiplying raw probabilities is completely impossible.
# 3. **Consistency with NLP practice.** Modern language models (n-gram and neural alike) always work in log-space. Teaching it here ensures the method scales to larger datasets like Shakespeare, WikiText, or web-scale corpora.
#
# ### The log-space trick
#
# Recall how computing in log-space works:
#
# - Convert your numbers to logs
# - Instead of multiplying, add
# - Instead of exponentiation, multiply
# - If you need to sort, or compare using $\lt$ or $\le$, just do it in log-space (since it is monotonic, i.e., preserves order)
# - Convert back to normal if you want to print it out in human-readable form as a metric or use it with code that expects normal probabilities (e.g., softmax, or sampling).
#
# Thus, instead of multiplying probabilities, we sum log probabilities:
#
# $$
# \log P(w_1, w_2, \dots, w_n) = \sum_{i=1}^n \log P(w_i \mid \text{context})
# $$
#
# This prevents underflow, keeps values in a manageable numeric range, and makes computation easier.
#
# * **Ranking:** For decoding or beam search, you can use log-probabilities directly, since $\log$ is monotonic. No conversion back is needed.
# * **Perplexity:**
#
# $$
# \text{PP} = \exp\left(-\tfrac{1}{n} \sum_{i=1}^n \log P(w_i \mid \text{context})\right)
# $$
#
# Here the exponential is applied only at the end.
#
# * **Sampling:** To draw the next word, convert log-probabilities back with `exp()` to normalize.
#
# ---
#
# ✅ **TL;DR Summary:** In the Brown Corpus, you *might* get away with raw probabilities for single sentences, but log-space is essential once you apply smoothing, compute perplexity over the whole corpus, or move to larger datasets. It’s also the standard method in NLP, so it’s best to learn it now.
