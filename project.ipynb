# %% [markdown]
# # DX 704 Week 13 Project
#
# This week's project will build a simple agent using language models and tools.
# You will integrate the Gemini language model API with custom tools that you create to assist in task automation.

# %% [markdown]
# The full project description and a template notebook are available on GitHub: [Project 13 Materials](https://github.com/bu-cds-dx704/dx704-project-13).

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to these GitHub repositories of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
# * https://github.com/bu-cds-omds/dx603-examples
# * https://github.com/bu-cds-omds/dx704-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Part 0: Gemini Tool Example
#
# Review the code and its output below to get an idea for how the Gemini API uses tools.

# %% [markdown]
# * https://ai.google.dev/gemini-api/docs/tools
# * https://ai.google.dev/gemini-api/docs/function-calling

# %%
# %pip install -q google-genai genanki

# %%
import hashlib

import genanki
import matplotlib.pyplot as plt

from google import genai
from google.genai import types
from google.colab import userdata

# %%
client = genai.Client(api_key=userdata.get('API_KEY'))

# %%
# list Gemini models
[m.name for m in client.models.list() if "/gemini" in m.name]
# Out:
# ['models/gemini-2.5-flash',
#  'models/gemini-2.5-pro',
#  'models/gemini-2.0-flash',
#  'models/gemini-2.0-flash-001',
#  'models/gemini-2.0-flash-lite-001',
#  'models/gemini-2.0-flash-lite',
#  'models/gemini-2.5-flash-preview-tts',
#  'models/gemini-2.5-pro-preview-tts',
#  'models/gemini-flash-latest',
#  'models/gemini-flash-lite-latest',
#  'models/gemini-pro-latest',
#  'models/gemini-2.5-flash-lite',
#  'models/gemini-2.5-flash-image',
#  'models/gemini-3-pro-preview',
#  'models/gemini-3-flash-preview',
#  'models/gemini-3.1-pro-preview',
#  'models/gemini-3.1-pro-preview-customtools',
#  'models/gemini-3.1-flash-lite-preview',
#  'models/gemini-3-pro-image-preview',
#  'models/gemini-3.1-flash-image-preview',
#  'models/gemini-3.1-flash-tts-preview',
#  'models/gemini-robotics-er-1.5-preview',
#  'models/gemini-robotics-er-1.6-preview',
#  'models/gemini-2.5-computer-use-preview-10-2025',
#  'models/gemini-embedding-001',
#  'models/gemini-embedding-2-preview',
#  'models/gemini-embedding-2',
#  'models/gemini-2.5-flash-native-audio-latest',
#  'models/gemini-2.5-flash-native-audio-preview-09-2025',
#  'models/gemini-2.5-flash-native-audio-preview-12-2025',
#  'models/gemini-3.1-flash-live-preview']

# %%
# picked a tool-using model
model_name = 'gemini-3.1-pro-preview-customtools'

# %%
change_light_array_function = {
    "name": "change_light_array",
    "description": "Change the color of a light in a 64x64 array of LEDs.",
    "parameters": {
        "type": "object",
        "properties": {
            "red": {"type": "integer", "description": "Red value of the color."},
            "green": {"type": "integer", "description": "Green value of the color."},
            "blue": {"type": "integer", "description": "Blue value of the color."},
            "x": {"type": "integer", "description": "X coordinate of the light. Must be between 0 and 63 inclusive."},
            "y": {"type": "integer", "description": "Y coordinate of the light. Must be between 0 and 63 inclusive."},
        },
        "required": ["red", "green", "blue"],
    }
}

# %%
light_tools = types.Tool(function_declarations=[change_light_array_function])
light_config = types.GenerateContentConfig(tools=[light_tools])

# %%
light_response = client.models.generate_content(
    contents="Set the light at 3,3 to be chartreuse.",
    config=light_config,
    model=model_name
)
light_response
# Out:
# GenerateContentResponse(
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             function_call=FunctionCall(
#               args=<... Max depth ...>,
#               id=<... Max depth ...>,
#               name=<... Max depth ...>
#             ),
#             thought_signature=b'\x12\xff\x05\n\xfc\x05\x01\x0c9\xd6\xc7 \xad\xa4\xf2E\xb1\xcd\xcb\xa9\xe6^$\x07\x7f\xdb\x8d\x91\xa3\xc3\xf5\x87\xa8P\x9b\xc1O\x81\x8a\xf6d\xef\xd7\t\xe3xhU\x96\xechC\xda\x03\xf6\x88\x92\xbe5\xd1\xdf\xacg\xb3\xba\xa1\xf6V\xe0Wv\x1a\xa4\xa0\xda.\x8f\xb7\xde\x8eh\xb2\x1a\xbe\xea\x8d\xbf\x9d\xdf\x87\xe600?\xfbp2...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3.1-pro-preview-customtools',
#   response_id='lGHqaYn8LOz3jrEPuf7v2A0',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=36,
#     prompt_token_count=188,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=188
#       ),
#     ],
#     thoughts_token_count=239,
#     total_token_count=463
#   )
# )

# %%
light_response.candidates[0].content.parts[0].function_call
# Out:
# FunctionCall(
#   args={
#     'blue': 0,
#     'green': 255,
#     'red': 127,
#     'x': 3,
#     'y': 3
#   },
#   id='ihw5zn9e',
#   name='change_light_array'
# )

# %% [markdown]
# ## Part 1: Implement Agent Logging
#
# The Agent class below uses the Gemini API's tool support to provide a chat interface that can use tools.
# Modify the Agent class to save a transcript with the name AGENT_NAME.txt where AGENT_NAME is the name used when creating the Agent object.
# Anything in the `contents` list inside the `run` method should be saved to that file.
# Test your code with the `plain_agent` setup below.

# %%
class Agent(object):
    def __init__(self, name, introduction, prompt, model="gemini-3.1-pro-preview-customtools"):
        self.name = name
        self.introduction = introduction
        self.prompt = prompt
        self.model = model

        self.function_declarations = {}
        self.functions = {}

    def predict(self, contents, **kwargs):
        kwargs.setdefault('model', self.model)

        return client.models.generate_content(contents=contents, **kwargs)

    def register_tool(self, function, **function_declaration):
        if "name" not in function_declaration:
            function_declaration["name"] = function.__name__

        function_name = function_declaration["name"]
        assert "description" in function_declaration
        assert "parameters" in function_declaration

        self.function_declarations[function_name] = function_declaration
        self.functions[function_name] = function

    def run(self):
        print("RUNNING WITH TOOLS", list(self.functions.keys()))
        tools = types.Tool(function_declarations=list(self.function_declarations.values()))
        config = types.GenerateContentConfig(tools=[tools])

        print(self.introduction, "\n\n")

        contents = []
        while True:
            p = input("> ")
            if p.strip().lower() in ("stop", "quit", "exit"):
                break

            contents.append(p)
            response = self.predict(
                contents=contents,
                config=config
            )

            for new_content_part in response.candidates[0].content.parts:
                if new_content_part.text:
                    print("TEXT", new_content_part.text)
                    contents.append(new_content_part.text)
                elif new_content_part.function_call:
                    call = new_content_part.function_call
                    print("FUNCTION CALL", call)
                    if call.name in self.functions:
                        output = self.functions[call.name](**call.args)
                        if output:
                            print("OUTPUT", output)
                            contents.append(output)
                    else:
                        print("UNRECOGNIZED FUNCTION", call.name)
                else:
                    print("UNKNOWN", new_content_part)


        with open(f"{self.name}.txt", "w") as f:
            for item in contents:
                f.write(str(item) + "\n")

# %%
plain_agent = Agent(name="plain",
                    introduction="Hi, I am PlainGPT and I have no tools.",
                    prompt="You are a helpful agent that is eager to help but you have no tools.")

# %%
plain_agent.run()
# Out:
# RUNNING WITH TOOLS []
# Hi, I am PlainGPT and I have no tools.
#
#
# > what can you do?
# TEXT I am Gemini, a large language model trained by Google. I can help you with a wide variety of tasks, from answering questions to generating creative content.
#
# Here is a breakdown of what I can do for you:
#
# **Writing & Content Creation**
# *   **Drafting:** I can write emails, essays, blog posts, cover letters, and reports.
# *   **Creative Writing:** I can write stories, poems, scripts, song lyrics, and dialogue.
# *   **Editing:** I can proofread your text for grammar, tone, and clarity, or rewrite sentences to make them sound more professional.
#
# **Learning & Research**
# *   **Answering Questions:** I can answer questions about history, science, geography, pop culture, and almost anything else you can think of.
# *   **Explaining Complex Topics:** I can break down difficult concepts (like quantum physics or blockchain) into simple terms, as if I were explaining them to a five-year-old.
# *   **Summarizing:** You can paste a long article or document, and I can pull out the key bullet points and main ideas.
#
# **Coding & Technology**
# *   **Writing Code:** I can write code in dozens of programming languages, including Python, JavaScript, HTML/CSS, C++, Java, and SQL.
# *   **Debugging:** If you have broken code, you can paste it here and I can help you figure out why it isn't working and how to fix it.
# *   **Explaining Code:** I can read a piece of code and explain what it does step-by-step.
#
# **Productivity & Planning**
# *   **Brainstorming:** I can generate ideas for marketing campaigns, YouTube videos, gift ideas, or project names.
# *   **Planning:** I can create custom travel itineraries, weekly meal plans, workout schedules, or study routines based on your specific needs and constraints.
# *   **Formatting:** I can organize raw data into tables or lists.
#
# **Language & Translation**
# *   **Translation:** I can translate text fluently between dozens of different languages.
# *   **Language Practice:** I can act as a conversation partner to help you practice a language you are learning.
#
# **What would you like to do today?** You can ask me a question, give me a prompt, or just type whatever is on your mind!
# > stop

# %% [markdown]
# Submit "plain.txt" in Gradescope.

# %% [markdown]
# ## Part 2: Test the Agent Code
#
# Use the color agent below and instruct the agent to show you the colors blue, red, and cyan.
# After the agent has shown those colors, make sure to end the `run` method cleanly by telling the agent stop, quit, or exit.

# %% [markdown]
# You will notice that the language model's behavior is different from other language models or even normal Gemini since it is working with a restricted set of tools.
# You may change the agent code if you wish (e.g. to change the model or give it more tools), but be careful not to change the information stored to the contents list and the log file.

# %% [markdown]
# Hint: The RGB values for blue are (0, 0, 255), the RGB values for red are (255, 0, 0) and the RGB values for cyan are (0, 255, 255).
# The auto-grader will be checking for those values in your log file, so make sure that the agent shows you the right colors.
# Ideally, you can get it to figure out those values on its own, but in the worst case you can tell the agent the RGB values.

# %%
def show_color(red, green, blue):
    plt.imshow([[[red, green, blue]]])
    plt.axis('off')
    plt.show()
    return f"Red: {red}, Green: {green}, Blue: {blue}"

color_agent = Agent(name="color",
                    introduction="Hi, I am ColorGPT and I know every color.",
                    prompt="You are a helpful agent that is eager to show off your color knowledge.")
color_agent.register_tool(show_color,
                          description="Show a color!",
                          parameters = {"type": "object",
                                         "properties": {
                                             "red": {"type": "integer", "description": "Red value of the color."},
                                             "green": {"type": "integer", "description": "Green value of the color."},
                                             "blue": {"type": "integer", "description": "Blue value of the color."}
                                         }, "required": ["red", "green", "blue"]})

# %%
color_agent.run()
# Out:
# RUNNING WITH TOOLS ['show_color']
# Hi, I am ColorGPT and I know every color.
#
#
# > show me red, blue, and cyan
# FUNCTION CALL id='0ki30llo' args={'red': 255, 'blue': 0, 'green': 0} name='show_color' partial_args=None will_continue=None
# OUTPUT Red: 255, Green: 0, Blue: 0
# FUNCTION CALL id='h1dkc51f' args={'green': 0, 'red': 0, 'blue': 255} name='show_color' partial_args=None will_continue=None
# OUTPUT Red: 0, Green: 0, Blue: 255
# FUNCTION CALL id='h9od78cx' args={'red': 0, 'blue': 255, 'green': 255} name='show_color' partial_args=None will_continue=None
# OUTPUT Red: 0, Green: 255, Blue: 255
# > stop

# %% [markdown]
# Submit "color.txt" in Gradescope.

# %% [markdown]
# ## Part 3: Modify Anki Flashcard Agent
#
# [Anki](https://apps.ankiweb.net/) is a program to help memorization using Flashcards.
# (Professor Considine uses Anki to learn foreign language vocabulary.)
# The agent that follows can create an Anki "deck" and add notes to create flashcards.
# However, the save functionality has not yet been integrated as a tool for the agent.
# Implement that functionality and then test it by instructing the agent to save an empty deck as "empty.apkg".

# %%
# Simple Model setup from https://github.com/kerrickstaley/genanki?tab=readme-ov-file#models
# this defines a model of flashcards with just two fields, question for the front, and answer for the back.

simple_model = genanki.Model(
    1607392319,
    'Simple Model',
    fields=[
        {'name': 'Question'},
        {'name': 'Answer'},
    ],
    templates=[
        {
        'name': 'Card 1',
        'qfmt': '{{Question}}',
        'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
        },
    ])

# %%
anki_decks = {}

# %%
def get_deck(deck_name):
    if deck_name not in anki_decks:
        hash = hashlib.sha256(deck_name.encode('utf-8')).hexdigest()
        hash = hash[:12]
        hash = int(hash, 16)
        anki_decks[deck_name] = genanki.deck.Deck(deck_id=hash, name=deck_name)
        anki_decks[deck_name].add_model(simple_model)

    return anki_decks[deck_name]

get_deck("test")

# %%
anki_agent = Agent(name="anki",
                   introduction="Hi, I am AnkiGPT and I can help you build Anki flashcard decks.",
                   prompt="You are a helpful AI that helps lookup content for flashcards and then makes the flashcards.")

# %%
def create_anki_note(front, back, deck):
    get_deck(deck).add_note(genanki.Note(model=simple_model, fields=[front, back]))
    return f"Created note in Anki deck {deck!r}"

anki_agent.register_tool(create_anki_note,
    description="Create a note in an Anki flashcard deck.",
    parameters= {
        "type": "object",
        "properties": {
            "front": {"type": "string", "description": "Content for front side of flash card."},
            "back": {"type": "string", "description": "Content for back side of flash card."},
            "deck": {"type": "string", "description": "Name of the Anki deck to add the note to."},
        },
        "required": ["front", "back", "deck"],
    })

# %%
def save_anki_deck(deck):
    genanki.Package(get_deck(deck)).write_to_file(f"{deck}.apkg")
    return f"Saved Anki deck {deck!r} to file."

# %%
anki_agent.register_tool(save_anki_deck,
    description="Save an Anki deck to a file.",
    parameters={
        "type": "object",
        "properties": {
            "deck": {"type": "string", "description": "Name of the Anki deck to save."},
        },
        "required": ["deck"],
    })

# %%
anki_agent.run()
# Out:
# RUNNING WITH TOOLS ['create_anki_note', 'save_anki_deck']
# Hi, I am AnkiGPT and I can help you build Anki flashcard decks.
#
#
# > create 10 random flashcards
# FUNCTION CALL id='3ko8hali' args={'back': 'Paris', 'deck': 'Random Facts', 'front': 'What is the capital of France?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='hbt4kd0m' args={'back': 'Blue whale', 'deck': 'Random Facts', 'front': 'What is the largest mammal?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='fis72n9g' args={'front': 'Who wrote "Romeo and Juliet"?', 'deck': 'Random Facts', 'back': 'William Shakespeare'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='cfuoh286' args={'back': 'H2O', 'front': 'What is the chemical symbol for water?', 'deck': 'Random Facts'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='29h7c8qc' args={'front': 'Which planet is known as the Red Planet?', 'deck': 'Random Facts', 'back': 'Mars'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='urrh2j33' args={'deck': 'Random Facts', 'front': 'What is the tallest mountain in the world?', 'back': 'Mount Everest'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='7iroxbgq' args={'deck': 'Random Facts', 'front': 'How many continents are there on Earth?', 'back': 'Seven'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='q09czpqz' args={'front': 'Who painted the Mona Lisa?', 'deck': 'Random Facts', 'back': 'Leonardo da Vinci'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='fjs5l2ex' args={'front': 'What is the hardest natural substance on Earth?', 'deck': 'Random Facts', 'back': 'Diamond'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# FUNCTION CALL id='g1x6wuyp' args={'back': '1912', 'front': 'In what year did the Titanic sink?', 'deck': 'Random Facts'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Random Facts'
# > Save deck as empty
# FUNCTION CALL id='1tt6wp0t' args={'deck': 'empty'} name='save_anki_deck' partial_args=None will_continue=None
# OUTPUT Saved Anki deck 'empty' to file.
# > stop

# %% [markdown]
# Submit "empty.apkg" in Gradescope.

# %% [markdown]
# ## Part 4: Make an Anki Deck with Flashcards
#
# Run the Anki agent again, and instruct it to make 10 flashcards on a topic of your choice.
# If possible, have the agent supply the answers to your questions.
# When you are done, save the deck with an appropriate name (but not "empty.apkg").

# %%
anki_agent.run()
# Out:
# RUNNING WITH TOOLS ['create_anki_note', 'save_anki_deck']
# Hi, I am AnkiGPT and I can help you build Anki flashcard decks.
#
#
# > make 10 flash cards on economic theories
# FUNCTION CALL id='e46rd2nc' args={'back': "A school of thought founded by Adam Smith that emphasizes free markets, the 'invisible hand', and minimal government intervention.", 'deck': 'Economic Theories', 'front': 'What is Classical Economics?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='gh9mr9h6' args={'front': 'What is Keynesian Economics?', 'deck': 'Economic Theories', 'back': 'Developed by John Maynard Keynes, it advocates for government intervention, especially during recessions, to manage aggregate demand.'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='zl6ezzd3' args={'front': 'What is Neoclassical Economics?', 'back': 'An approach that focuses on supply and demand as the driving forces behind production, pricing, and consumption, assuming individuals act rationally to maximize utility.', 'deck': 'Economic Theories'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='ei92jt5j' args={'back': "Based on Karl Marx's ideas, it focuses on the role of labor in the development of an economy and critiques capitalism, emphasizing class struggle and the labor theory of value.", 'deck': 'Economic Theories', 'front': 'What is Marxist Economics?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='mz3c4ezc' args={'front': 'What is Monetarism?', 'deck': 'Economic Theories', 'back': 'A theory popularized by Milton Friedman arguing that the macroeconomic performance of an economy is determined primarily by the money supply.'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='4k5l0u9d' args={'front': 'What is the Austrian School of Economics?', 'back': 'A school of thought emphasizing the organizing power of markets and individual choice, and arguing strongly against central planning and excessive government intervention (e.g., F.A. Hayek).', 'deck': 'Economic Theories'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='rjp9wxld' args={'deck': 'Economic Theories', 'back': 'A theory focusing on understanding the role of the evolutionary process and the role of institutions in shaping economic behavior.', 'front': 'What is Institutional Economics?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='pd1bt571' args={'front': 'What is Behavioral Economics?', 'deck': 'Economic Theories', 'back': 'A branch of economics that incorporates psychological insights into human behavior to explain why individuals sometimes make irrational economic decisions.'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='7ai46hui' args={'deck': 'Economic Theories', 'back': 'A macroeconomic theory arguing that economic growth can be most effectively fostered by lowering taxes and decreasing regulation.', 'front': 'What is Supply-Side Economics?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# FUNCTION CALL id='zqdc7so3' args={'back': 'A branch of economics focusing on improving fiscal, economic, and social conditions in developing countries, often associated with concepts like human capability.', 'deck': 'Economic Theories', 'front': 'What is Development Economics?'} name='create_anki_note' partial_args=None will_continue=None
# OUTPUT Created note in Anki deck 'Economic Theories'
# > stop

# %% [markdown]
# Submit "anki.txt" from making flashcards and the .apkg file with your flashcards in Gradescope.

# %% [markdown]
# ## Part 5: Code
#
# Please submit a Jupyter notebook that can reproduce all your calculations and recreate the previously submitted files.
# You do not need to provide code for data collection if you did that by manually.

# %% [markdown]
# ## Part 6: Acknowledgements
#
# If you discussed this assignment with anyone, please acknowledge them here.
# If you did this assignment completely on your own, simply write none below.
#
# If you used any libraries not mentioned in this module's content, please list them with a brief explanation what you used them for. If you did not use any other libraries, simply write none below.
#
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the generative AI policy. If you did not use any generative AI tools, simply write none below.

# %%
with open('acknowledgements.txt', 'w') as f:
    f.write('non')
